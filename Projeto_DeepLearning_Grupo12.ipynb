# %% [markdown]
# <a href="https://colab.research.google.com/github/Lariiuki/Aprendizado-de-maquina/blob/main/Projeto_DeepLearning_Grupo12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Análise e Geração de Relatório para Dados Tabulares – Grupo 12
# **Integrantes:** Danilo Falcão,  Getúlio, Larissa Akemi, Ricardo Arruda
#
# **Descrição:**
# Este trabalho utiliza o conjunto de dados "Anime Data Set for ML" disponível no Kaggle. Este dataset compreende informações detalhadas sobre uma vasta coleção de animes, totalizando **29.153 entradas e 19 atributos** por entrada. As informações contidas no dataset são cruciais para análise que visam compreender características e tendências no universo dos animes.
#
# **Dataset**: [Anime data set for recommendation system](https://www.kaggle.com/datasets/wiltheman/anime-data-set-for-ml)
#
#
#  Esse conjunto de dados contém informações sobre animes, incluindo
#
# | Nome da Coluna       | Descrição                                                                 |
# |----------------------|---------------------------------------------------------------------------|
# | `title`              | Título principal do anime.                                                |
# | `title_english`      | Título oficial em inglês, se disponível.                                  |
# | `title_japanese`     | Título original em japonês.                                               |
# | `image`              | URL da imagem de capa do anime.                                           |
# | `aired_from`         | Data de início da exibição do anime.                                      |
# | `aired_to`           | Data de término da exibição do anime.                                     |
# | `synopsis`           | Breve descrição ou resumo da história do anime.                           |
# | `status`             | Status de exibição (ex: Finalizado, Em exibição, Não lançado).            |
# | `episodes`           | Número total de episódios.                                                |
# | `rating`             | Faixa etária recomendada (ex: PG-13, R).                                  |
# | `rank`               | Posição do anime no ranking geral com base nas avaliações dos usuários.   |
# | `popularity`         | Posição no ranking de popularidade com base na quantidade de membros.     |
# | `members`            | Número de usuários que adicionaram o anime às suas listas.                |
# | `favorites`          | Número de usuários que marcaram o anime como favorito.                    |
# | `score`              | Pontuação média atribuída pelos usuários.                                 |
# | `scored_by`          | Número de usuários que avaliaram o anime.                                 |
# | `genres`             | Gêneros do anime (ex: Ação, Fantasia).                                    |
# | `themes`             | Temas associados ao anime (ex: Escola, Superpoder).                       |
# | `demographics`       | Público-alvo do anime (ex: Shounen, Seinen).                              |

# %%
import kagglehub

path = kagglehub.dataset_download("wiltheman/anime-data-set-for-ml")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/anime-data-set-for-ml

# %%
import os

print(os.listdir(path))
# Out:
# ['65k_anime_data.csv']

# %%
import pandas as pd
import os

csv_file = os.path.join(path, '65k_anime_data.csv')

df = pd.read_csv(csv_file)

df.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                   aired_from                   aired_to  \
# 0  1998-04-03 00:00:00+00:00  1999-04-24 00:00:00+00:00
# 1  2001-09-01 00:00:00+00:00                        NaN
# 2  1998-04-01 00:00:00+00:00  1998-09-30 00:00:00+00:00
# 3  2002-07-03 00:00:00+00:00  2002-12-25 00:00:00+00:00
# 4  2004-09-30 00:00:00+00:00  2005-09-29 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# 1       1.0  R - 17+ (violence & profanity)   216.0         643   398998
# 2      26.0       PG-13 - Teens 13 or older   385.0         261   805264
# 3      26.0       PG-13 - Teens 13 or older  3272.0        1958   123821
# 4      52.0                   PG - Children  4816.0        5680    16325
#
#    favorites  score  scored_by                                genres  \
# 0      86816   8.75  1022817.0         Action, Award Winning, Sci-Fi
# 1       1712   8.38   225855.0                        Action, Sci-Fi
# 2      16908   8.22   389888.0             Action, Adventure, Sci-Fi
# 3        674   7.23    45420.0  Action, Drama, Mystery, Supernatural
# 4         16   6.92     6969.0            Action, Adventure, Fantasy
#
#               themes demographics
# 0  Adult Cast, Space          NaN
# 1  Adult Cast, Space          NaN
# 2         Adult Cast      Shounen
# 3          Detective          NaN
# 4                NaN      Shounen

# %%
df.shape
# Out:
# (29153, 19)

# %%
df.columns
# Out:
# Index(['title', 'title_english', 'title_japanese', 'image', 'aired_from',
#        'aired_to', 'synopsis', 'status', 'episodes', 'rating', 'rank',
#        'popularity', 'members', 'favorites', 'score', 'scored_by', 'genres',
#        'themes', 'demographics'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29153 entries, 0 to 29152
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           29153 non-null  object
#  1   title_english   12475 non-null  object
#  2   title_japanese  28931 non-null  object
#  3   image           29153 non-null  object
#  4   aired_from      4123 non-null   object
#  5   aired_to        2107 non-null   object
#  6   synopsis        23970 non-null  object
#  7   status          29153 non-null  object
#  8   episodes        29153 non-null  float64
#  9   rating          28467 non-null  object
#  10  rank            22361 non-null  float64
#  11  popularity      29153 non-null  int64
#  12  members         29153 non-null  int64
#  13  favorites       29153 non-null  int64
#  14  score           18681 non-null  float64
#  15  scored_by       18681 non-null  float64
#  16  genres          22979 non-null  object
#  17  themes          17235 non-null  object
#  18  demographics    10788 non-null  object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 4.2+ MB

# %%
# fazer um novo dataset
df_anime = df.copy()

# %% [markdown]
# # Análise Exploratória de Dados (EDA) - Formatação do dataset

# %% [markdown]
# Vamos verificar o que contém cada coluna que nos interessa

# %%
df_anime['title'].tolist()
# Out:
# ['Cowboy Bebop',
#  'Cowboy Bebop: Tengoku no Tobira',
#  'Trigun',
#  'Witch Hunter Robin',
#  'Bouken Ou Beet',
#  'Eyeshield 21',
#  'Hachimitsu to Clover',
#  'Hungry Heart: Wild Striker',
#  'Initial D Fourth Stage',
#  'Monster',
#  'Naruto',
#  'One Piece',
#  'Tennis no Oujisama',
#  'Ring ni Kakero 1',
#  'School Rumble',
#  'Sunabouzu',
#  'Texhnolyze',
#  'Trinity Blood',
#  'Yakitate!! Japan',
#  'Zipang',
#  'Shinseiki Evangelion',
#  'Shinseiki Evangelion Movie: Shi to Shinsei',
#  'Shinseiki Evangelion Movie: Air/Magokoro wo, Kimi ni',
#  'Kenpuu Denki Berserk',
#  'Koukaku Kidoutai',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Ishinshishi e no Chinkonka',
#  'Akira',
#  '.hack//Sign',
#  'Aa! Megami-sama!',
#  'Aa! Megami-sama! (TV)',
#  'Tenshi Kinryouku',
#  'Kidou Tenshi Angelic Layer',
#  'Ai Yori Aoshi',
#  'Appleseed (Movie)',
#  'Arc the Lad',
#  'Avenger',
#  'Beck',
#  'Blue Gender',
#  'Chobits',
#  'Chrno Crusade',
#  'D.N.Angel',
#  'D.C.: Da Capo',
#  'DearS',
#  'Rozen Maiden',
#  'Rozen Maiden: Träumend',
#  'Azumanga Daiou The Animation',
#  'Basilisk: Kouga Ninpou Chou',
#  'Black Cat',
#  'Cluster Edge',
#  'Full Metal Panic!',
#  'Full Metal Panic? Fumoffu',
#  'Full Metal Panic! The Second Raid',
#  'Gakuen Alice',
#  'Soukyuu no Fafner: Dead Aggressor',
#  'Mahou Shoujo Lyrical Nanoha',
#  "Mahou Shoujo Lyrical Nanoha A's",
#  'Shuffle!',
#  'Kidou Senshi Gundam',
#  'Kidou Senshi Gundam: Dai 08 MS Shoutai',
#  'Kidou Senshi Gundam 0080: Pocket no Naka no Sensou',
#  "Kidou Senshi Gundam: Dai 08 MS Shoutai - Miller's Report",
#  'Kidou Senshi Gundam 0083: Stardust Memory',
#  'Kidou Senshi Zeta Gundam',
#  'Kidou Senshi Gundam ZZ',
#  'Kidou Senshi Gundam: Gyakushuu no Char',
#  'Kidou Senshi Gundam F91',
#  'Kidou Senshi Victory Gundam',
#  'Shin Kidou Senki Gundam Wing',
#  'Shin Kidou Senki Gundam Wing: Endless Waltz',
#  'Kidou Shinseiki Gundam X',
#  'Kidou Senshi Gundam SEED',
#  'Kidou Senshi Gundam SEED Destiny',
#  'Turn A Gundam',
#  'Kidou Butouden G Gundam',
#  'Last Exile',
#  'Mai-HiME',
#  'Mai-Otome',
#  'Shin Shirayuki-hime Densetsu Prétear',
#  'Air',
#  'Aishiteruze Baby★★',
#  'Akazukin Chacha',
#  'Ayashi no Ceres',
#  'Boys Be...',
#  'Hana yori Dango',
#  'Ou Dorobou Jing',
#  'Ou Dorobou Jing in Seventh Heaven',
#  'Bakuretsu Tenshi',
#  'Chuuka Ichiban!',
#  'Corrector Yui',
#  'Chou Henshin Cosprayers',
#  'Uchuu no Stellvia',
#  'Sakigake!! Cromartie Koukou',
#  'Ijigen no Sekai El-Hazard',
#  'Shinpi no Sekai El-Hazard (TV)',
#  'Shinpi no Sekai El-Hazard',
#  'Shinpi no Sekai El-Hazard Season 2',
#  'Final Approach',
#  'Fruits Basket',
#  'Fullmetal Alchemist',
#  'Full Moon wo Sagashite',
#  'Fushigi Yuugi',
#  'Fushigi Yuugi: Eikouden',
#  'Futakoi',
#  'Futakoi Alternative',
#  'Gate Keepers',
#  'Gate Keepers 21',
#  'Gensoumaden Saiyuuki',
#  'Saiyuuki Reload',
#  'Saiyuuki Reload Gunlock',
#  'GetBackers',
#  'Green Green',
#  'Gunslinger Girl',
#  'Hikaru no Go',
#  'Hunter x Hunter',
#  'Hunter x Hunter: Original Video Animation',
#  'Hunter x Hunter: Greed Island',
#  'Hunter x Hunter: Greed Island Final',
#  'Jinki:Extend',
#  'Kamikaze Kaitou Jeanne',
#  'Kannazuki no Miko',
#  'Kanon',
#  'Kareshi Kanojo no Jijou',
#  'Kono Minikuku mo Utsukushii Sekai',
#  'Kimi ga Nozomu Eien',
#  'Kita e.: Diamond Dust Drops',
#  'Loveless',
#  'Blood+',
#  'Re: Cutie Honey',
#  'Solty Rei',
#  'Juuni Kokuki',
#  'Shaman King',
#  'X/1999',
#  'X',
#  'Mahou Sensei Negima!',
#  'Maria-sama ga Miteru',
#  'Boukyaku no Senritsu',
#  'Ima, Soko ni Iru Boku',
#  'Peace Maker Kurogane',
#  'Pita Ten',
#  'Power Stone',
#  'Mononoke Hime',
#  'RahXephon',
#  'Samurai 7',
#  'Scrapped Princess',
#  's.CRY.ed',
#  'Shingetsutan Tsukihime',
#  'Slam Dunk',
#  'Strange Dawn',
#  'Tactics',
#  'Tenjou Tenge',
#  'Tokyo Underground',
#  'Triangle Heart: Sweet Songs Forever',
#  'Tsubasa Chronicle',
#  'Ultra Maniac',
#  'Ultra Maniac OVA',
#  'Vandread',
#  'Vandread: The Second Stage',
#  'Tenkuu no Escaflowne',
#  'Whistle!',
#  'Xenosaga The Animation',
#  'Initial D First Stage',
#  'Initial D Second Stage',
#  'Initial D Third Stage',
#  'Gosenzo Sane',
#  'Love Hina',
#  'Love Hina Again',
#  'Love Hina Christmas Special: Silent Eve',
#  'Love Hina Haru Special: Kimi Sakura Chiru Nakare!!',
#  'Maburaho',
#  'Macross Zero',
#  'Onegai☆Teacher',
#  'Onegai☆Twins',
#  'Rizelmine',
#  'Speed Grapher',
#  'Sen to Chihiro no Kamikakushi',
#  'Tenshi na Konamaiki',
#  'Video Girl Ai',
#  "Wolf's Rain",
#  'Words Worth',
#  'Yumeria',
#  'Samurai Champloo',
#  'Lodoss-tou Senki: Eiyuu Kishi Den',
#  'Lodoss-tou Senki',
#  'R.O.D: Read or Die',
#  'R.O.D: The TV',
#  'Ranma ½',
#  'Pure Mail',
#  'Project A-Ko',
#  'Pia Carrot e Youkoso!!',
#  'Pia Carrot e Youkoso!! 2',
#  'Pia Carrot e Youkoso!! 2 DX',
#  'Pia Carrot e Youkoso!!: Sayaka no Koi Monogatari',
#  'Shin Angel',
#  'Kidou Senkan Nadesico',
#  'Kidou Senkan Nadesico: The Prince of Darkness',
#  'Kuro no Danshou',
#  'Mezzo Forte',
#  'Mezzo DSA',
#  'Dragon Ball',
#  'Dragon Ball GT',
#  'Elfen Lied',
#  'FLCL',
#  'Jigoku Shoujo',
#  'Ninin ga Shinobuden',
#  'Air Master',
#  'Asagiri no Miko',
#  'Cardcaptor Sakura',
#  'Daa! Daa! Daa!',
#  'Dan Doh!!',
#  'Meitantei Conan',
#  "E's Otherwise",
#  'Koukyoushihen Eureka Seven',
#  'Rekka no Honoo',
#  'Gankutsuou',
#  'Genshiken',
#  'Girls Bravo: First Season',
#  'Gokusen',
#  'Gravitation',
#  'Agatha Christie no Meitantei Poirot to Marple',
#  'Great Teacher Onizuka',
#  'Groove Adventure Rave',
#  'Harukanaru Toki no Naka de: Hachiyou Shou',
#  'Ichigo 100%',
#  'InuYasha',
#  'Konjiki no Gash Bell!!',
#  'Kyou kara Maou!',
#  'Madlax',
#  'Jungle wa Itsumo Hare nochi Guu',
#  'Jungle wa Itsumo Hare nochi Guu Deluxe',
#  'Jungle wa Itsumo Hare nochi Guu Final',
#  'Hoshi no Koe',
#  'Ikkitousen',
#  'Hitsuji no Uta',
#  'Happy☆Lesson',
#  'Happy☆Lesson (TV)',
#  'Happy☆Lesson Advance',
#  'Happy☆Lesson The Final',
#  'Hajime no Ippo',
#  'Hajime no Ippo: Champion Road',
#  'Hajime no Ippo: Mashiba vs. Kimura',
#  'Gunparade March: Arata Naru Kougunka',
#  'Gungrave',
#  'Golden Boy',
#  'Bleach',
#  'Hellsing',
#  'Gad Guard',
#  'Noir',
#  'Mahoutsukai ni Taisetsu na Koto',
#  'Kiddy Grade',
#  'Love♥Love?',
#  'Mahoromatic: Automatic Maiden',
#  'Mahoromatic: Motto Utsukushii Mono',
#  'Viewtiful Joe',
#  'Kyougoku Natsuhiko: Kousetsu Hyaku Monogatari',
#  'Animal Yokochou',
#  'Akane Maniax',
#  'Angel Heart',
#  'Akage no Anne',
#  'Area 88 (TV)',
#  'Argento Soma',
#  "B'T X",
#  'Grappler Baki (TV)',
#  'Bakuten Shoot Beyblade',
#  'Comic Party',
#  'Seikai no Monshou',
#  'D.C.S.S: Da Capo Second Season',
#  'Dear Boys',
#  'Di Gi Charat',
#  'Divergence Eve',
#  'Divergence Eve 2: Misaki Chronicles',
#  'Dragon Drive',
#  'Grenadier: Hohoemi no Senshi',
#  '.hack//Tasogare no Udewa Densetsu',
#  '.hack//Liminality',
#  '3x3 Eyes',
#  'Cinderella Boy',
#  'Mirai Shounen Conan',
#  'Aa! Megami-sama!: Chichaitte Koto wa Benri da ne',
#  'Aa! Megami-sama! Movie',
#  'Abashiri Ikka',
#  'Abenobashi Mahou☆Shoutengai',
#  'Kerokko Demetan',
#  'Zettai Shounen',
#  'Akahori Gedou Hour Rabuge',
#  'Chiisana Obake: Acchi, Kocchi, Socchi',
#  'Ace wo Nerae!',
#  'Ace wo Nerae! Final Stage',
#  'Ace wo Nerae! (1979)',
#  'Ace wo Nerae! 2',
#  'Xiao Qian',
#  'Nageki no Kenkou Yuuryouji',
#  'Final Fantasy VII: Advent Children',
#  'Hand Maid May',
#  'Happy World!',
#  'A Kite',
#  'Najica Dengeki Sakusen',
#  'Paradise Kiss',
#  'Mousou Dairinin',
#  'Kidou Keisatsu Patlabor: On Television',
#  'Peach Girl',
#  'Petshop of Horrors',
#  'Puchi Pri*Yucie',
#  'Piano',
#  'Planetes',
#  'Midori no Hibi',
#  'Mahoujin Guruguru',
#  'Dokidoki♡Densetsu: Mahoujin Guruguru',
#  'Mama wa Shougaku 4-nensei',
#  'Marmalade Boy',
#  'Matantei Loki Ragnarok',
#  'Ginyuu Mokushiroku Meine Liebe',
#  'Psychic Academy',
#  'Versailles no Bara',
#  'Serial Experiments Lain',
#  'Mutsu Enmei Ryuu Gaiden: Shura no Toki',
#  'Spiral: Suiri no Kizuna',
#  'Starship Operators',
#  'Tsukuyomi: Moon Phase',
#  'Futatsu no Spica',
#  'Eikoku Koi Monogatari Emma',
#  'W: Wish',
#  'Wild Arms: Twilight Venom',
#  'Binzume Yousei',
#  'Magical Canan',
#  'Ojamajo Doremi',
#  'Ojamajo Doremi Sharp',
#  'Motto! Ojamajo Doremi',
#  'Ojamajo Doremi Dokkaan!',
#  'UG☆Ultimate Girls',
#  'Shakugan no Shana',
#  'Fate/stay night',
#  'Bokusatsu Tenshi Dokuro-chan',
#  'Iriya no Sora, UFO no Natsu',
#  "I'll/CKBC",
#  'Himiko-den',
#  'Memories Off',
#  'Memories Off 2nd',
#  'Memories Off 3.5',
#  'Gallery Fake',
#  'Fake',
#  'AIKa',
#  'Akazukin Chacha OVA',
#  'Bible Black',
#  'Boogiepop wa Warawanai',
#  'Burn Up Excess',
#  'Cardcaptor Sakura Movie 1',
#  'Cardcaptor Sakura Movie 2: Fuuin Sareta Card',
#  'Bannou Bunka Neko-Musume',
#  'Bannou Bunka Neko-Musume DASH!',
#  'Bannou Bunka Neko-Musume (1998)',
#  'Elfen Lied: Tooriame nite Arui wa, Shoujo wa Ikani Shite Sono Shinjou ni Itatta ka? - Regenschauer',
#  'eX-Driver',
#  'eX-Driver the Movie',
#  'Heppoko Jikken Animation Excel♥Saga',
#  'Fushigi Yuugi OVA',
#  'Fushigi Yuugi: Dai Ni Bu',
#  'Futari Ecchi',
#  'Galaxy Angel',
#  'Gantz',
#  'Gilgamesh',
#  'H2',
#  'Haibane Renmei',
#  'Capeta',
#  'Karas',
#  'Suzuka',
#  'Tales of Phantasia The Animation',
#  'Yuu☆Yuu☆Hakusho',
#  'Escaflowne',
#  'Ai Yori Aoshi: Enishi',
#  'Gantz 2nd Stage',
#  'Seikai no Senki',
#  'Seikai no Senki II',
#  'Seikai no Senki III',
#  'Seikai no Senki Special',
#  'Seihou Bukyou Outlaw Star',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Seisou-hen',
#  'Otogi Juushi Akazukin OVA',
#  'Hanaukyou Maid-tai',
#  'Bastard!! Ankoku no Hakaishin',
#  'Blood: The Last Vampire',
#  'Buzzer Beater',
#  'Tantei Gakuen Q',
#  'Final Fantasy VII: Last Order',
#  'Gun x Sword',
#  'Kore ga Watashi no Goshujinsama',
#  'Hametsu no Mars',
#  'Tonari no Yamada-kun',
#  'Kurenai no Buta',
#  'Ragnarök The Animation',
#  'Ranma ½: Chuugoku Nekonron Daikessen! Okite Yaburi no Gekitou-hen!!',
#  'Samurai Deeper Kyou',
#  'Spriggan',
#  'Stratos 4',
#  'Stratos 4 OVA',
#  'Stratos 4 Advance',
#  'Dirty Pair',
#  'Shiritsu Araiso Koutougakkou Seitokai Shikkoubu',
#  'Final Fantasy',
#  'Kaleido Star',
#  'Kaleido Star: Aratanaru Tsubasa - Extra Stage',
#  'Kaleido Star: Legend of Phoenix - Layla Hamilton Monogatari',
#  'Fullmetal Alchemist: The Conqueror of Shamballa',
#  'Howl no Ugoku Shiro',
#  'Iria: Zeiram The Animation',
#  'Kumo no Mukou, Yakusoku no Basho',
#  'Legend of Lemnear: Kyokuguro no Tsubasa Valkisas',
#  'Magic Knight Rayearth',
#  'Perfect Blue',
#  'Phantom The Animation',
#  'RG Veda',
#  'Shoujo Kakumei Utena',
#  'Shoujo Kakumei Utena: Adolescence Mokushiroku',
#  'Naruto Movie 1: Dai Katsugeki!! Yuki Hime Ninpouchou Dattebayo!',
#  'Onegai☆Teacher: Himitsu na Futari',
#  'Maria-sama ga Miteru: Haru',
#  'Tales of Eternia The Animation',
#  'Weiß Kreuz Glühen',
#  'Weiß Kreuz',
#  'Tenjou Tenge: The Ultimate Fight',
#  'InuYasha Movie 4: Guren no Houraijima',
#  'InuYasha Movie 2: Kagami no Naka no Mugenjou',
#  'InuYasha Movie 3: Tenka Hadou no Ken',
#  'InuYasha Movie 1: Toki wo Koeru Omoi',
#  '.hack//Gift',
#  'Fantastic Children',
#  'Gokujou Seitokai',
#  'Mushishi',
#  'Buttobi!! CPU',
#  'One Piece Movie 01',
#  'One Piece Movie 02: Nejimaki-jima no Daibouken',
#  'One Piece Movie 03: Chinjuu-jima no Chopper Oukoku',
#  'One Piece Movie 04: Dead End no Bouken',
#  'One Piece Movie 05: Norowareta Seiken',
#  'One Piece Movie 06: Omatsuri Danshaku to Himitsu no Shima',
#  'One Piece Movie 07: Karakuri-jou no Mecha Kyohei',
#  'One Piece: Taose! Kaizoku Ganzack',
#  'Koukaku Kidoutai: Stand Alone Complex',
#  'Innocence',
#  'Karin',
#  'Okusama wa Joshikousei (TV)',
#  'To Heart 2',
#  'To Heart',
#  'Tide-Line Blue',
#  'Macross Plus',
#  'Hotori: Tada Saiwai wo Koinegau',
#  'Ginban Kaleidoscope',
#  'Aria the Animation',
#  'Sousei no Aquarion',
#  'Ueki no Housoku',
#  'Yu☆Gi☆Oh! Duel Monsters',
#  'Yu☆Gi☆Oh! Duel Monsters GX',
#  'Kurau Phantom Memory',
#  'Gensoumaden Saiyuuki Movie: Requiem - Erabarezaru Mono e no Chinkonka',
#  'Damekko Doubutsu',
#  'Kino no Tabi: The Beautiful World',
#  'Girls Bravo: Second Season',
#  'Ichigo Mashimaro',
#  'Kamichu!',
#  'Paniponi Dash!',
#  'Armitage III: Dual-Matrix',
#  'Armitage III: Poly-Matrix',
#  'Bakuretsu Hunters',
#  'Kamui no Ken',
#  'Yami to Boushi to Hon no Tabibito',
#  'Haja Taisei Dangaiou',
#  'Makai Toshi Shinjuku',
#  'Doraemon',
#  'Dragon Ball Movie 1: Shen Long no Densetsu',
#  'Eien no Aselia',
#  'Garou Densetsu: The Motion Picture',
#  'Fushigiboshi no☆Futagohime',
#  'Glass no Kamen',
#  'Gravitation: Lyrics of Love',
#  'Tottoko Hamtarou',
#  'I My Me! Strawberry Eggs',
#  'Kakyuusei 2: Hitomi no Naka no Shoujo-tachi',
#  'Kidou Shinsengumi Moeyo Ken TV',
#  'Majo no Takkyuubin',
#  'Tenkuu no Shiro Laputa',
#  'Cossette no Shouzou',
#  'Hajimari no Boukensha-tachi: Legend of Crystania',
#  'Keroro Gunsou',
#  'School Rumble: Ichi Gakki Hoshuu',
#  'Mahou no Princess Minky Momo',
#  'Mahoraba: Heartful Days',
#  'Marmalade Boy Movie',
#  'Mermaid Melody Pichi Pichi Pitch',
#  'Metropolis',
#  'Tonari no Totoro',
#  'Onegai☆Twins: Natsu wa Owaranai',
#  'Otogizoushi',
#  'Boku no Chikyuu wo Mamotte',
#  'Pokemon',
#  'Pokemon Movie 01: Mewtwo no Gyakushuu',
#  'Saishuu Heiki Kanojo',
#  'Bishoujo Senshi Sailor Moon',
#  'Bishoujo Senshi Sailor Moon R: The Movie',
#  'Bishoujo Senshi Sailor Moon S',
#  'Sensei no Ojikan: Dokidoki School Hours',
#  'Slayers',
#  'Slayers Next',
#  'Slayers: The Motion Picture',
#  'Tekken',
#  'Shin Tenchi Muyou!',
#  'Tenchi Muyou! Ryououki',
#  'Tenchi Muyou! Ryououki 2nd Season',
#  'Tenchi Muyou! Ryououki 3rd Season',
#  'Vampire Hunter D (2000)',
#  'Venus Senki',
#  'Mousou Kagaku Series: Wandaba Style',
#  'Wind: A Breath of Heart (TV)',
#  'Wind: A Breath of Heart OVA',
#  'Wonderful Days',
#  'Yu☆Gi☆Oh!',
#  'Grappler Baki: Saidai Tournament-hen',
#  'Digimon Adventure',
#  'Yami no Matsuei',
#  'Koutetsu Tenshi Kurumi',
#  'Koutetsu Tenshi Kurumi 2',
#  'Koutetsu Tenshi Kurumi Zero',
#  'Koutetsu Tenshi Kurumi Encore',
#  'Major S2',
#  'RahXephon: Kansoukyoku/Kanojo to Kanojo Jishin to - Thatness and Thereness',
#  'Soukyuu no Fafner: Dead Aggressor - Right of Left',
#  'Sakura Taisen',
#  'Sakura Taisen: Le Nouveau Paris',
#  'DNA²',
#  'Puni Puni☆Poemii',
#  'Steamboy',
#  'Tetsuwan Birdy',
#  'The Big O',
#  'Bubblegum Crisis Tokyo 2040',
#  'Musekinin Kanchou Tylor',
#  'Jin-Rou',
#  'Moldiver',
#  'Kaze no Tani no Nausicaä',
#  'Saber Marionette J',
#  'Rean no Tsubasa',
#  'Magikano',
#  'Kagi Hime Monogatari: Eikyuu Alice Rondo',
#  'Hotaru no Haka',
#  'Battle Programmer Shirase',
#  'Kogepan',
#  'Honoo no Labyrinth',
#  'Sexy Commando Gaiden: Sugoi yo!! Masaru-san',
#  'Noein: Mou Hitori no Kimi e',
#  'Mimi wo Sumaseba',
#  'Ayakashi: Japanese Classic Horror',
#  'Hanbun no Tsuki ga Noboru Sora',
#  'Itsudatte My Santa!',
#  'Ginga Nagareboshi Gin',
#  'Kage kara Mamoru!',
#  'Amaenaide yo!!',
#  'PopoloCrois',
#  'Mugen no Ryvius',
#  'Naruto: Takigakure no Shitou - Ore ga Eiyuu Dattebayo!',
#  'X OVA',
#  'Chobits: Chibits',
#  'Neko no Ongaeshi',
#  'Jinzou Ningen Kikaider The Animation',
#  'Yuugen Kaisha',
#  'Legend of Duo',
#  'Nekojiru-sou',
#  'KO Seiki Beast Sanjuushi',
#  'Futari wa Precure',
#  'Mahou no Stage Fancy Lala',
#  'Tenshi ni Narumon!',
#  'Kazemakase Tsukikage Ran',
#  'Otogi Juushi Akazukin',
#  'Sakura Taisen: Katsudou Shashin',
#  'Saishuu Heiki Kanojo: Another Love Song',
#  'Popotan',
#  'Platonic Chain',
#  'PetoPeto-san',
#  'Onmyou Taisenki',
#  'Okusama wa Mahou Shoujo',
#  'Nurse Witch Komugi-chan Magikarte',
#  'Nurse Angel Ririka SOS',
#  'Juubee Ninpuuchou',
#  'Juubee Ninpuuchou: Ryuuhougyoku-hen',
#  'Ninja Ryuukenden',
#  'Takahashi Rumiko Gekijou Ningyo no Mori',
#  'Night Walker: Mayonaka no Tantei',
#  'Natsu-iro no Sunadokei',
#  'Shichinin no Nana',
#  'Mouse',
#  'Moekan The Animation',
#  'Mamotte Shugogetten!',
#  'Major S1',
#  'Mahoutsukai Tai!',
#  'Mahoutsukai Tai! (TV)',
#  'Mahoromatic Summer Special',
#  'Mahoromatic End Year Special',
#  'Legend of Basara',
#  'Koi Kaze',
#  'Juubee-chan: Lovely Gantai no Himitsu',
#  'Juubee-chan 2: Siberia Yagyuu no Gyakushuu',
#  'Iketeru Futari',
#  'Ichigo 100% Special 2',
#  'Ichigo 100%: Koi ga Hajimaru?! Satsuei Gasshuku - Yureru Kokoro ga Higashi e Nishi e',
#  'Hachimitsu to Clover Specials',
#  'Hikaru no Go: Hokuto Hai e no Michi',
#  'Haunted Junction',
#  'Harukanaru Toki no Naka de: Ajisai Yumegatari',
#  'Tsuki wa Higashi ni Hi wa Nishi ni: Operation Sanctuary',
#  'Hanaukyou Maid-tai: La Verite',
#  'Gunsmith Cats',
#  'Green Green Thirteen: Erolutions',
#  'Galaxy Angel Z',
#  'Galaxy Angel 3',
#  'Galaxy Angel 3 Specials',
#  'Galaxy Angel 4',
#  'Air in Summer',
#  'Touhai Densetsu Akagi: Yami ni Maiorita Tensai',
#  'Azumanga Daiou: Gekijou Tanpen',
#  'Denshin Mamotte Shugogetten',
#  'Elf-ban Kakyuusei: Anata dake wo Mitsumete...',
#  'Fullmetal Alchemist: Reflections',
#  'JoJo no Kimyou na Bouken: Adventure',
#  'JoJo no Kimyou na Bouken',
#  'Kashimashi: Girl Meets Girl',
#  'Koi Koi 7',
#  'Kujibiki Unbalance',
#  'Lamune',
#  'Lemon Angel Project',
#  'Mai-HiME Specials',
#  'One: Kagayaku Kisetsu e',
#  'Refrain Blue',
#  'Sentimental Journey',
#  'Shadow Skill: Eigi',
#  'Shadow Skill (1996)',
#  'Tenbatsu Angel Rabbie☆',
#  'Otogi Story Tenshi no Shippo',
#  'Otogi Story Tenshi no Shippo Specials',
#  'Tenshi no Shippo Chu!',
#  'To Heart: Remember My Memories',
#  'To Heart: Remember My Memories Specials',
#  'Tokyo Mew Mew',
#  'Uta∽Kata',
#  'Uta∽Kata: Shotou no Futanatsu',
#  'Kyuuketsuhime Miyu (TV)',
#  'Yawara!',
#  'Dousou Kai',
#  'Burn Up Scramble',
#  'Canvas 2: Nijiiro no Sketch',
#  'Canvas: Sepia-iro no Motif',
#  'Tenchi Muyou!',
#  'Kanon Kazahana',
#  'Chou Henshin Cosprayers vs. Ankoku Uchuu Shougun the Movie',
#  'Comic Party Revolution',
#  'Comic Party Specials',
#  'Patapata Hikousen no Bouken',
#  'Mujin Wakusei Survive',
#  'Rec',
#  'Uchuu Senkan Yamato (Movie)',
#  'Zoids Genesis',
#  'Air Movie',
#  'High School! Kimengumi',
#  'Yume de Aetara',
#  'Yume de Aetara (TV)',
#  'Ai no Kusabi',
#  'Princess Tutu',
#  'Baby☆Love',
#  'Candy Candy (Movie)',
#  'Enzai',
#  'First Kiss Monogatari',
#  'Kingyo Chuuihou!',
#  'Hiatari Ryoukou!',
#  'Houkago no Shokuinshitsu',
#  'Interstella5555: The 5tory of The 5ecret 5tar 5ystem',
#  'Vampire Hunter D',
#  'Kizuna',
#  'Kizuna: Koi no Karasawagi',
#  'Keiraku no Houteishiki Level-C',
#  'MÄR',
#  'Bishoujo Senshi Sailor Moon R',
#  'Sensitive Pornograph',
#  'Umi ga Kikoeru',
#  'Trouble Chocolate',
#  'Papa to Kiss in the Dark',
#  'Haru wo Daite Ita',
#  'True Love Story',
#  'Nanami-chan',
#  'Binchou-tan',
#  'Bomberman Jetters',
#  'Osakana wa Ami no Naka',
#  'Chijoku Shinsatsushitsu',
#  'Yuki no Joou (TV)',
#  'Boku no Sexual Harassment',
#  'School Days ONA',
#  'Kaze wo Mita Shounen',
#  'RahXephon: Tagen Hensoukyoku',
#  'Tokyo Godfathers',
#  'Tenjou Tenge: The Past Chapter',
#  'Naruto: Akaki Yotsuba no Clover wo Sagase',
#  'Bleach: Memories in the Rain',
#  'Zoids',
#  'Zoids Shinseiki/Zero',
#  'Chou Henshin Cosprayers Specials',
#  'Kishin Houkou Demonbane',
#  'Burn Up!',
#  'Burn Up! W',
#  'Pale Cocoon',
#  'Ginyuu Mokushiroku Meine Liebe Wieder',
#  'Tenamonya Voyagers',
#  'Nanaka 6/17',
#  'Hellsing Ultimate',
#  'Meitantei Conan Movie 01: Tokei Jikake no Matenrou',
#  'Meitantei Conan Movie 02: 14-banme no Target',
#  'Meitantei Conan Movie 03: Seikimatsu no Majutsushi',
#  'Gasaraki',
#  'Miami Guns',
#  'Otaku no Video',
#  'Pugyuru',
#  'Eiken: Eikenbu yori Ai wo Komete',
#  'Shinigami no Ballad.',
#  'Ergo Proxy',
#  'Arion',
#  'Ranma ½: Kessen Tougenkyou! Hanayome wo Torimodose!',
#  'xxxHOLiC Movie: Manatsu no Yoru no Yume',
#  'Oniisama e...',
#  'Mahoujin Guruguru Movie',
#  'Hanaukyou Maid-tai OVA',
#  'Yomigaeru Sora: Rescue Wings',
#  'Kokoro Toshokan',
#  'NieA Under 7',
#  'Koukaku Kidoutai: Stand Alone Complex 2nd GIG',
#  'Tsubasa Chronicle: Tori Kago no Kuni no Himegimi',
#  'Bakuretsu Hunters OVA',
#  'Android Ana Maico 2010',
#  "I''s Pure",
#  'Chikyuu Shoujo Arjuna',
#  'Dragon Ball Z',
#  'Tennis no Oujisama: Atobe kara no Okurimono - Kimi ni Sasageru Tennis Prince Matsuri',
#  'Tennis no Oujisama Movie 1: Futari no Samurai - The First Game',
#  'Nanako Kaitai Shinsho',
#  'Tactical Roar',
#  'Sakura Tsuushin',
#  'Boku wa Imouto ni Koi wo Suru',
#  'Ginga Eiyuu Densetsu',
#  'Initial D Battle Stage',
#  'Initial D Extra Stage',
#  'Virgin Night',
#  'Guardian Hearts',
#  'King of Fighters: Another Day',
#  'Uba',
#  'Jinshin Yuugi',
#  'Sexfriend',
#  'Chicchana Yukitsukai Sugar',
#  'Ginsoukikou Ordian',
#  'Choujuushin Gravion',
#  'Bleach: The Sealed Sword Frenzy',
#  'Sister Princess: Re Pure',
#  'Sister Princess',
#  'Kyou no 5 no 2',
#  'Narutaru: Mukuro Naru Hoshi Tama Taru Ko',
#  'Samurai Spirits 2: Asura Zanmaden',
#  'Narue no Sekai',
#  'Colorful',
#  'Ushio to Tora',
#  'Konjiki no Gash Bell!!: 101-banme no Mamono',
#  'Kiba',
#  'School Rumble Ni Gakki',
#  'Jinki:Extend - Sorekara',
#  'Suzumiya Haruhi no Yuuutsu',
#  'Gakuen Heaven',
#  'Kyou kara Ore wa!!',
#  'Gokinjo Monogatari',
#  'Ouran Koukou Host Club',
#  'Soul Link',
#  'Strawberry Panic',
#  'Utawarerumono',
#  'Air Gear',
#  'Gunparade Orchestra',
#  'Digimon Savers',
#  'Makai Senki Disgaea',
#  'xxxHOLiC',
#  "Joshikousei: Girl's High",
#  'Kidou Senshi Gundam SEED MSV Astray',
#  'Kikou Senki Dragonar',
#  'Slayers Premium',
#  'Slayers Gorgeous',
#  'Slayers Great',
#  'Slayers Return',
#  'Dragon Half',
#  'Mahou Shoujo-tai Arusu',
#  '.hack//Roots',
#  'Digimon Tamers',
#  'Mind Game',
#  'Street Fighter II V',
#  'Nana',
#  'Zegapain',
#  'Simoun',
#  'Aa! Megami-sama! Sorezore no Tsubasa',
#  'Green Green OVA',
#  'Yuu☆Yuu☆Hakusho (Movie)',
#  'Yuu☆Yuu☆Hakusho: Meikai Shitou-hen - Honoo no Kizuna',
#  'Shin Angyo Onshi',
#  'Tenshi no Tamago',
#  'Amaenaide yo!! Katsu!!',
#  'Megami Kouhosei Special Curriculum',
#  'Megami Kouhosei',
#  'Black Lagoon',
#  'Yuusha-Ou GaoGaiGar',
#  'Dragon Ball Movie 2: Majinjou no Nemurihime',
#  'Dragon Ball Movie 3: Makafushigi Daibouken',
#  'Dragon Ball Movie 4: Saikyou e no Michi',
#  'Dragon Ball Z Movie 01: Ora no Gohan wo Kaese!!',
#  'Dragon Ball Z Movie 02: Kono Yo de Ichiban Tsuyoi Yatsu',
#  'Dragon Ball Z Movie 03: Chikyuu Marugoto Choukessen',
#  'Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu',
#  'Dragon Ball Z Movie 05: Tobikkiri no Saikyou tai Saikyou',
#  'Dragon Ball Z Movie 06: Gekitotsu!! 100-oku Power no Senshi-tachi',
#  'Dragon Ball Z Movie 07: Kyokugen Battle!! Sandai Super Saiyajin',
#  'Dragon Ball Z Movie 08: Moetsukiro!! Nessen, Ressen, Chougekisen',
#  'Dragon Ball Z Movie 09: Ginga Girigiri!! Bucchigiri no Sugoi Yatsu',
#  'Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai',
#  'Dragon Ball Z Movie 11: Super Senshi Gekiha!! Katsu no wa Ore da',
#  'Dragon Ball Z Movie 12: Fukkatsu no Fusion!! Gokuu to Vegeta',
#  'Dragon Ball Z Movie 13: Ryuuken Bakuhatsu!! Gokuu ga Yaraneba Dare ga Yaru',
#  'Princess Princess',
#  'Fullmetal Alchemist: Premium Collection',
#  'Geneshaft',
#  'Himawari!',
#  'Konjiki no Gash Bell!!: Mecha Vulkan no Raishuu',
#  'Ninkuu',
#  'Kakutou Bijin Wulong',
#  'Ike! Ina-chuu Takkyuu-bu',
#  'Ginga Densetsu Weed',
#  'Tokkou',
#  'Riding Bean',
#  'Gintama',
#  'Ray The Animation',
#  'Nurse Witch Komugi-chan Magikarte Special',
#  'Nurse Witch Komugi-chan Magikarte Z',
#  'Transformers: Choujin Master Force',
#  'Transformers: The☆Headmasters',
#  'Tatakae! Chou Robot Seimeitai Transformers Victory',
#  'Transformers Superlink',
#  'Transformers Galaxy Force',
#  'Seisenshi Dunbine',
#  'Densetsu Kyojin Ideon',
#  'Ichigeki Sacchuu!! Hoihoi-san',
#  'Dai Mahou Touge',
#  'Higurashi no Naku Koro ni',
#  'Witchblade',
#  'Naruto Movie 2: Dai Gekitotsu! Maboroshi no Chiteiiseki Dattebayo!',
#  'Appleseed',
#  'Shin Getter Robo tai Neo Getter Robo',
#  'Inukami!',
#  'Renkin San-kyuu Magical? Pokaan',
#  'Nishi no Yoki Majo: Astraea Testament',
#  'Yume Tsukai',
#  'The Third: Aoi Hitomi no Shoujo',
#  'Top wo Nerae! Gunbuster',
#  'Street Fighter Alpha: Generations',
#  'Chibi Maruko-chan',
#  'Magical Nyan Nyan Taruto',
#  'Juu Ou Sei',
#  'Daikuu Maryuu Gaiking',
#  'Saiunkoku Monogatari',
#  'Heat Guy J',
#  'Shin Chou Kyou Ryo: Condor Hero',
#  'Shin Chou Kyou Ryo: Condor Hero II',
#  'Virtua Fighter',
#  'Aria the Natural',
#  'Love Hina: Motoko no Sentaku, Koi ka Ken... "Naku na"',
#  'Hit wo Nerae!',
#  'Yoshinaga-sanchi no Gargoyle',
#  'Crayon Shin-chan',
#  'Hokuto no Ken',
#  'Kakutou Bijin Wulong: Rebirth',
#  'Tsubasa Chronicle 2nd Season',
#  'Yokoyama Mitsuteru Sangokushi',
#  'Astro Boy: Tetsuwan Atom',
#  'Bible Black Gaiden',
#  "Glass no Kantai: La Legende du Vent de l'Univers",
#  'Dead Leaves',
#  'Yokohama Kaidashi Kikou',
#  'Yokohama Kaidashi Kikou: Quiet Country Cafe',
#  'Ginga Teikoku no Metsubou Gaiden: Aoki Ookami-tachi no Densetsu',
#  'Change!! Getter Robo: Sekai Saigo no Hi',
#  'Street Fighter Zero The Animation',
#  'Rikujou Bouei-tai Mao-chan',
#  'Ichigo 100% OVA',
#  'Cosplay Complex',
#  'Cosplay Complex: Extra Identification',
#  'Dragon Ball Z: Saiya-jin Zetsumetsu Keikaku',
#  'Dragon Ball Z Special 2: Zetsubou e no Hankou!! Nokosareta Chousenshi - Gohan to Trunks',
#  'Dragon Ball Z Special 1: Tatta Hitori no Saishuu Kessen',
#  'Dragon Ball GT: Gokuu Gaiden! Yuuki no Akashi wa Suushinchuu',
#  'Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Yuushi The Animation',
#  'Shinshaku Sengoku Eiyuu Densetsu: Sanada Juu Yuushi',
#  'Kamisama Kazoku',
#  'Usagi-chan de Cue!!',
#  'Dual! Parallel Lun-Lun Monogatari',
#  'Dual! Parallel Runrun Monogatari Special',
#  'Sin in the Rain',
#  'Tennis no Oujisama: Zenkoku Taikai-hen',
#  'Bishoujo Senshi Sailor Moon: Sailor Stars',
#  'Bishoujo Senshi Sailor Moon S: Kaguya-hime no Koibito',
#  'Blue Seed',
#  'Blue Seed 2',
#  'Uchuu Kaizoku Captain Herlock',
#  'Tide-Line Blue: Kyoudai',
#  'Top wo Nerae 2! Diebuster',
#  'Aa! Megami-sama! (TV) Specials',
#  'Kanojo to Kanojo no Neko',
#  'Star Ocean EX',
#  'Tenchi Muyou! in Love',
#  'Ranma ½ OVA',
#  'Ranma ½: Yomigaeru Kioku',
#  'Battle Spirits: Ryuuko no Ken',
#  'Ranma ½: Chou Musabetsu Kessen! Ranma Team vs. Densetsu no Houou',
#  'Ranma ½ Super',
#  'Sexy Commando Gaiden: Sugoi yo!! Masaru-san Specials',
#  "Le Chevalier D'Eon",
#  'Chicchana Yukitsukai Sugar Specials',
#  'Full Metal Panic! The Second Raid: Wari to Hima na Sentaichou no Ichinichi',
#  'Gunnm',
#  'Majutsushi Orphen',
#  'Majutsushi Orphen: Revenge',
#  'Honoo no Mirage',
#  'Honoo no Mirage: Minagiwa no Hangyakusha',
#  'Kaikan Phrase',
#  'Generator Gawl',
#  "Wolf's Rain OVA",
#  'Weiß Kreuz OVA',
#  'Kachou Ouji',
#  'Yakumotatsu',
#  'Psychic Force',
#  'Arete Hime',
#  'Omoide Poroporo',
#  'Heisei Tanuki Gassen Ponpoko',
#  'Hanare Toride no Yonna',
#  'Kumo no You ni Kaze no You ni',
#  'Sennen Joyuu',
#  'Ouritsu Uchuugun: Honneamise no Tsubasa',
#  'Patalliro Saiyuuki!',
#  'Kashou no Tsuki: Aki Kyougen',
#  'Saint Beast: Seijuu Kourin-hen',
#  'Mizuiro',
#  'Mizuiro (2003)',
#  'Mizuiro Jidai',
#  'Zetsuai 1989',
#  'Bronze: Zetsuai Since 1989',
#  'Tokyo Babylon',
#  'Taiyou no Ouji: Horus no Daibouken',
#  'Elf wo Karu Mono-tachi',
#  'Elf wo Karu Mono-tachi II',
#  'On Your Mark',
#  'The SoulTaker: Tamashii-gari',
#  'Cello Hiki no Gauche (1982)',
#  'Bobobo-bo Bo-bobo',
#  'Ao no 6-gou',
#  'Tokyo Juushouden',
#  'Tokyo Daigaku Monogatari',
#  'Blame!',
#  'Good Morning Call',
#  'Ippatsu Kiki Musume',
#  'Kidou Shinsengumi Moeyo Ken',
#  'Mutant Turtles: Choujin Densetsu-hen',
#  'Oruchuban Ebichu',
#  'Nekojiru Gekijou Jirujiru Original',
#  'Mazinkaiser',
#  'Touch',
#  'Shakugan no Shana-tan',
#  'Kishin Houkou Demonbane (TV)',
#  'Chou Denji Robo Combattler V',
#  'Chou Denji Machine Voltes V',
#  'Love Get Chu',
#  'Memories Off #5 Togireta Film The Animation',
#  'Sweat Punch',
#  'Naruto Narutimate Hero 3: Tsuini Gekitotsu! Jounin vs. Genin!! Musabetsu Dairansen Taikai Kaisai!!',
#  'Netrun-mon the Movie',
#  'Wizardry',
#  'Cardcaptor Sakura: Kero-chan ni Omakase!',
#  'Armitage III',
#  'Sentou Yousei Yukikaze',
#  'Space Pirate Captain Herlock: Outside Legend - The Endless Odyssey',
#  'Hikari to Mizu no Daphne',
#  'Ningen Kousaten',
#  "I''s",
#  'Interlude',
#  'Kenran Butou Sai: The Mars Daybreak',
#  'Kimagure Orange☆Road',
#  'Macross',
#  'Macross: Do You Remember Love?',
#  'Kidou Senshi Gundam I',
#  'Kidou Senshi Gundam II: Ai Senshi-hen',
#  'Kidou Senshi Gundam III: Meguriai Sora-hen',
#  'Oishinbo',
#  'One Piece: Umi no Heso no Daibouken-hen',
#  'Kidou Keisatsu Patlabor the Movie',
#  'Kidou Keisatsu Patlabor 2 the Movie',
#  'Lime-iro Senkitan',
#  'Samurai Girl Real Bout High School',
#  'Shadow Skill: Kurudaryuu Kousatsuhou no Himitsu',
#  ...]

# %%
df_anime['genres'].tolist()
# Out:
# ['Action, Award Winning, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Drama, Mystery, Supernatural',
#  'Action, Adventure, Fantasy',
#  'Sports',
#  'Comedy, Drama, Romance',
#  'Sports',
#  'Action, Drama',
#  'Drama, Mystery, Suspense',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Sports',
#  'Sports',
#  'Comedy, Romance',
#  'Action, Adventure, Comedy, Sci-Fi, Ecchi',
#  'Avant Garde, Drama, Mystery, Sci-Fi, Suspense',
#  'Action, Fantasy, Sci-Fi',
#  'Comedy, Gourmet',
#  'Action, Drama, Sci-Fi',
#  'Action, Avant Garde, Award Winning, Drama, Sci-Fi, Suspense',
#  'Action, Drama, Sci-Fi, Suspense',
#  'Action, Avant Garde, Drama, Sci-Fi, Suspense',
#  'Action, Adventure, Drama, Fantasy, Horror',
#  'Action, Award Winning, Mystery, Sci-Fi, Suspense',
#  'Action, Drama, Romance',
#  'Action, Comedy, Romance',
#  'Drama',
#  'Action, Horror, Sci-Fi',
#  'Adventure, Fantasy, Mystery',
#  'Comedy, Romance, Supernatural',
#  'Comedy, Romance, Supernatural',
#  'Action, Drama, Romance, Supernatural',
#  'Award Winning, Comedy, Drama, Sci-Fi',
#  'Comedy, Drama, Romance',
#  'Action, Sci-Fi',
#  'Action, Adventure, Fantasy, Horror, Sci-Fi',
#  'Adventure, Fantasy, Sci-Fi',
#  'Drama',
#  'Action, Adventure, Drama, Horror, Sci-Fi',
#  'Comedy, Drama, Romance, Sci-Fi, Ecchi',
#  'Action, Romance, Supernatural',
#  'Action, Comedy, Fantasy, Romance',
#  'Drama, Romance',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Action, Drama, Supernatural',
#  'Action, Drama, Supernatural',
#  'Comedy',
#  'Action, Drama, Romance',
#  'Action, Adventure, Sci-Fi',
#  'Action, Fantasy, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Comedy',
#  'Action',
#  'Comedy',
#  'Action, Drama, Sci-Fi',
#  'Action, Comedy, Drama',
#  'Action, Comedy, Drama',
#  'Comedy, Fantasy, Romance, Ecchi',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Romance, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Drama, Romance, Sci-Fi',
#  'Action, Adventure, Drama, Romance, Sci-Fi',
#  'Action, Drama, Romance, Sci-Fi',
#  'Action, Comedy, Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Award Winning, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Action, Award Winning, Drama, Romance, Sci-Fi',
#  'Action, Drama, Romance, Sci-Fi',
#  'Action, Adventure, Award Winning, Drama, Romance, Sci-Fi',
#  'Action, Drama, Romance, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Fantasy, Girls Love',
#  'Comedy, Drama, Fantasy',
#  'Drama, Romance',
#  'Drama, Romance, Supernatural',
#  'Comedy, Drama, Romance',
#  'Adventure, Comedy, Fantasy, Romance',
#  'Adventure, Drama, Horror, Romance, Supernatural',
#  'Comedy, Romance',
#  'Drama, Romance',
#  'Adventure, Comedy, Fantasy, Sci-Fi',
#  'Adventure, Comedy, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Comedy, Drama, Gourmet',
#  'Adventure, Comedy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi, Ecchi',
#  'Action, Romance, Sci-Fi',
#  'Comedy',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy, Romance',
#  'Adventure, Comedy, Fantasy, Romance',
#  'Adventure, Comedy, Fantasy',
#  'Comedy, Drama, Romance',
#  'Drama, Romance, Supernatural',
#  'Action, Adventure, Award Winning, Drama, Fantasy',
#  'Comedy, Drama, Romance, Supernatural',
#  'Action, Adventure, Fantasy, Romance',
#  'Adventure, Drama, Fantasy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance',
#  'Action, Comedy, Fantasy, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Fantasy',
#  'Action, Adventure, Comedy, Drama, Supernatural',
#  'Action, Adventure, Comedy, Drama, Supernatural',
#  'Action, Mystery, Supernatural',
#  'Comedy, Romance, Ecchi',
#  'Action, Drama, Sci-Fi, Suspense',
#  'Comedy, Drama, Supernatural',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Sci-Fi',
#  'Action, Drama, Mystery, Romance',
#  'Drama, Girls Love, Supernatural',
#  'Drama, Romance, Supernatural',
#  'Comedy, Drama, Romance',
#  'Comedy, Drama, Romance, Sci-Fi, Ecchi',
#  'Drama, Romance',
#  'Drama, Romance',
#  'Boys Love, Drama, Mystery, Supernatural',
#  'Action, Drama, Horror, Mystery, Supernatural',
#  'Action, Comedy, Girls Love, Sci-Fi, Ecchi',
#  'Action, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Supernatural',
#  'Action, Drama, Fantasy, Mystery',
#  'Action, Drama, Fantasy, Mystery',
#  'Action, Comedy, Fantasy, Romance, Ecchi',
#  'Drama, Girls Love',
#  'Action, Adventure, Fantasy, Horror, Sci-Fi',
#  'Adventure, Drama, Fantasy, Sci-Fi',
#  'Action, Comedy',
#  'Comedy, Fantasy, Romance',
#  'Adventure, Comedy, Fantasy',
#  'Action, Adventure, Award Winning, Fantasy',
#  'Action, Award Winning, Drama, Mystery, Romance, Sci-Fi, Suspense',
#  'Action, Sci-Fi',
#  'Action, Adventure, Drama, Fantasy, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Action, Horror, Mystery, Romance, Supernatural',
#  'Sports',
#  'Adventure, Drama, Fantasy',
#  'Mystery, Supernatural',
#  'Action, Drama, Supernatural, Ecchi',
#  'Action, Adventure, Romance, Sci-Fi',
#  'Adventure, Romance',
#  'Action, Adventure, Drama, Fantasy, Romance',
#  'Comedy, Fantasy, Romance',
#  'Comedy, Fantasy, Romance',
#  'Action, Sci-Fi, Ecchi',
#  'Action, Sci-Fi, Ecchi',
#  'Action, Adventure, Fantasy, Romance',
#  'Sports',
#  'Action, Sci-Fi',
#  'Action, Drama',
#  'Action, Drama',
#  'Action, Drama',
#  'Comedy, Mystery, Supernatural, Hentai',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Romance',
#  'Adventure, Comedy, Romance',
#  'Comedy, Drama, Romance, Ecchi',
#  'Action, Adventure, Sci-Fi',
#  'Drama, Romance, Sci-Fi',
#  'Comedy, Drama, Sci-Fi',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Action, Mystery, Suspense',
#  'Adventure, Award Winning, Fantasy',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance, Ecchi',
#  'Action, Adventure, Drama, Fantasy, Mystery',
#  'Adventure, Fantasy, Hentai',
#  'Action, Comedy, Ecchi',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Drama, Fantasy, Romance',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Mystery, Sci-Fi',
#  'Action, Adventure, Comedy, Drama, Sci-Fi',
#  'Action, Comedy, Romance, Ecchi',
#  'Hentai',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Comedy, Hentai',
#  'Comedy, Hentai',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama, Hentai',
#  'Action, Comedy, Romance, Sci-Fi',
#  'Action, Award Winning, Drama, Sci-Fi',
#  'Horror, Hentai',
#  'Action, Comedy, Sci-Fi, Hentai',
#  'Action, Adventure, Comedy, Mystery, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Drama, Horror, Romance, Suspense',
#  'Action, Avant Garde, Comedy, Sci-Fi, Suspense',
#  'Horror, Mystery, Supernatural, Suspense',
#  'Comedy',
#  'Action, Comedy',
#  'Action, Comedy, Supernatural',
#  'Adventure, Comedy, Drama, Romance',
#  'Comedy, Sci-Fi',
#  'Adventure, Sports',
#  'Adventure, Comedy, Mystery',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Romance, Sci-Fi',
#  'Action, Adventure',
#  'Award Winning, Drama, Mystery, Sci-Fi, Supernatural, Suspense',
#  'Slice of Life',
#  'Comedy, Fantasy, Romance, Ecchi',
#  'Action, Comedy',
#  'Boys Love, Comedy',
#  'Mystery',
#  'Comedy',
#  'Action, Adventure, Comedy, Fantasy, Romance',
#  'Fantasy, Romance',
#  'Comedy, Romance, Ecchi',
#  'Action, Adventure, Fantasy, Romance',
#  'Action, Adventure, Comedy, Supernatural',
#  'Adventure, Comedy, Fantasy',
#  'Drama, Mystery, Supernatural',
#  'Comedy',
#  'Comedy',
#  'Award Winning, Comedy, Slice of Life',
#  'Action, Award Winning, Drama, Romance, Sci-Fi',
#  'Action, Ecchi',
#  'Drama, Horror',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Action, Drama, Romance, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Adventure, Comedy, Ecchi',
#  'Action, Adventure, Supernatural',
#  'Action, Horror, Supernatural',
#  'Action, Adventure, Sci-Fi',
#  'Action, Drama, Mystery',
#  'Fantasy, Slice of Life',
#  'Action, Sci-Fi',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Comedy, Drama, Romance, Sci-Fi, Ecchi',
#  'Action, Comedy, Sci-Fi',
#  'Horror, Mystery, Supernatural',
#  'Adventure, Comedy, Fantasy',
#  'Comedy, Romance',
#  'Action, Drama, Mystery, Romance',
#  'Drama',
#  'Action, Drama, Romance',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Sports',
#  'Adventure, Comedy, Sports',
#  'Comedy, Drama',
#  'Action, Romance, Sci-Fi',
#  'Comedy, Drama, Romance, Supernatural',
#  'Drama, Sports',
#  'Comedy, Fantasy, Sci-Fi',
#  'Adventure, Drama, Sci-Fi',
#  'Adventure, Drama, Sci-Fi',
#  'Action, Adventure, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Ecchi',
#  'Adventure, Comedy, Fantasy',
#  'Mystery',
#  'Action, Fantasy, Horror, Romance',
#  'Action, Adventure, Comedy, Mystery',
#  'Adventure, Drama, Sci-Fi',
#  'Comedy, Supernatural',
#  'Comedy, Romance, Supernatural',
#  'Action, Comedy, Ecchi',
#  'Award Winning, Comedy, Fantasy, Ecchi',
#  'Comedy, Fantasy',
#  'Drama, Fantasy, Mystery, Sci-Fi',
#  'Comedy',
#  'Comedy, Supernatural',
#  'Drama, Romance, Sports',
#  'Drama, Sports',
#  'Drama, Romance, Sports',
#  'Drama, Sports',
#  'Action, Drama, Fantasy, Romance',
#  'Comedy, Girls Love, Hentai',
#  'Action, Fantasy',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Comedy, Fantasy, Romance, Ecchi',
#  'Action, Drama, Hentai',
#  'Action, Comedy, Sci-Fi, Ecchi',
#  'Drama, Romance',
#  'Avant Garde, Award Winning, Drama, Mystery, Supernatural, Suspense',
#  'Action, Comedy, Sci-Fi',
#  'Drama, Romance',
#  'Horror, Mystery, Supernatural',
#  'Comedy, Fantasy',
#  'Drama, Romance',
#  'Award Winning, Drama, Romance, Sci-Fi',
#  'Comedy, Romance, Supernatural, Ecchi',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Award Winning, Comedy, Drama, Sci-Fi',
#  'Comedy, Drama, Romance',
#  'Comedy, Mystery, Supernatural',
#  'Drama, Fantasy',
#  'Comedy, Romance, Ecchi',
#  'Drama, Romance',
#  'Avant Garde, Award Winning, Drama, Mystery, Sci-Fi, Supernatural, Suspense',
#  'Action',
#  'Drama, Mystery',
#  'Drama, Sci-Fi',
#  'Comedy, Romance, Supernatural',
#  'Drama, Sci-Fi, Supernatural',
#  'Drama, Romance',
#  'Drama, Romance',
#  'Action, Adventure, Fantasy, Sci-Fi',
#  'Comedy, Fantasy',
#  'Drama, Fantasy, Ecchi',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy, Sci-Fi, Ecchi',
#  'Action, Drama, Fantasy, Romance',
#  'Action, Fantasy, Romance',
#  'Comedy, Supernatural, Ecchi',
#  'Drama, Romance, Sci-Fi',
#  'Sports',
#  'Adventure, Drama, Fantasy, Supernatural',
#  'Drama, Romance',
#  'Drama, Romance',
#  'Drama, Romance',
#  'Mystery',
#  'Boys Love, Comedy, Mystery',
#  'Action, Adventure, Comedy, Sci-Fi, Ecchi',
#  'Comedy, Fantasy',
#  'Hentai',
#  'Avant Garde, Drama, Horror, Mystery, Supernatural, Suspense',
#  'Action, Adventure, Comedy, Mystery, Sci-Fi, Ecchi',
#  'Award Winning, Comedy, Drama',
#  'Award Winning, Comedy, Drama, Romance',
#  'Adventure, Comedy, Sci-Fi',
#  'Action, Comedy, Romance, Sci-Fi, Ecchi',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Drama, Horror, Suspense',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Adventure, Fantasy, Romance',
#  'Adventure, Fantasy, Romance',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Sci-Fi',
#  'Action, Drama, Horror, Sci-Fi, Suspense',
#  'Drama, Sci-Fi, Suspense',
#  'Comedy, Romance, Sports',
#  'Drama, Fantasy, Mystery',
#  'Sports',
#  'Action, Fantasy, Sci-Fi',
#  'Drama, Romance, Sports',
#  'Adventure, Fantasy',
#  'Action, Supernatural',
#  'Action, Adventure, Fantasy, Romance',
#  'Comedy, Drama, Romance',
#  'Action, Drama, Horror, Sci-Fi, Suspense',
#  'Action, Romance, Sci-Fi',
#  'Action, Romance, Sci-Fi',
#  'Action, Romance, Sci-Fi',
#  'Action, Romance, Sci-Fi',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Drama, Romance',
#  'Adventure, Comedy, Fantasy',
#  'Comedy, Romance, Ecchi',
#  'Action, Adventure, Fantasy, Ecchi',
#  'Award Winning, Horror, Supernatural',
#  'Sci-Fi, Sports',
#  'Comedy, Drama, Mystery',
#  'Action, Adventure, Drama, Fantasy, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Comedy, Ecchi',
#  'Action, Horror, Sci-Fi',
#  'Award Winning, Comedy',
#  'Action, Adventure, Award Winning, Comedy, Drama, Romance',
#  'Action, Fantasy',
#  'Adventure, Comedy',
#  'Action, Adventure, Comedy, Supernatural',
#  'Adventure, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi',
#  'Boys Love, Comedy, Sports',
#  'Action, Adventure, Comedy, Fantasy',
#  'Comedy, Drama, Supernatural',
#  'Comedy, Drama, Supernatural',
#  'Comedy, Drama',
#  'Action, Adventure, Award Winning, Drama, Fantasy',
#  'Adventure, Award Winning, Drama, Fantasy, Romance',
#  'Action, Adventure, Sci-Fi',
#  'Award Winning, Drama, Romance, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy, Drama, Fantasy',
#  'Avant Garde, Award Winning, Drama, Horror, Suspense',
#  'Action, Drama',
#  'Adventure, Drama, Fantasy',
#  'Award Winning, Drama, Fantasy, Mystery, Suspense',
#  'Avant Garde, Drama, Fantasy, Girls Love',
#  'Action, Adventure, Fantasy',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Drama, Girls Love',
#  'Adventure, Comedy, Fantasy, Romance',
#  'Action, Drama',
#  'Action, Drama',
#  'Action, Drama, Romance, Supernatural',
#  'Action, Adventure, Fantasy, Romance',
#  'Action, Adventure, Fantasy, Romance',
#  'Action, Adventure, Fantasy, Romance',
#  'Action, Adventure, Fantasy, Romance',
#  'Comedy, Fantasy',
#  'Adventure, Fantasy, Mystery, Romance, Sci-Fi, Suspense',
#  'Comedy',
#  'Adventure, Mystery, Slice of Life, Supernatural',
#  'Comedy, Sci-Fi, Ecchi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Award Winning, Mystery, Sci-Fi',
#  'Action, Award Winning, Mystery, Sci-Fi, Suspense',
#  'Comedy, Romance, Supernatural',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Drama, Romance',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Drama, Romance, Sci-Fi',
#  'Drama, Sci-Fi',
#  'Drama, Romance, Sports, Supernatural',
#  'Sci-Fi, Slice of Life',
#  'Action, Fantasy, Romance, Sci-Fi',
#  'Action, Adventure, Supernatural',
#  'Action, Adventure, Fantasy',
#  'Action, Comedy, Fantasy',
#  'Action, Drama, Sci-Fi',
#  'Adventure, Supernatural',
#  'Comedy, Slice of Life',
#  'Adventure, Drama, Fantasy',
#  'Comedy, Fantasy, Romance, Ecchi',
#  'Slice of Life',
#  'Award Winning, Slice of Life, Supernatural',
#  'Comedy',
#  'Action, Sci-Fi',
#  'Action, Mystery, Romance, Sci-Fi',
#  'Adventure, Comedy, Fantasy, Ecchi',
#  'Adventure, Drama, Fantasy',
#  'Adventure, Fantasy, Girls Love, Mystery, Ecchi',
#  'Action, Adventure, Sci-Fi',
#  'Adventure, Horror, Romance, Supernatural',
#  'Adventure, Comedy, Fantasy',
#  'Action, Adventure, Comedy, Fantasy',
#  'Adventure, Drama, Fantasy',
#  'Action, Adventure, Drama, Romance',
#  'Comedy, Fantasy',
#  'Drama, Romance',
#  'Boys Love, Comedy',
#  'Adventure, Comedy',
#  'Comedy, Drama, Romance',
#  'Comedy, Drama, Romance',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Award Winning, Comedy, Drama, Fantasy',
#  'Adventure, Award Winning, Fantasy',
#  'Drama, Horror, Romance, Supernatural',
#  'Action, Adventure, Fantasy, Supernatural',
#  'Comedy, Sci-Fi',
#  'Comedy, Romance',
#  'Fantasy',
#  'Comedy, Romance',
#  'Romance',
#  'Romance',
#  'Adventure, Drama, Romance, Sci-Fi',
#  'Adventure, Award Winning, Supernatural',
#  'Comedy, Drama, Romance',
#  'Adventure, Drama, Fantasy',
#  'Drama, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Adventure, Award Winning, Comedy, Fantasy',
#  'Drama, Romance, Sci-Fi',
#  'Romance',
#  'Drama, Romance',
#  'Romance',
#  'Comedy',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Comedy, Romance, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Drama, Fantasy, Horror, Romance, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Drama, Romance, Supernatural',
#  'Drama, Romance, Supernatural',
#  'Action, Drama, Romance, Sci-Fi',
#  'Action, Comedy, Fantasy',
#  'Sports',
#  'Action, Adventure, Comedy, Fantasy',
#  'Boys Love, Fantasy, Horror, Mystery',
#  'Action, Adventure, Comedy, Drama, Romance',
#  'Comedy, Girls Love, Sci-Fi',
#  'Drama, Romance, Sci-Fi',
#  'Comedy, Romance, Sci-Fi',
#  'Sports',
#  'Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Comedy, Romance, Sci-Fi',
#  'Comedy, Fantasy, Sci-Fi, Ecchi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Action, Award Winning, Drama, Romance, Suspense',
#  'Action, Romance, Sci-Fi',
#  'Adventure, Award Winning, Drama, Fantasy',
#  'Action, Adventure, Comedy, Drama, Romance, Sci-Fi',
#  'Award Winning, Fantasy, Sci-Fi',
#  'Comedy, Fantasy, Romance',
#  'Fantasy',
#  'Drama',
#  'Comedy, Sci-Fi, Ecchi',
#  'Comedy, Gourmet',
#  'Comedy, Ecchi',
#  'Action, Comedy',
#  'Adventure, Drama, Sci-Fi',
#  'Drama, Romance',
#  'Horror, Mystery, Supernatural, Suspense',
#  'Drama, Romance',
#  'Comedy, Fantasy, Romance, Ecchi',
#  'Action, Adventure, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance, Supernatural, Ecchi',
#  'Adventure, Fantasy',
#  'Award Winning, Drama, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Drama, Fantasy, Mystery',
#  'Comedy, Romance',
#  'Adventure, Award Winning, Drama, Fantasy',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Comedy, Supernatural',
#  'Boys Love, Drama, Supernatural',
#  'Avant Garde, Award Winning, Comedy',
#  'Action, Adventure, Comedy, Fantasy, Supernatural',
#  'Action, Comedy',
#  'Comedy, Drama, Romance',
#  'Comedy, Fantasy, Romance',
#  'Adventure, Comedy',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Sci-Fi',
#  'Drama, Romance, Sci-Fi',
#  'Comedy, Drama, Supernatural, Ecchi',
#  'Sci-Fi, Slice of Life',
#  'Comedy, Romance',
#  'Adventure, Fantasy, Supernatural',
#  'Romance',
#  'Comedy, Fantasy',
#  'Drama, Fantasy',
#  'Action, Adventure, Fantasy, Horror, Romance',
#  'Action, Adventure, Fantasy, Horror',
#  'Action, Sci-Fi, Supernatural, Suspense',
#  'Drama, Fantasy, Horror, Mystery',
#  'Action, Horror, Mystery, Supernatural',
#  'Drama, Romance, Sci-Fi',
#  'Adventure, Comedy, Romance',
#  'Action, Comedy, Ecchi',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Comedy, Fantasy, Romance',
#  'Sports',
#  'Comedy, Fantasy, Romance, Sci-Fi',
#  'Comedy, Fantasy, Romance, Sci-Fi',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Adventure, Award Winning, Drama, Fantasy, Romance',
#  'Drama, Romance',
#  'Action, Adventure, Comedy, Drama',
#  'Action, Adventure, Comedy, Drama',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Romance, Ecchi',
#  'Romance, Ecchi',
#  'Comedy, Drama, Romance',
#  nan,
#  'Comedy, Supernatural',
#  'Adventure, Drama, Fantasy, Romance, Supernatural',
#  'Comedy, Drama, Romance, Sci-Fi',
#  'Comedy, Romance, Ecchi',
#  'Action, Comedy',
#  'Comedy, Hentai',
#  'Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Comedy, Drama, Romance, Supernatural',
#  'Suspense',
#  'Comedy',
#  'Comedy, Fantasy, Romance',
#  'Drama, Romance',
#  'Adventure, Comedy, Drama, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Comedy, Drama, Girls Love',
#  'Comedy, Romance, Sci-Fi, Ecchi',
#  'Comedy, Romance',
#  'Drama, Romance',
#  'Drama',
#  'Comedy',
#  'Drama, Supernatural',
#  'Drama, Romance',
#  'Drama, Romance',
#  'Action, Adventure, Drama, Fantasy',
#  'Action, Adventure, Drama, Fantasy',
#  'Comedy, Sci-Fi',
#  'Comedy, Fantasy, Romance',
#  'Comedy, Fantasy, Romance',
#  'Fantasy, Romance',
#  'Drama, Romance, Sci-Fi',
#  'Comedy, Sci-Fi',
#  'Romance, Sci-Fi',
#  'Drama, Fantasy',
#  'Drama, Fantasy',
#  'Action, Drama, Horror, Supernatural',
#  'Comedy, Romance, Sports',
#  'Hentai',
#  'Action, Comedy, Drama, Mystery, Sci-Fi, Ecchi',
#  'Comedy, Drama, Romance',
#  'Comedy, Romance',
#  'Comedy, Romance, Sci-Fi',
#  'Drama, Romance, Supernatural',
#  'Adventure, Comedy, Sci-Fi',
#  'Comedy, Drama',
#  'Comedy, Drama',
#  'Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy, Sci-Fi, Slice of Life',
#  'Comedy, Romance',
#  'Drama, Sci-Fi',
#  'Action, Adventure, Comedy',
#  'Drama, Romance, Supernatural',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance, Ecchi',
#  'Comedy, Drama, Romance, Ecchi',
#  'Boys Love, Drama, Sci-Fi, Erotica',
#  'Drama, Mystery, Romance',
#  'Comedy, Romance',
#  'Drama, Romance',
#  'Boys Love, Drama, Horror, Hentai',
#  'Drama, Romance',
#  'Comedy',
#  'Comedy, Romance, Sports',
#  'Boys Love, Drama',
#  'Adventure, Drama, Sci-Fi',
#  'Action, Fantasy, Horror, Sci-Fi',
#  'Boys Love, Drama, Erotica',
#  'Boys Love, Drama, Erotica',
#  'Boys Love, Drama, Hentai',
#  'Action, Adventure, Comedy, Fantasy',
#  'Romance',
#  'Boys Love, Comedy, Drama, Hentai',
#  'Drama, Romance',
#  'Comedy, Romance, Sci-Fi',
#  'Boys Love, Comedy, Drama, Erotica',
#  'Boys Love, Drama, Erotica',
#  'Romance',
#  'Comedy',
#  'Slice of Life',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Boys Love, Drama',
#  'Hentai',
#  'Adventure, Drama, Fantasy',
#  'Boys Love, Hentai',
#  'Drama, Romance',
#  'Adventure, Drama, Fantasy',
#  'Action, Drama, Romance, Sci-Fi',
#  'Award Winning, Comedy, Drama',
#  'Action, Drama, Supernatural',
#  'Adventure, Comedy',
#  'Action, Adventure, Drama, Supernatural',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi, Sports',
#  'Adventure, Comedy, Sci-Fi',
#  'Comedy, Drama, Sci-Fi',
#  'Action, Comedy, Sci-Fi, Ecchi',
#  'Action, Comedy, Sci-Fi, Ecchi',
#  'Drama, Sci-Fi',
#  'Drama, Fantasy',
#  'Adventure, Comedy, Sci-Fi, Ecchi',
#  'Comedy, Drama, Romance',
#  'Action, Horror, Supernatural',
#  'Adventure, Comedy, Mystery',
#  'Adventure, Comedy, Mystery',
#  'Adventure, Comedy, Mystery',
#  'Drama, Supernatural',
#  'Comedy, Ecchi',
#  'Comedy, Drama, Sci-Fi',
#  'Comedy, Fantasy',
#  'Comedy, Ecchi',
#  'Drama, Supernatural',
#  'Mystery, Sci-Fi, Suspense',
#  'Action, Adventure, Drama, Fantasy',
#  'Adventure, Comedy',
#  'Comedy, Drama, Mystery, Supernatural',
#  'Drama, Girls Love',
#  'Adventure, Comedy, Fantasy',
#  'Comedy, Romance, Ecchi',
#  'Drama',
#  'Slice of Life',
#  'Sci-Fi, Slice of Life',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Drama, Fantasy, Romance',
#  'Action, Adventure, Comedy, Fantasy, Romance, Ecchi',
#  'Comedy, Drama, Sci-Fi',
#  'Comedy, Drama, Romance, Ecchi',
#  'Adventure, Drama, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Comedy, Sports',
#  'Sports',
#  'Comedy, Sci-Fi, Ecchi',
#  'Comedy, Romance, Sci-Fi',
#  'Comedy, Drama, Romance, Ecchi',
#  'Romance',
#  'Drama, Sci-Fi',
#  'Action, Drama',
#  'Action, Drama',
#  'Hentai',
#  'Comedy, Romance, Ecchi',
#  'Adventure, Drama',
#  'Hentai',
#  'Hentai',
#  'Hentai',
#  'Comedy, Fantasy',
#  'Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Action, Adventure, Supernatural',
#  'Drama, Romance',
#  'Comedy, Drama, Romance',
#  'Comedy, Ecchi',
#  'Drama, Horror, Sci-Fi, Suspense',
#  'Action, Fantasy',
#  'Comedy, Romance, Sci-Fi',
#  'Comedy, Ecchi',
#  'Action, Horror',
#  'Adventure, Supernatural',
#  'Action, Adventure, Fantasy',
#  'Comedy, Romance',
#  'Action, Sci-Fi',
#  'Award Winning, Comedy, Mystery, Sci-Fi',
#  'Boys Love, Comedy, Drama',
#  'Action, Comedy',
#  'Comedy, Drama, Romance',
#  'Comedy, Romance',
#  'Action, Adventure, Comedy, Romance, Sci-Fi',
#  'Drama, Girls Love',
#  'Action, Drama, Fantasy, Sci-Fi',
#  'Sports, Ecchi',
#  'Drama, Romance, Sci-Fi',
#  'Adventure, Comedy, Drama, Fantasy',
#  'Action, Comedy, Fantasy',
#  'Comedy, Drama, Mystery, Supernatural',
#  'Comedy, Ecchi',
#  'Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy, Supernatural',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Drama, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Adventure, Avant Garde, Award Winning, Comedy, Romance',
#  'Action, Adventure, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Romance, Sci-Fi',
#  'Drama, Fantasy, Girls Love, Sci-Fi',
#  'Comedy, Romance, Supernatural',
#  'Comedy, Romance, Ecchi',
#  'Action, Supernatural',
#  'Action, Supernatural',
#  'Action, Fantasy',
#  'Avant Garde, Drama, Fantasy',
#  'Comedy, Romance, Supernatural, Ecchi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#  'Comedy',
#  'Comedy, Fantasy',
#  'Adventure, Sci-Fi',
#  'Adventure, Comedy',
#  'Adventure, Supernatural',
#  'Adventure',
#  'Action, Ecchi',
#  'Comedy, Ecchi',
#  'Adventure, Drama',
#  'Action, Horror, Mystery, Supernatural',
#  'Action',
#  'Action, Comedy, Sci-Fi',
#  'Drama, Romance, Sci-Fi',
#  'Comedy',
#  'Comedy, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Drama, Fantasy, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Comedy, Sci-Fi, Slice of Life',
#  'Comedy, Fantasy',
#  'Horror, Mystery, Suspense',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Comedy, Romance, Supernatural, Ecchi',
#  'Comedy, Ecchi',
#  'Comedy, Drama, Fantasy, Mystery, Romance',
#  'Drama, Fantasy, Slice of Life',
#  'Action, Adventure, Sci-Fi',
#  'Action, Award Winning, Comedy, Drama, Sci-Fi',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Action, Adventure, Drama, Mystery, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Adventure, Fantasy, Romance',
#  'Action, Adventure, Sci-Fi',
#  'Adventure, Drama, Romance',
#  'Adventure, Drama, Romance',
#  'Action',
#  'Sci-Fi, Slice of Life',
#  'Drama, Romance',
#  'Comedy, Ecchi',
#  'Comedy, Fantasy, Slice of Life',
#  'Comedy, Ecchi',
#  'Action, Drama, Sci-Fi',
#  'Action, Comedy',
#  'Action, Adventure, Drama, Fantasy, Romance',
#  'Action, Adventure',
#  'Action, Adventure, Sci-Fi',
#  'Supernatural, Hentai',
#  'Adventure, Sci-Fi',
#  'Action, Comedy, Sci-Fi',
#  'Sci-Fi, Slice of Life',
#  'Sci-Fi, Slice of Life',
#  'Action, Boys Love, Sci-Fi, Hentai',
#  'Action, Adventure, Horror, Sci-Fi',
#  'Action, Drama',
#  'Comedy, Sci-Fi',
#  'Comedy, Romance, Ecchi',
#  'Comedy, Ecchi',
#  'Comedy',
#  'Adventure, Comedy, Fantasy, Sci-Fi',
#  'Adventure, Drama, Fantasy',
#  'Adventure, Comedy, Fantasy, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Action, Comedy',
#  nan,
#  'Comedy, Fantasy, Romance',
#  'Action, Comedy, Romance, Ecchi',
#  'Action, Comedy, Sci-Fi',
#  'Comedy, Drama, Romance, Sci-Fi',
#  'Mystery',
#  'Sports',
#  'Adventure, Comedy, Drama, Romance',
#  'Adventure, Comedy, Drama, Romance',
#  'Action, Adventure, Drama, Horror, Mystery, Romance, Supernatural',
#  'Action, Adventure, Drama, Horror, Mystery, Supernatural',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Adventure, Drama',
#  'Action, Award Winning, Comedy, Drama, Sci-Fi',
#  'Comedy, Romance, Supernatural',
#  'Slice of Life',
#  'Adventure, Fantasy, Sci-Fi',
#  'Action, Comedy, Romance, Sci-Fi',
#  'Action, Comedy, Romance, Ecchi',
#  'Comedy, Drama, Romance',
#  'Action, Comedy',
#  'Action, Adventure, Comedy, Supernatural',
#  'Action, Adventure, Comedy, Romance, Supernatural',
#  'Comedy',
#  'Mystery, Supernatural',
#  'Comedy, Fantasy',
#  'Comedy',
#  'Drama, Sci-Fi',
#  'Action, Adventure, Comedy, Fantasy',
#  'Adventure, Comedy, Fantasy',
#  'Action, Boys Love, Drama, Supernatural',
#  'Action, Boys Love, Drama, Supernatural',
#  'Drama, Romance',
#  'Action, Adventure, Comedy, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Fantasy',
#  'Action, Drama',
#  'Adventure, Comedy, Sci-Fi',
#  'Adventure, Horror, Supernatural',
#  'Action, Sci-Fi',
#  'Fantasy',
#  'Drama, Romance',
#  'Award Winning',
#  'Adventure, Fantasy',
#  'Adventure, Drama, Romance',
#  'Action, Adventure, Award Winning, Drama, Fantasy, Romance',
#  'Action, Award Winning, Drama, Sci-Fi',
#  'Adventure, Boys Love, Comedy, Fantasy',
#  'Romance, Supernatural',
#  'Action, Fantasy, Supernatural',
#  'Hentai',
#  'Drama, Romance, Supernatural',
#  'Drama, Romance',
#  'Boys Love, Drama, Sports, Erotica',
#  'Boys Love, Drama, Sports, Erotica',
#  'Action, Drama, Mystery, Supernatural',
#  'Adventure, Drama',
#  'Adventure, Comedy, Fantasy, Ecchi',
#  'Adventure, Comedy, Fantasy',
#  'Drama, Sci-Fi',
#  'Horror, Supernatural',
#  'Award Winning, Drama, Fantasy',
#  'Adventure, Comedy, Sci-Fi',
#  'Action, Adventure, Award Winning, Sci-Fi',
#  'Action, Adventure, Supernatural',
#  'Comedy, Drama, Romance, Ecchi',
#  'Action, Drama, Sci-Fi, Suspense',
#  'Comedy, Drama, Romance',
#  'Action, Comedy, Ecchi',
#  'Adventure, Comedy',
#  'Action, Adventure, Comedy, Sci-Fi',
#  'Comedy, Ecchi',
#  'Action, Comedy',
#  'Adventure, Comedy, Sci-Fi',
#  'Drama, Romance, Sports',
#  'Comedy',
#  'Action, Drama, Fantasy, Romance, Sci-Fi',
#  'Adventure, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Comedy, Romance',
#  'Drama, Romance',
#  'Action, Fantasy',
#  'Action',
#  'Comedy, Fantasy, Ecchi',
#  'Action, Adventure, Fantasy',
#  'Comedy, Gourmet',
#  'Action, Mystery, Romance, Sci-Fi',
#  'Action, Award Winning, Drama, Sci-Fi, Suspense',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Comedy, Drama, Mystery, Sci-Fi, Ecchi',
#  'Drama',
#  'Drama, Romance',
#  'Adventure, Horror, Mystery',
#  'Action, Adventure, Comedy, Romance, Sci-Fi',
#  'Comedy, Drama, Romance',
#  'Action, Romance, Sci-Fi',
#  'Action, Romance, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Action, Drama, Sci-Fi',
#  'Action, Adventure, Drama, Sci-Fi',
#  'Comedy, Gourmet, Slice of Life',
#  'Action, Adventure, Fantasy',
#  'Action, Drama',
#  'Action, Award Winning, Drama, Mystery, Sci-Fi',
#  'Drama, Supernatural, Ecchi',
#  'Action, Comedy, Fantasy',
#  'Action, Adventure, Drama, Fantasy',
#  ...]

# %%
df_anime['aired_to'].tolist()
# Out:
# ['1999-04-24 00:00:00+00:00',
#  nan,
#  '1998-09-30 00:00:00+00:00',
#  '2002-12-25 00:00:00+00:00',
#  '2005-09-29 00:00:00+00:00',
#  '2008-03-19 00:00:00+00:00',
#  '2005-09-27 00:00:00+00:00',
#  '2003-09-10 00:00:00+00:00',
#  '2006-02-18 00:00:00+00:00',
#  '2005-09-28 00:00:00+00:00',
#  '2007-02-08 00:00:00+00:00',
#  nan,
#  '2005-03-23 00:00:00+00:00',
#  '2004-12-15 00:00:00+00:00',
#  '2005-03-29 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2003-09-25 00:00:00+00:00',
#  '2005-10-28 00:00:00+00:00',
#  '2006-03-14 00:00:00+00:00',
#  '2005-04-01 00:00:00+00:00',
#  '1996-03-27 00:00:00+00:00',
#  nan,
#  nan,
#  '1998-04-01 00:00:00+00:00',
#  nan,
#  '1999-09-22 00:00:00+00:00',
#  '1998-09-08 00:00:00+00:00',
#  nan,
#  nan,
#  '2002-09-26 00:00:00+00:00',
#  '1994-05-17 00:00:00+00:00',
#  '2005-07-08 00:00:00+00:00',
#  '2000-08-25 00:00:00+00:00',
#  '2001-09-23 00:00:00+00:00',
#  '2002-09-26 00:00:00+00:00',
#  nan,
#  '1999-10-11 00:00:00+00:00',
#  '2003-12-25 00:00:00+00:00',
#  '2005-03-31 00:00:00+00:00',
#  '2000-03-31 00:00:00+00:00',
#  '2002-09-25 00:00:00+00:00',
#  '2004-06-10 00:00:00+00:00',
#  '2003-09-25 00:00:00+00:00',
#  '2003-12-27 00:00:00+00:00',
#  '2004-09-26 00:00:00+00:00',
#  '2004-12-24 00:00:00+00:00',
#  '2006-01-27 00:00:00+00:00',
#  '2002-10-01 00:00:00+00:00',
#  '2005-09-21 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  '2002-06-18 00:00:00+00:00',
#  '2003-11-18 00:00:00+00:00',
#  '2005-10-20 00:00:00+00:00',
#  '2005-05-14 00:00:00+00:00',
#  '2004-12-27 00:00:00+00:00',
#  '2004-12-26 00:00:00+00:00',
#  '2005-12-25 00:00:00+00:00',
#  '2006-01-06 00:00:00+00:00',
#  '1980-01-26 00:00:00+00:00',
#  '1999-07-25 00:00:00+00:00',
#  '1989-08-25 00:00:00+00:00',
#  nan,
#  '1992-09-24 00:00:00+00:00',
#  '1986-02-22 00:00:00+00:00',
#  '1987-01-31 00:00:00+00:00',
#  nan,
#  nan,
#  '1994-03-25 00:00:00+00:00',
#  '1996-03-29 00:00:00+00:00',
#  '1997-07-25 00:00:00+00:00',
#  '1996-12-28 00:00:00+00:00',
#  '2003-09-27 00:00:00+00:00',
#  '2005-10-01 00:00:00+00:00',
#  '2000-04-14 00:00:00+00:00',
#  '1995-03-31 00:00:00+00:00',
#  '2003-09-30 00:00:00+00:00',
#  '2005-04-01 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  '2001-06-27 00:00:00+00:00',
#  '2005-03-25 00:00:00+00:00',
#  '2004-10-09 00:00:00+00:00',
#  '1995-06-30 00:00:00+00:00',
#  '2000-09-28 00:00:00+00:00',
#  '2000-07-04 00:00:00+00:00',
#  '1997-08-31 00:00:00+00:00',
#  '2002-08-14 00:00:00+00:00',
#  '2004-04-28 00:00:00+00:00',
#  '2004-09-15 00:00:00+00:00',
#  '1998-09-13 00:00:00+00:00',
#  '2000-10-20 00:00:00+00:00',
#  '2004-03-02 00:00:00+00:00',
#  '2003-09-25 00:00:00+00:00',
#  '2004-03-26 00:00:00+00:00',
#  '1998-03-26 00:00:00+00:00',
#  '1996-03-29 00:00:00+00:00',
#  '1996-01-25 00:00:00+00:00',
#  '1997-10-25 00:00:00+00:00',
#  '2004-12-26 00:00:00+00:00',
#  '2001-12-27 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2003-03-29 00:00:00+00:00',
#  '1996-03-28 00:00:00+00:00',
#  '2002-06-25 00:00:00+00:00',
#  '2004-12-30 00:00:00+00:00',
#  '2005-06-30 00:00:00+00:00',
#  '2000-09-18 00:00:00+00:00',
#  '2003-01-08 00:00:00+00:00',
#  '2001-03-27 00:00:00+00:00',
#  '2004-03-25 00:00:00+00:00',
#  '2004-09-24 00:00:00+00:00',
#  '2003-09-20 00:00:00+00:00',
#  '2003-09-28 00:00:00+00:00',
#  '2004-02-19 00:00:00+00:00',
#  '2003-03-26 00:00:00+00:00',
#  '2001-03-31 00:00:00+00:00',
#  '2002-04-17 00:00:00+00:00',
#  '2003-04-16 00:00:00+00:00',
#  '2004-08-18 00:00:00+00:00',
#  '2005-03-24 00:00:00+00:00',
#  '2000-01-29 00:00:00+00:00',
#  '2004-12-18 00:00:00+00:00',
#  '2002-03-28 00:00:00+00:00',
#  '1999-03-26 00:00:00+00:00',
#  '2004-06-18 00:00:00+00:00',
#  '2004-01-04 00:00:00+00:00',
#  '2004-04-05 00:00:00+00:00',
#  '2005-06-30 00:00:00+00:00',
#  '2006-09-23 00:00:00+00:00',
#  '2004-09-25 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  '2003-08-30 00:00:00+00:00',
#  '2002-09-25 00:00:00+00:00',
#  nan,
#  '2002-03-27 00:00:00+00:00',
#  '2005-06-30 00:00:00+00:00',
#  '2004-04-01 00:00:00+00:00',
#  '2004-09-22 00:00:00+00:00',
#  '2000-01-20 00:00:00+00:00',
#  '2004-03-24 00:00:00+00:00',
#  '2002-09-29 00:00:00+00:00',
#  '1999-09-25 00:00:00+00:00',
#  nan,
#  '2002-09-11 00:00:00+00:00',
#  '2004-12-25 00:00:00+00:00',
#  '2003-10-07 00:00:00+00:00',
#  '2001-12-26 00:00:00+00:00',
#  '2003-12-26 00:00:00+00:00',
#  '1996-03-23 00:00:00+00:00',
#  '2000-09-26 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2004-09-17 00:00:00+00:00',
#  '2002-09-24 00:00:00+00:00',
#  '2003-12-26 00:00:00+00:00',
#  '2005-10-15 00:00:00+00:00',
#  '2003-11-11 00:00:00+00:00',
#  nan,
#  '2000-12-19 00:00:00+00:00',
#  '2002-01-18 00:00:00+00:00',
#  '1996-09-24 00:00:00+00:00',
#  '2003-02-03 00:00:00+00:00',
#  '2005-03-24 00:00:00+00:00',
#  '1998-12-06 00:00:00+00:00',
#  '2000-01-21 00:00:00+00:00',
#  nan,
#  '1999-03-25 00:00:00+00:00',
#  '2000-09-27 00:00:00+00:00',
#  '2002-03-27 00:00:00+00:00',
#  nan,
#  nan,
#  '2004-04-06 00:00:00+00:00',
#  '2004-10-20 00:00:00+00:00',
#  '2002-03-28 00:00:00+00:00',
#  '2003-10-14 00:00:00+00:00',
#  '2002-12-22 00:00:00+00:00',
#  '2005-09-30 00:00:00+00:00',
#  nan,
#  '2003-03-30 00:00:00+00:00',
#  '1992-08-28 00:00:00+00:00',
#  '2003-07-29 00:00:00+00:00',
#  '2000-11-25 00:00:00+00:00',
#  '2004-03-26 00:00:00+00:00',
#  '2005-03-19 00:00:00+00:00',
#  '1998-09-30 00:00:00+00:00',
#  '1991-11-23 00:00:00+00:00',
#  '2002-02-06 00:00:00+00:00',
#  '2004-03-16 00:00:00+00:00',
#  '1992-09-25 00:00:00+00:00',
#  '2001-12-21 00:00:00+00:00',
#  nan,
#  '1998-04-24 00:00:00+00:00',
#  '1999-04-23 00:00:00+00:00',
#  '2000-10-25 00:00:00+00:00',
#  nan,
#  '1995-11-22 00:00:00+00:00',
#  '1997-03-25 00:00:00+00:00',
#  nan,
#  '2000-09-25 00:00:00+00:00',
#  '2001-06-25 00:00:00+00:00',
#  '2004-03-28 00:00:00+00:00',
#  '1989-04-12 00:00:00+00:00',
#  '1997-11-19 00:00:00+00:00',
#  '2004-10-17 00:00:00+00:00',
#  '2001-03-16 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2004-09-25 00:00:00+00:00',
#  '2003-10-01 00:00:00+00:00',
#  '2002-12-26 00:00:00+00:00',
#  '2000-03-21 00:00:00+00:00',
#  '2002-02-26 00:00:00+00:00',
#  '2004-09-25 00:00:00+00:00',
#  nan,
#  '2003-09-23 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '1998-07-10 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2004-12-27 00:00:00+00:00',
#  '2004-09-27 00:00:00+00:00',
#  '2004-03-31 00:00:00+00:00',
#  '2001-01-10 00:00:00+00:00',
#  '2005-05-15 00:00:00+00:00',
#  '2000-09-17 00:00:00+00:00',
#  '2002-09-28 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2005-06-22 00:00:00+00:00',
#  '2004-09-13 00:00:00+00:00',
#  '2006-03-26 00:00:00+00:00',
#  '2006-02-25 00:00:00+00:00',
#  '2004-09-28 00:00:00+00:00',
#  '2001-09-25 00:00:00+00:00',
#  '2003-01-25 00:00:00+00:00',
#  '2004-06-25 00:00:00+00:00',
#  nan,
#  '2003-10-22 00:00:00+00:00',
#  '2004-02-25 00:00:00+00:00',
#  '2003-05-23 00:00:00+00:00',
#  '2002-06-30 00:00:00+00:00',
#  '2003-09-28 00:00:00+00:00',
#  '2004-10-22 00:00:00+00:00',
#  '2002-03-27 00:00:00+00:00',
#  nan,
#  nan,
#  '2003-04-24 00:00:00+00:00',
#  '2004-03-30 00:00:00+00:00',
#  '1996-06-28 00:00:00+00:00',
#  '2012-03-27 00:00:00+00:00',
#  '2002-01-17 00:00:00+00:00',
#  '2003-09-25 00:00:00+00:00',
#  '2001-09-28 00:00:00+00:00',
#  '2003-03-28 00:00:00+00:00',
#  '2003-03-19 00:00:00+00:00',
#  '2004-06-29 00:00:00+00:00',
#  '2001-12-29 00:00:00+00:00',
#  '2003-01-16 00:00:00+00:00',
#  '2005-09-24 00:00:00+00:00',
#  '2003-12-27 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '2005-08-26 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '1979-12-30 00:00:00+00:00',
#  '2004-03-26 00:00:00+00:00',
#  '2001-03-22 00:00:00+00:00',
#  '1996-09-21 00:00:00+00:00',
#  '2001-06-26 00:00:00+00:00',
#  '2001-12-24 00:00:00+00:00',
#  '2001-06-25 00:00:00+00:00',
#  '1999-03-28 00:00:00+00:00',
#  '2005-12-24 00:00:00+00:00',
#  '2003-09-29 00:00:00+00:00',
#  '1999-12-24 00:00:00+00:00',
#  '2003-09-24 00:00:00+00:00',
#  '2004-03-27 00:00:00+00:00',
#  '2003-03-27 00:00:00+00:00',
#  '2005-01-13 00:00:00+00:00',
#  '2003-03-27 00:00:00+00:00',
#  '2003-04-10 00:00:00+00:00',
#  '1992-03-19 00:00:00+00:00',
#  '2003-09-13 00:00:00+00:00',
#  '1978-10-31 00:00:00+00:00',
#  '1999-03-29 00:00:00+00:00',
#  nan,
#  '1991-11-21 00:00:00+00:00',
#  '2002-06-27 00:00:00+00:00',
#  '1973-09-25 00:00:00+00:00',
#  '2005-11-19 00:00:00+00:00',
#  '2005-09-27 00:00:00+00:00',
#  '1992-04-07 00:00:00+00:00',
#  '1974-03-29 00:00:00+00:00',
#  '1990-04-25 00:00:00+00:00',
#  nan,
#  '1988-10-25 00:00:00+00:00',
#  nan,
#  '1995-10-13 00:00:00+00:00',
#  nan,
#  '2000-09-27 00:00:00+00:00',
#  '2003-06-27 00:00:00+00:00',
#  '1998-10-25 00:00:00+00:00',
#  '2001-12-27 00:00:00+00:00',
#  '2005-12-30 00:00:00+00:00',
#  '2004-05-18 00:00:00+00:00',
#  '1990-09-26 00:00:00+00:00',
#  '2005-06-25 00:00:00+00:00',
#  '1999-03-23 00:00:00+00:00',
#  '2003-03-24 00:00:00+00:00',
#  '2003-01-13 00:00:00+00:00',
#  '2004-04-17 00:00:00+00:00',
#  '2004-06-27 00:00:00+00:00',
#  '1995-09-14 00:00:00+00:00',
#  '2000-12-26 00:00:00+00:00',
#  '1992-12-25 00:00:00+00:00',
#  '1995-09-03 00:00:00+00:00',
#  '2003-09-27 00:00:00+00:00',
#  '2005-02-03 00:00:00+00:00',
#  '2002-09-13 00:00:00+00:00',
#  '1980-09-03 00:00:00+00:00',
#  '1998-09-28 00:00:00+00:00',
#  '2004-09-28 00:00:00+00:00',
#  '2003-03-25 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2005-03-29 00:00:00+00:00',
#  '2004-03-27 00:00:00+00:00',
#  '2005-06-19 00:00:00+00:00',
#  '2004-12-26 00:00:00+00:00',
#  '2000-03-27 00:00:00+00:00',
#  '2003-12-27 00:00:00+00:00',
#  '2005-03-26 00:00:00+00:00',
#  '2000-01-30 00:00:00+00:00',
#  '2001-01-28 00:00:00+00:00',
#  '2002-01-27 00:00:00+00:00',
#  '2003-01-26 00:00:00+00:00',
#  '2005-03-28 00:00:00+00:00',
#  '2006-03-23 00:00:00+00:00',
#  '2006-06-17 00:00:00+00:00',
#  '2005-09-22 00:00:00+00:00',
#  '2005-06-29 00:00:00+00:00',
#  '2003-03-26 00:00:00+00:00',
#  '1999-04-01 00:00:00+00:00',
#  '2002-03-06 00:00:00+00:00',
#  '2003-05-21 00:00:00+00:00',
#  '2004-10-20 00:00:00+00:00',
#  '2005-09-25 00:00:00+00:00',
#  nan,
#  '1999-04-25 00:00:00+00:00',
#  '1996-03-06 00:00:00+00:00',
#  '2003-06-25 00:00:00+00:00',
#  '2000-03-22 00:00:00+00:00',
#  '1998-07-01 00:00:00+00:00',
#  nan,
#  nan,
#  '1994-05-25 00:00:00+00:00',
#  '1998-12-23 00:00:00+00:00',
#  '1998-03-25 00:00:00+00:00',
#  nan,
#  '2001-09-25 00:00:00+00:00',
#  nan,
#  '2000-03-31 00:00:00+00:00',
#  '1997-02-25 00:00:00+00:00',
#  '1998-10-25 00:00:00+00:00',
#  '2004-01-22 00:00:00+00:00',
#  '2001-09-30 00:00:00+00:00',
#  '2004-06-22 00:00:00+00:00',
#  '2004-03-18 00:00:00+00:00',
#  '1996-03-21 00:00:00+00:00',
#  '2002-12-19 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '2007-08-03 00:00:00+00:00',
#  '2005-12-29 00:00:00+00:00',
#  '2006-02-24 00:00:00+00:00',
#  '1995-01-07 00:00:00+00:00',
#  nan,
#  '2003-12-29 00:00:00+00:00',
#  '2004-11-18 00:00:00+00:00',
#  '2000-07-14 00:00:00+00:00',
#  '2001-09-26 00:00:00+00:00',
#  nan,
#  nan,
#  '1998-06-26 00:00:00+00:00',
#  '2002-03-20 00:00:00+00:00',
#  nan,
#  '2001-06-29 00:00:00+00:00',
#  '1993-06-25 00:00:00+00:00',
#  nan,
#  '2005-04-30 00:00:00+00:00',
#  '2004-03-20 00:00:00+00:00',
#  nan,
#  '2005-12-26 00:00:00+00:00',
#  '2005-07-01 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '2004-09-29 00:00:00+00:00',
#  nan,
#  '2002-12-24 00:00:00+00:00',
#  nan,
#  '2003-03-30 00:00:00+00:00',
#  '2004-08-01 00:00:00+00:00',
#  '2006-01-27 00:00:00+00:00',
#  '1985-12-26 00:00:00+00:00',
#  '2002-07-26 00:00:00+00:00',
#  '1994-07-21 00:00:00+00:00',
#  '2004-03-27 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  '1994-11-21 00:00:00+00:00',
#  nan,
#  nan,
#  '1995-03-13 00:00:00+00:00',
#  nan,
#  '2004-11-26 00:00:00+00:00',
#  '1992-06-21 00:00:00+00:00',
#  '1997-12-24 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '2004-09-26 00:00:00+00:00',
#  '2001-03-26 00:00:00+00:00',
#  '2003-03-20 00:00:00+00:00',
#  '1998-10-01 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2005-03-29 00:00:00+00:00',
#  '2005-09-29 00:00:00+00:00',
#  '2006-06-19 00:00:00+00:00',
#  '1997-09-26 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2003-10-01 00:00:00+00:00',
#  nan,
#  '2006-05-11 00:00:00+00:00',
#  '2005-09-24 00:00:00+00:00',
#  '2006-01-03 00:00:00+00:00',
#  '1999-06-25 00:00:00+00:00',
#  '2005-09-29 00:00:00+00:00',
#  '1995-06-25 00:00:00+00:00',
#  nan,
#  '2005-12-25 00:00:00+00:00',
#  '2005-12-29 00:00:00+00:00',
#  '2005-09-27 00:00:00+00:00',
#  '2006-03-27 00:00:00+00:00',
#  '2004-09-29 00:00:00+00:00',
#  '2008-03-26 00:00:00+00:00',
#  '2004-12-16 00:00:00+00:00',
#  nan,
#  '2005-02-21 00:00:00+00:00',
#  '2003-07-08 00:00:00+00:00',
#  '2005-04-21 00:00:00+00:00',
#  '2005-10-14 00:00:00+00:00',
#  '2005-09-28 00:00:00+00:00',
#  '2005-12-26 00:00:00+00:00',
#  nan,
#  nan,
#  '1996-03-26 00:00:00+00:00',
#  nan,
#  '2003-12-25 00:00:00+00:00',
#  '1989-07-25 00:00:00+00:00',
#  nan,
#  '1973-09-30 00:00:00+00:00',
#  nan,
#  '2006-03-24 00:00:00+00:00',
#  nan,
#  '2006-03-25 00:00:00+00:00',
#  '1984-09-24 00:00:00+00:00',
#  '1999-09-22 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  '2001-09-26 00:00:00+00:00',
#  '2004-12-25 00:00:00+00:00',
#  '2005-09-24 00:00:00+00:00',
#  nan,
#  nan,
#  '2004-12-22 00:00:00+00:00',
#  nan,
#  '2011-04-04 00:00:00+00:00',
#  nan,
#  '1983-05-26 00:00:00+00:00',
#  '2005-06-27 00:00:00+00:00',
#  nan,
#  '2004-03-27 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '2005-03-30 00:00:00+00:00',
#  '1994-09-23 00:00:00+00:00',
#  '2002-11-14 00:00:00+00:00',
#  nan,
#  '2002-09-24 00:00:00+00:00',
#  '1993-02-27 00:00:00+00:00',
#  nan,
#  '1995-02-25 00:00:00+00:00',
#  '2004-06-28 00:00:00+00:00',
#  '1995-09-29 00:00:00+00:00',
#  '1996-09-27 00:00:00+00:00',
#  nan,
#  '1998-02-21 00:00:00+00:00',
#  '1997-09-23 00:00:00+00:00',
#  '1993-03-25 00:00:00+00:00',
#  '1995-09-25 00:00:00+00:00',
#  '2005-03-16 00:00:00+00:00',
#  nan,
#  nan,
#  '2003-06-21 00:00:00+00:00',
#  '2004-09-22 00:00:00+00:00',
#  '2004-12-22 00:00:00+00:00',
#  nan,
#  '1998-10-10 00:00:00+00:00',
#  '2001-12-25 00:00:00+00:00',
#  '2000-03-26 00:00:00+00:00',
#  '2000-12-18 00:00:00+00:00',
#  '2000-04-04 00:00:00+00:00',
#  '2001-06-28 00:00:00+00:00',
#  '2001-06-20 00:00:00+00:00',
#  '2000-10-04 00:00:00+00:00',
#  '2006-06-10 00:00:00+00:00',
#  nan,
#  nan,
#  '2000-09-23 00:00:00+00:00',
#  '2005-03-16 00:00:00+00:00',
#  '1994-12-23 00:00:00+00:00',
#  '2001-12-19 00:00:00+00:00',
#  nan,
#  '1997-02-25 00:00:00+00:00',
#  '2003-03-27 00:00:00+00:00',
#  '1999-04-01 00:00:00+00:00',
#  '1993-07-19 00:00:00+00:00',
#  nan,
#  '1993-11-25 00:00:00+00:00',
#  nan,
#  '1997-03-25 00:00:00+00:00',
#  '2006-08-18 00:00:00+00:00',
#  '2006-04-01 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  nan,
#  '2004-01-04 00:00:00+00:00',
#  '2001-11-16 00:00:00+00:00',
#  '2000-12-21 00:00:00+00:00',
#  '1998-04-01 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  nan,
#  '2006-03-24 00:00:00+00:00',
#  '2006-02-24 00:00:00+00:00',
#  nan,
#  '1986-08-22 00:00:00+00:00',
#  '2006-03-26 00:00:00+00:00',
#  '2005-09-16 00:00:00+00:00',
#  '2004-03-28 00:00:00+00:00',
#  '2000-03-29 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  '2001-01-08 00:00:00+00:00',
#  '1995-02-25 00:00:00+00:00',
#  '2005-01-12 00:00:00+00:00',
#  nan,
#  '1993-11-21 00:00:00+00:00',
#  '2005-01-30 00:00:00+00:00',
#  '1998-09-27 00:00:00+00:00',
#  '1999-09-29 00:00:00+00:00',
#  '2000-04-19 00:00:00+00:00',
#  '2007-03-31 00:00:00+00:00',
#  nan,
#  '2005-09-09 00:00:00+00:00',
#  '2003-10-03 00:00:00+00:00',
#  '2003-03-29 00:00:00+00:00',
#  '2005-10-01 00:00:00+00:00',
#  '2005-09-29 00:00:00+00:00',
#  '2005-09-26 00:00:00+00:00',
#  '2004-04-02 00:00:00+00:00',
#  '1996-03-29 00:00:00+00:00',
#  nan,
#  '2003-07-15 00:00:00+00:00',
#  nan,
#  '2003-12-21 00:00:00+00:00',
#  '1998-09-23 00:00:00+00:00',
#  '2004-07-23 00:00:00+00:00',
#  '2002-06-27 00:00:00+00:00',
#  '2003-03-24 00:00:00+00:00',
#  '2004-07-23 00:00:00+00:00',
#  '1999-04-03 00:00:00+00:00',
#  '2005-05-21 00:00:00+00:00',
#  '1997-10-25 00:00:00+00:00',
#  '1999-10-06 00:00:00+00:00',
#  nan,
#  nan,
#  '1998-06-26 00:00:00+00:00',
#  '2004-06-18 00:00:00+00:00',
#  '1999-06-29 00:00:00+00:00',
#  '2004-04-01 00:00:00+00:00',
#  '1999-02-26 00:00:00+00:00',
#  nan,
#  nan,
#  '2006-02-24 00:00:00+00:00',
#  nan,
#  '1997-06-25 00:00:00+00:00',
#  '2003-01-23 00:00:00+00:00',
#  '2004-09-22 00:00:00+00:00',
#  '2004-06-20 00:00:00+00:00',
#  '1996-09-01 00:00:00+00:00',
#  nan,
#  '2002-03-31 00:00:00+00:00',
#  '2003-03-31 00:00:00+00:00',
#  nan,
#  '2004-09-29 00:00:00+00:00',
#  '2005-09-04 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  nan,
#  '2001-11-30 00:00:00+00:00',
#  '1998-06-26 00:00:00+00:00',
#  nan,
#  '2002-01-25 00:00:00+00:00',
#  '1994-11-18 00:00:00+00:00',
#  '2006-03-30 00:00:00+00:00',
#  '2005-06-25 00:00:00+00:00',
#  '2005-04-22 00:00:00+00:00',
#  '2005-12-27 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  '2010-01-27 00:00:00+00:00',
#  '2002-05-24 00:00:00+00:00',
#  '2000-10-27 00:00:00+00:00',
#  '1998-07-01 00:00:00+00:00',
#  '1998-12-25 00:00:00+00:00',
#  '1996-11-21 00:00:00+00:00',
#  nan,
#  '2001-12-20 00:00:00+00:00',
#  '2002-07-25 00:00:00+00:00',
#  '2003-04-03 00:00:00+00:00',
#  '2004-12-25 00:00:00+00:00',
#  '2006-08-24 00:00:00+00:00',
#  '2003-03-29 00:00:00+00:00',
#  '2004-12-19 00:00:00+00:00',
#  nan,
#  '1998-03-30 00:00:00+00:00',
#  '1992-09-21 00:00:00+00:00',
#  '1998-12-18 00:00:00+00:00',
#  '2004-03-29 00:00:00+00:00',
#  '2006-03-26 00:00:00+00:00',
#  '2002-03-25 00:00:00+00:00',
#  '1995-09-24 00:00:00+00:00',
#  nan,
#  nan,
#  '2005-06-28 00:00:00+00:00',
#  nan,
#  '2002-06-29 00:00:00+00:00',
#  '2004-10-28 00:00:00+00:00',
#  '2006-03-31 00:00:00+00:00',
#  nan,
#  '2006-03-26 00:00:00+00:00',
#  nan,
#  '1987-10-03 00:00:00+00:00',
#  '1998-12-19 00:00:00+00:00',
#  '1998-12-24 00:00:00+00:00',
#  '1994-05-01 00:00:00+00:00',
#  '2003-05-23 00:00:00+00:00',
#  nan,
#  nan,
#  '2004-10-22 00:00:00+00:00',
#  nan,
#  '1992-02-29 00:00:00+00:00',
#  '1988-03-20 00:00:00+00:00',
#  '1995-01-27 00:00:00+00:00',
#  nan,
#  nan,
#  '1995-09-29 00:00:00+00:00',
#  nan,
#  nan,
#  '2007-03-25 00:00:00+00:00',
#  '1994-03-12 00:00:00+00:00',
#  nan,
#  nan,
#  '2000-03-24 00:00:00+00:00',
#  '2005-12-21 00:00:00+00:00',
#  '2005-05-27 00:00:00+00:00',
#  '2004-04-23 00:00:00+00:00',
#  '2005-01-08 00:00:00+00:00',
#  '2006-04-16 00:00:00+00:00',
#  '2003-09-24 00:00:00+00:00',
#  nan,
#  '2003-09-25 00:00:00+00:00',
#  '2006-02-12 00:00:00+00:00',
#  '1995-10-06 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2000-12-23 00:00:00+00:00',
#  '2001-06-30 00:00:00+00:00',
#  '2004-07-26 00:00:00+00:00',
#  nan,
#  nan,
#  '1996-09-26 00:00:00+00:00',
#  nan,
#  '2006-04-13 00:00:00+00:00',
#  '1999-12-18 00:00:00+00:00',
#  '2003-03-27 00:00:00+00:00',
#  '2012-12-26 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '1999-03-28 00:00:00+00:00',
#  '2000-05-20 00:00:00+00:00',
#  '1991-12-20 00:00:00+00:00',
#  '2004-07-06 00:00:00+00:00',
#  '2004-06-23 00:00:00+00:00',
#  '2006-04-07 00:00:00+00:00',
#  '2006-08-12 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '1992-05-31 00:00:00+00:00',
#  nan,
#  '2001-11-07 00:00:00+00:00',
#  '2006-03-27 00:00:00+00:00',
#  '2002-02-17 00:00:00+00:00',
#  '2000-07-19 00:00:00+00:00',
#  '2005-01-08 00:00:00+00:00',
#  nan,
#  '1997-04-23 00:00:00+00:00',
#  '1998-09-28 00:00:00+00:00',
#  '2006-06-23 00:00:00+00:00',
#  '2001-03-27 00:00:00+00:00',
#  '1996-01-31 00:00:00+00:00',
#  nan,
#  nan,
#  '2000-03-24 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '1997-10-22 00:00:00+00:00',
#  nan,
#  '1997-03-17 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '2003-11-28 00:00:00+00:00',
#  '2006-03-03 00:00:00+00:00',
#  '2004-07-09 00:00:00+00:00',
#  '2001-06-21 00:00:00+00:00',
#  '2004-04-23 00:00:00+00:00',
#  '2002-03-27 00:00:00+00:00',
#  '2000-09-19 00:00:00+00:00',
#  '2002-12-17 00:00:00+00:00',
#  nan,
#  '2002-12-25 00:00:00+00:00',
#  '2001-09-26 00:00:00+00:00',
#  '2007-03-21 00:00:00+00:00',
#  '2003-09-29 00:00:00+00:00',
#  '1999-09-30 00:00:00+00:00',
#  '2003-06-28 00:00:00+00:00',
#  '1999-10-01 00:00:00+00:00',
#  '1993-08-01 00:00:00+00:00',
#  nan,
#  '2007-03-25 00:00:00+00:00',
#  '2006-09-25 00:00:00+00:00',
#  nan,
#  '2006-07-03 00:00:00+00:00',
#  '2006-06-24 00:00:00+00:00',
#  '1997-12-21 00:00:00+00:00',
#  '1996-09-01 00:00:00+00:00',
#  '2006-09-27 00:00:00+00:00',
#  '2006-06-25 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '2006-09-27 00:00:00+00:00',
#  '2006-03-28 00:00:00+00:00',
#  '2007-03-25 00:00:00+00:00',
#  '2006-06-21 00:00:00+00:00',
#  '2006-09-29 00:00:00+00:00',
#  '2006-06-20 00:00:00+00:00',
#  '2004-07-01 00:00:00+00:00',
#  '1988-01-30 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  '1993-05-28 00:00:00+00:00',
#  '2005-03-04 00:00:00+00:00',
#  '2006-09-28 00:00:00+00:00',
#  '2002-03-31 00:00:00+00:00',
#  nan,
#  '1995-11-27 00:00:00+00:00',
#  '2007-03-28 00:00:00+00:00',
#  '2006-09-28 00:00:00+00:00',
#  '2006-09-26 00:00:00+00:00',
#  '2006-09-15 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2006-03-22 00:00:00+00:00',
#  nan,
#  '2000-03-27 00:00:00+00:00',
#  '2006-06-25 00:00:00+00:00',
#  '1998-01-31 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2006-06-22 00:00:00+00:00',
#  nan,
#  '2001-06-28 00:00:00+00:00',
#  '2006-07-02 00:00:00+00:00',
#  nan,
#  '1996-02-24 00:00:00+00:00',
#  '2006-03-26 00:00:00+00:00',
#  '1995-09-28 00:00:00+00:00',
#  '2006-05-11 00:00:00+00:00',
#  '2006-07-30 00:00:00+00:00',
#  nan,
#  '2010-03-25 00:00:00+00:00',
#  '2006-06-29 00:00:00+00:00',
#  nan,
#  '2005-09-22 00:00:00+00:00',
#  '1989-03-07 00:00:00+00:00',
#  '1988-03-28 00:00:00+00:00',
#  '1989-12-19 00:00:00+00:00',
#  '2004-12-24 00:00:00+00:00',
#  '2005-12-31 00:00:00+00:00',
#  '1984-01-21 00:00:00+00:00',
#  '1981-01-30 00:00:00+00:00',
#  nan,
#  '2007-03-21 00:00:00+00:00',
#  '2006-09-27 00:00:00+00:00',
#  '2006-09-21 00:00:00+00:00',
#  nan,
#  nan,
#  '2001-06-25 00:00:00+00:00',
#  '2006-09-28 00:00:00+00:00',
#  '2006-06-20 00:00:00+00:00',
#  '2006-07-01 00:00:00+00:00',
#  '2006-06-25 00:00:00+00:00',
#  '2006-10-27 00:00:00+00:00',
#  '1989-07-07 00:00:00+00:00',
#  nan,
#  '1992-09-27 00:00:00+00:00',
#  '2001-09-27 00:00:00+00:00',
#  '2006-06-23 00:00:00+00:00',
#  '1977-01-27 00:00:00+00:00',
#  '2007-02-24 00:00:00+00:00',
#  '2003-03-26 00:00:00+00:00',
#  '2002-10-28 00:00:00+00:00',
#  '2006-09-02 00:00:00+00:00',
#  '1996-06-27 00:00:00+00:00',
#  '2006-09-25 00:00:00+00:00',
#  nan,
#  '2004-04-27 00:00:00+00:00',
#  '2006-06-25 00:00:00+00:00',
#  nan,
#  '1987-03-05 00:00:00+00:00',
#  '2006-10-01 00:00:00+00:00',
#  '2006-11-04 00:00:00+00:00',
#  '1992-09-25 00:00:00+00:00',
#  '2004-03-28 00:00:00+00:00',
#  '2002-08-25 00:00:00+00:00',
#  '2006-09-22 00:00:00+00:00',
#  nan,
#  '1998-12-02 00:00:00+00:00',
#  '2003-03-05 00:00:00+00:00',
#  nan,
#  '1999-05-25 00:00:00+00:00',
#  nan,
#  '2002-12-26 00:00:00+00:00',
#  '2005-10-31 00:00:00+00:00',
#  '2002-10-26 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2005-07-23 00:00:00+00:00',
#  nan,
#  '2006-08-10 00:00:00+00:00',
#  '2002-04-26 00:00:00+00:00',
#  '1999-07-01 00:00:00+00:00',
#  nan,
#  nan,
#  '2007-03-23 00:00:00+00:00',
#  '1997-02-08 00:00:00+00:00',
#  nan,
#  '1995-03-29 00:00:00+00:00',
#  '1998-02-04 00:00:00+00:00',
#  '1979-02-13 00:00:00+00:00',
#  nan,
#  '2006-08-25 00:00:00+00:00',
#  '2005-12-23 00:00:00+00:00',
#  nan,
#  '2001-09-25 00:00:00+00:00',
#  nan,
#  '1994-08-19 00:00:00+00:00',
#  '1995-02-17 00:00:00+00:00',
#  nan,
#  nan,
#  '1996-01-19 00:00:00+00:00',
#  '1998-04-03 00:00:00+00:00',
#  '2007-02-24 00:00:00+00:00',
#  '2003-08-28 00:00:00+00:00',
#  nan,
#  '1993-08-21 00:00:00+00:00',
#  '1999-03-27 00:00:00+00:00',
#  '2000-03-25 00:00:00+00:00',
#  '2002-04-08 00:00:00+00:00',
#  '2004-11-26 00:00:00+00:00',
#  '2000-03-26 00:00:00+00:00',
#  '1998-12-23 00:00:00+00:00',
#  '2004-02-25 00:00:00+00:00',
#  '2000-02-23 00:00:00+00:00',
#  '1999-10-07 00:00:00+00:00',
#  '1997-11-25 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2005-11-29 00:00:00+00:00',
#  '1999-01-21 00:00:00+00:00',
#  '2003-06-13 00:00:00+00:00',
#  '2002-12-06 00:00:00+00:00',
#  '2003-10-10 00:00:00+00:00',
#  '1997-02-27 00:00:00+00:00',
#  nan,
#  nan,
#  '1994-03-21 00:00:00+00:00',
#  nan,
#  '1996-12-20 00:00:00+00:00',
#  '1997-12-25 00:00:00+00:00',
#  nan,
#  '2001-07-04 00:00:00+00:00',
#  nan,
#  '2005-10-15 00:00:00+00:00',
#  '2000-03-25 00:00:00+00:00',
#  '2000-01-21 00:00:00+00:00',
#  '2004-03-24 00:00:00+00:00',
#  nan,
#  nan,
#  '1999-10-29 00:00:00+00:00',
#  '2004-02-18 00:00:00+00:00',
#  nan,
#  '1999-10-01 00:00:00+00:00',
#  '1999-10-01 00:00:00+00:00',
#  '2002-09-20 00:00:00+00:00',
#  '1987-03-22 00:00:00+00:00',
#  '2007-04-04 00:00:00+00:00',
#  '2006-08-18 00:00:00+00:00',
#  '1977-05-28 00:00:00+00:00',
#  '1978-03-25 00:00:00+00:00',
#  '2006-09-27 00:00:00+00:00',
#  nan,
#  '2006-07-01 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  '1995-11-25 00:00:00+00:00',
#  '2005-08-26 00:00:00+00:00',
#  '2003-12-21 00:00:00+00:00',
#  '2004-07-03 00:00:00+00:00',
#  '2003-06-29 00:00:00+00:00',
#  '2003-03-19 00:00:00+00:00',
#  '2004-08-27 00:00:00+00:00',
#  '2004-09-23 00:00:00+00:00',
#  '1988-03-07 00:00:00+00:00',
#  '1983-06-26 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  nan,
#  '1992-03-17 00:00:00+00:00',
#  nan,
#  nan,
#  nan,
#  '2003-03-29 00:00:00+00:00',
#  '2001-10-22 00:00:00+00:00',
#  nan,
#  ...]

# %%
df_anime['aired_from'].tolist()
# Out:
# ['1998-04-03 00:00:00+00:00',
#  '2001-09-01 00:00:00+00:00',
#  '1998-04-01 00:00:00+00:00',
#  '2002-07-03 00:00:00+00:00',
#  '2004-09-30 00:00:00+00:00',
#  '2005-04-06 00:00:00+00:00',
#  '2005-04-15 00:00:00+00:00',
#  '2002-09-11 00:00:00+00:00',
#  '2004-04-17 00:00:00+00:00',
#  '2004-04-07 00:00:00+00:00',
#  '2002-10-03 00:00:00+00:00',
#  '1999-10-20 00:00:00+00:00',
#  '2001-10-10 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2004-10-05 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2003-04-17 00:00:00+00:00',
#  '2005-04-29 00:00:00+00:00',
#  '2004-10-12 00:00:00+00:00',
#  '2004-10-08 00:00:00+00:00',
#  '1995-10-04 00:00:00+00:00',
#  '1997-03-15 00:00:00+00:00',
#  '1997-07-19 00:00:00+00:00',
#  '1997-10-08 00:00:00+00:00',
#  '1995-11-18 00:00:00+00:00',
#  '1999-02-20 00:00:00+00:00',
#  '1996-01-10 00:00:00+00:00',
#  '1997-12-20 00:00:00+00:00',
#  '1988-07-16 00:00:00+00:00',
#  '2002-04-04 00:00:00+00:00',
#  '1993-02-21 00:00:00+00:00',
#  '2005-01-07 00:00:00+00:00',
#  '2000-05-25 00:00:00+00:00',
#  '2001-04-01 00:00:00+00:00',
#  '2002-04-11 00:00:00+00:00',
#  '2004-04-17 00:00:00+00:00',
#  '1999-04-05 00:00:00+00:00',
#  '2003-10-02 00:00:00+00:00',
#  '2004-10-07 00:00:00+00:00',
#  '1999-10-08 00:00:00+00:00',
#  '2002-04-03 00:00:00+00:00',
#  '2003-11-25 00:00:00+00:00',
#  '2003-04-03 00:00:00+00:00',
#  '2003-07-05 00:00:00+00:00',
#  '2004-07-11 00:00:00+00:00',
#  '2004-10-08 00:00:00+00:00',
#  '2005-10-21 00:00:00+00:00',
#  '2002-04-09 00:00:00+00:00',
#  '2005-04-13 00:00:00+00:00',
#  '2005-10-07 00:00:00+00:00',
#  '2005-10-05 00:00:00+00:00',
#  '2002-01-08 00:00:00+00:00',
#  '2003-08-26 00:00:00+00:00',
#  '2005-07-14 00:00:00+00:00',
#  '2004-10-30 00:00:00+00:00',
#  '2004-07-05 00:00:00+00:00',
#  '2004-10-03 00:00:00+00:00',
#  '2005-10-02 00:00:00+00:00',
#  '2005-07-08 00:00:00+00:00',
#  '1979-04-07 00:00:00+00:00',
#  '1996-01-25 00:00:00+00:00',
#  '1989-03-25 00:00:00+00:00',
#  '1998-08-01 00:00:00+00:00',
#  '1991-05-23 00:00:00+00:00',
#  '1985-03-02 00:00:00+00:00',
#  '1986-03-01 00:00:00+00:00',
#  '1988-03-12 00:00:00+00:00',
#  '1991-03-16 00:00:00+00:00',
#  '1993-04-02 00:00:00+00:00',
#  '1995-04-07 00:00:00+00:00',
#  '1997-01-25 00:00:00+00:00',
#  '1996-04-05 00:00:00+00:00',
#  '2002-10-05 00:00:00+00:00',
#  '2004-10-09 00:00:00+00:00',
#  '1999-04-09 00:00:00+00:00',
#  '1994-04-01 00:00:00+00:00',
#  '2003-04-08 00:00:00+00:00',
#  '2004-10-01 00:00:00+00:00',
#  '2005-10-07 00:00:00+00:00',
#  '2001-04-04 00:00:00+00:00',
#  '2005-01-07 00:00:00+00:00',
#  '2004-04-03 00:00:00+00:00',
#  '1994-01-07 00:00:00+00:00',
#  '2000-04-20 00:00:00+00:00',
#  '2000-04-11 00:00:00+00:00',
#  '1996-09-08 00:00:00+00:00',
#  '2002-05-15 00:00:00+00:00',
#  '2004-01-21 00:00:00+00:00',
#  '2004-04-07 00:00:00+00:00',
#  '1997-04-27 00:00:00+00:00',
#  '1999-04-09 00:00:00+00:00',
#  '2004-01-13 00:00:00+00:00',
#  '2003-04-03 00:00:00+00:00',
#  '2003-10-03 00:00:00+00:00',
#  '1998-01-08 00:00:00+00:00',
#  '1995-10-06 00:00:00+00:00',
#  '1995-05-26 00:00:00+00:00',
#  '1997-03-21 00:00:00+00:00',
#  '2004-10-03 00:00:00+00:00',
#  '2001-07-05 00:00:00+00:00',
#  '2003-10-04 00:00:00+00:00',
#  '2002-04-06 00:00:00+00:00',
#  '1995-04-06 00:00:00+00:00',
#  '2001-12-21 00:00:00+00:00',
#  '2004-10-07 00:00:00+00:00',
#  '2005-04-07 00:00:00+00:00',
#  '2000-04-03 00:00:00+00:00',
#  '2002-04-24 00:00:00+00:00',
#  '2000-04-04 00:00:00+00:00',
#  '2003-10-02 00:00:00+00:00',
#  '2004-04-02 00:00:00+00:00',
#  '2002-10-05 00:00:00+00:00',
#  '2003-07-13 00:00:00+00:00',
#  '2003-10-09 00:00:00+00:00',
#  '2001-10-10 00:00:00+00:00',
#  '1999-10-16 00:00:00+00:00',
#  '2002-01-17 00:00:00+00:00',
#  '2003-02-05 00:00:00+00:00',
#  '2004-03-03 00:00:00+00:00',
#  '2005-01-06 00:00:00+00:00',
#  '1999-02-13 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2002-01-31 00:00:00+00:00',
#  '1998-10-02 00:00:00+00:00',
#  '2004-04-02 00:00:00+00:00',
#  '2003-10-05 00:00:00+00:00',
#  '2004-01-20 00:00:00+00:00',
#  '2005-04-07 00:00:00+00:00',
#  '2005-10-08 00:00:00+00:00',
#  '2004-07-24 00:00:00+00:00',
#  '2005-10-07 00:00:00+00:00',
#  '2002-04-09 00:00:00+00:00',
#  '2001-07-04 00:00:00+00:00',
#  '1996-08-03 00:00:00+00:00',
#  '2001-10-03 00:00:00+00:00',
#  '2005-01-06 00:00:00+00:00',
#  '2004-01-08 00:00:00+00:00',
#  '2004-04-07 00:00:00+00:00',
#  '1999-10-14 00:00:00+00:00',
#  '2003-10-08 00:00:00+00:00',
#  '2002-04-07 00:00:00+00:00',
#  '1999-04-03 00:00:00+00:00',
#  '1997-07-12 00:00:00+00:00',
#  '2002-01-21 00:00:00+00:00',
#  '2004-06-12 00:00:00+00:00',
#  '2003-04-08 00:00:00+00:00',
#  '2001-07-04 00:00:00+00:00',
#  '2003-10-10 00:00:00+00:00',
#  '1993-10-16 00:00:00+00:00',
#  '2000-07-11 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2004-04-02 00:00:00+00:00',
#  '2002-04-02 00:00:00+00:00',
#  '2003-07-24 00:00:00+00:00',
#  '2005-04-09 00:00:00+00:00',
#  '2003-05-20 00:00:00+00:00',
#  '2002-08-06 00:00:00+00:00',
#  '2000-10-03 00:00:00+00:00',
#  '2001-10-05 00:00:00+00:00',
#  '1996-04-02 00:00:00+00:00',
#  '2002-05-06 00:00:00+00:00',
#  '2005-01-06 00:00:00+00:00',
#  '1998-04-19 00:00:00+00:00',
#  '1999-10-15 00:00:00+00:00',
#  '2001-01-13 00:00:00+00:00',
#  '1998-09-25 00:00:00+00:00',
#  '2000-04-19 00:00:00+00:00',
#  '2002-01-26 00:00:00+00:00',
#  '2000-12-25 00:00:00+00:00',
#  '2001-04-02 00:00:00+00:00',
#  '2003-10-14 00:00:00+00:00',
#  '2002-12-21 00:00:00+00:00',
#  '2002-01-10 00:00:00+00:00',
#  '2003-07-15 00:00:00+00:00',
#  '2002-04-03 00:00:00+00:00',
#  '2005-04-08 00:00:00+00:00',
#  '2001-07-20 00:00:00+00:00',
#  '2002-04-07 00:00:00+00:00',
#  '1992-03-27 00:00:00+00:00',
#  '2003-01-07 00:00:00+00:00',
#  '1999-08-25 00:00:00+00:00',
#  '2004-01-09 00:00:00+00:00',
#  '2004-05-20 00:00:00+00:00',
#  '1998-04-01 00:00:00+00:00',
#  '1990-06-30 00:00:00+00:00',
#  '2001-05-23 00:00:00+00:00',
#  '2003-09-01 00:00:00+00:00',
#  '1989-04-15 00:00:00+00:00',
#  '2001-09-25 00:00:00+00:00',
#  '1986-06-21 00:00:00+00:00',
#  '1997-10-24 00:00:00+00:00',
#  '1998-10-23 00:00:00+00:00',
#  '1999-12-18 00:00:00+00:00',
#  '2002-10-19 00:00:00+00:00',
#  '1994-10-21 00:00:00+00:00',
#  '1996-10-01 00:00:00+00:00',
#  '1998-08-01 00:00:00+00:00',
#  '1999-10-29 00:00:00+00:00',
#  '2000-05-25 00:00:00+00:00',
#  '2004-01-04 00:00:00+00:00',
#  '1986-02-26 00:00:00+00:00',
#  '1996-02-07 00:00:00+00:00',
#  '2004-07-25 00:00:00+00:00',
#  '2000-04-26 00:00:00+00:00',
#  '2005-10-05 00:00:00+00:00',
#  '2004-07-10 00:00:00+00:00',
#  '2003-04-02 00:00:00+00:00',
#  '2002-07-04 00:00:00+00:00',
#  '1998-04-07 00:00:00+00:00',
#  '2000-03-28 00:00:00+00:00',
#  '2004-04-03 00:00:00+00:00',
#  '1996-01-08 00:00:00+00:00',
#  '2003-04-01 00:00:00+00:00',
#  '2005-04-17 00:00:00+00:00',
#  '1997-07-19 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2004-10-11 00:00:00+00:00',
#  '2004-07-05 00:00:00+00:00',
#  '2004-01-07 00:00:00+00:00',
#  '2000-10-04 00:00:00+00:00',
#  '2004-07-04 00:00:00+00:00',
#  '1999-06-30 00:00:00+00:00',
#  '2001-10-13 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2005-04-06 00:00:00+00:00',
#  '2000-10-16 00:00:00+00:00',
#  '2003-04-06 00:00:00+00:00',
#  '2004-04-03 00:00:00+00:00',
#  '2004-04-06 00:00:00+00:00',
#  '2001-04-03 00:00:00+00:00',
#  '2002-08-25 00:00:00+00:00',
#  '2003-12-21 00:00:00+00:00',
#  '2002-02-02 00:00:00+00:00',
#  '2003-07-30 00:00:00+00:00',
#  '2003-05-25 00:00:00+00:00',
#  '2001-07-19 00:00:00+00:00',
#  '2002-04-01 00:00:00+00:00',
#  '2003-07-03 00:00:00+00:00',
#  '2004-05-25 00:00:00+00:00',
#  '2000-10-04 00:00:00+00:00',
#  '2003-04-18 00:00:00+00:00',
#  '2003-09-05 00:00:00+00:00',
#  '2003-02-06 00:00:00+00:00',
#  '2003-10-07 00:00:00+00:00',
#  '1995-10-27 00:00:00+00:00',
#  '2004-10-05 00:00:00+00:00',
#  '2001-10-11 00:00:00+00:00',
#  '2003-04-16 00:00:00+00:00',
#  '2001-04-06 00:00:00+00:00',
#  '2003-01-10 00:00:00+00:00',
#  '2002-10-09 00:00:00+00:00',
#  '2004-05-04 00:00:00+00:00',
#  '2001-10-06 00:00:00+00:00',
#  '2002-09-26 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2003-10-04 00:00:00+00:00',
#  '2005-10-04 00:00:00+00:00',
#  '2004-11-25 00:00:00+00:00',
#  '2005-10-04 00:00:00+00:00',
#  '1979-01-07 00:00:00+00:00',
#  '2004-01-09 00:00:00+00:00',
#  '2000-10-06 00:00:00+00:00',
#  '1996-04-06 00:00:00+00:00',
#  '2001-01-09 00:00:00+00:00',
#  '2001-01-08 00:00:00+00:00',
#  '2001-04-02 00:00:00+00:00',
#  '1999-01-03 00:00:00+00:00',
#  '2005-07-02 00:00:00+00:00',
#  '2003-04-07 00:00:00+00:00',
#  '1999-11-30 00:00:00+00:00',
#  '2003-07-02 00:00:00+00:00',
#  '2004-01-03 00:00:00+00:00',
#  '2002-07-04 00:00:00+00:00',
#  '2004-10-14 00:00:00+00:00',
#  '2003-01-09 00:00:00+00:00',
#  '2002-06-20 00:00:00+00:00',
#  '1991-07-25 00:00:00+00:00',
#  '2003-06-21 00:00:00+00:00',
#  '1978-04-04 00:00:00+00:00',
#  '1998-04-06 00:00:00+00:00',
#  '2000-10-21 00:00:00+00:00',
#  '1991-05-21 00:00:00+00:00',
#  '2002-04-04 00:00:00+00:00',
#  '1973-01-02 00:00:00+00:00',
#  '2005-05-21 00:00:00+00:00',
#  '2005-07-05 00:00:00+00:00',
#  '1991-04-09 00:00:00+00:00',
#  '1973-10-05 00:00:00+00:00',
#  '1989-10-25 00:00:00+00:00',
#  '1979-09-08 00:00:00+00:00',
#  '1988-07-25 00:00:00+00:00',
#  '1997-07-31 00:00:00+00:00',
#  '1994-08-05 00:00:00+00:00',
#  '2005-09-14 00:00:00+00:00',
#  '2000-07-26 00:00:00+00:00',
#  '2002-12-13 00:00:00+00:00',
#  '1998-02-25 00:00:00+00:00',
#  '2001-10-05 00:00:00+00:00',
#  '2005-10-14 00:00:00+00:00',
#  '2004-02-03 00:00:00+00:00',
#  '1989-10-11 00:00:00+00:00',
#  '2005-01-08 00:00:00+00:00',
#  '1999-03-02 00:00:00+00:00',
#  '2002-09-30 00:00:00+00:00',
#  '2002-11-11 00:00:00+00:00',
#  '2003-10-04 00:00:00+00:00',
#  '2004-04-04 00:00:00+00:00',
#  '1994-10-13 00:00:00+00:00',
#  '2000-04-04 00:00:00+00:00',
#  '1992-01-10 00:00:00+00:00',
#  '1994-03-13 00:00:00+00:00',
#  '2003-04-05 00:00:00+00:00',
#  '2004-11-04 00:00:00+00:00',
#  '2002-03-29 00:00:00+00:00',
#  '1979-10-10 00:00:00+00:00',
#  '1998-07-06 00:00:00+00:00',
#  '2004-04-06 00:00:00+00:00',
#  '2002-10-01 00:00:00+00:00',
#  '2005-01-05 00:00:00+00:00',
#  '2004-10-05 00:00:00+00:00',
#  '2003-11-01 00:00:00+00:00',
#  '2005-04-03 00:00:00+00:00',
#  '2004-10-03 00:00:00+00:00',
#  '1999-10-18 00:00:00+00:00',
#  '2003-10-04 00:00:00+00:00',
#  '2005-01-01 00:00:00+00:00',
#  '1999-02-07 00:00:00+00:00',
#  '2000-02-06 00:00:00+00:00',
#  '2001-02-04 00:00:00+00:00',
#  '2002-02-03 00:00:00+00:00',
#  '2005-01-10 00:00:00+00:00',
#  '2005-10-06 00:00:00+00:00',
#  '2006-01-07 00:00:00+00:00',
#  '2005-03-13 00:00:00+00:00',
#  '2005-02-25 00:00:00+00:00',
#  '2002-12-18 00:00:00+00:00',
#  '1999-01-07 00:00:00+00:00',
#  '2001-11-21 00:00:00+00:00',
#  '2003-01-22 00:00:00+00:00',
#  '2004-05-12 00:00:00+00:00',
#  '2005-01-09 00:00:00+00:00',
#  '1998-04-21 00:00:00+00:00',
#  '1997-04-25 00:00:00+00:00',
#  '1995-12-06 00:00:00+00:00',
#  '2001-07-21 00:00:00+00:00',
#  '2000-01-05 00:00:00+00:00',
#  '1997-12-12 00:00:00+00:00',
#  '1999-08-21 00:00:00+00:00',
#  '2000-07-15 00:00:00+00:00',
#  '1992-10-21 00:00:00+00:00',
#  '1998-09-23 00:00:00+00:00',
#  '1998-01-07 00:00:00+00:00',
#  '2005-04-21 00:00:00+00:00',
#  '2000-07-25 00:00:00+00:00',
#  '2002-04-20 00:00:00+00:00',
#  '1999-10-08 00:00:00+00:00',
#  '1996-10-25 00:00:00+00:00',
#  '1997-05-25 00:00:00+00:00',
#  '2002-07-26 00:00:00+00:00',
#  '2001-04-08 00:00:00+00:00',
#  '2004-04-13 00:00:00+00:00',
#  '2003-10-02 00:00:00+00:00',
#  '1995-06-01 00:00:00+00:00',
#  '2002-10-10 00:00:00+00:00',
#  '2005-10-04 00:00:00+00:00',
#  '2005-03-25 00:00:00+00:00',
#  '2005-07-07 00:00:00+00:00',
#  '2004-11-25 00:00:00+00:00',
#  '1992-10-10 00:00:00+00:00',
#  '2000-06-24 00:00:00+00:00',
#  '2003-10-13 00:00:00+00:00',
#  '2004-08-26 00:00:00+00:00',
#  '2000-04-14 00:00:00+00:00',
#  '2001-07-11 00:00:00+00:00',
#  '2005-08-06 00:00:00+00:00',
#  '2001-07-04 00:00:00+00:00',
#  '1998-01-09 00:00:00+00:00',
#  '2001-12-19 00:00:00+00:00',
#  '2005-02-20 00:00:00+00:00',
#  '2001-04-13 00:00:00+00:00',
#  '1992-08-25 00:00:00+00:00',
#  '2000-11-18 00:00:00+00:00',
#  '2005-02-05 00:00:00+00:00',
#  '2003-04-15 00:00:00+00:00',
#  '2005-09-14 00:00:00+00:00',
#  '2005-07-04 00:00:00+00:00',
#  '2005-04-08 00:00:00+00:00',
#  '2005-07-06 00:00:00+00:00',
#  '1999-07-17 00:00:00+00:00',
#  '1992-07-18 00:00:00+00:00',
#  '2004-04-07 00:00:00+00:00',
#  '1991-11-02 00:00:00+00:00',
#  '2002-07-02 00:00:00+00:00',
#  '1998-09-05 00:00:00+00:00',
#  '2003-01-05 00:00:00+00:00',
#  '2004-05-28 00:00:00+00:00',
#  '2005-03-05 00:00:00+00:00',
#  '1985-07-15 00:00:00+00:00',
#  '2002-03-29 00:00:00+00:00',
#  '1994-03-21 00:00:00+00:00',
#  '2003-04-03 00:00:00+00:00',
#  '2004-09-24 00:00:00+00:00',
#  '2005-12-11 00:00:00+00:00',
#  '2005-07-23 00:00:00+00:00',
#  '2004-11-20 00:00:00+00:00',
#  '1994-06-23 00:00:00+00:00',
#  '2004-11-20 00:00:00+00:00',
#  '1989-07-25 00:00:00+00:00',
#  '1994-10-17 00:00:00+00:00',
#  '1998-02-28 00:00:00+00:00',
#  '2004-02-27 00:00:00+00:00',
#  '1991-06-01 00:00:00+00:00',
#  '1997-04-02 00:00:00+00:00',
#  '1999-08-14 00:00:00+00:00',
#  '2004-08-21 00:00:00+00:00',
#  '2002-10-25 00:00:00+00:00',
#  '2004-07-04 00:00:00+00:00',
#  '2001-01-08 00:00:00+00:00',
#  '2002-11-28 00:00:00+00:00',
#  '1998-04-09 00:00:00+00:00',
#  '2005-03-16 00:00:00+00:00',
#  '2004-12-23 00:00:00+00:00',
#  '2002-12-21 00:00:00+00:00',
#  '2003-12-20 00:00:00+00:00',
#  '2001-12-22 00:00:00+00:00',
#  '2003-11-16 00:00:00+00:00',
#  '2004-10-05 00:00:00+00:00',
#  '2005-04-07 00:00:00+00:00',
#  '2005-10-23 00:00:00+00:00',
#  '1997-04-25 00:00:00+00:00',
#  '2000-03-04 00:00:00+00:00',
#  '2001-03-03 00:00:00+00:00',
#  '2002-03-02 00:00:00+00:00',
#  '2003-03-01 00:00:00+00:00',
#  '2004-03-06 00:00:00+00:00',
#  '2005-03-05 00:00:00+00:00',
#  '2006-03-04 00:00:00+00:00',
#  '1998-07-26 00:00:00+00:00',
#  '2002-10-01 00:00:00+00:00',
#  '2004-03-06 00:00:00+00:00',
#  '2005-11-03 00:00:00+00:00',
#  '2005-07-02 00:00:00+00:00',
#  '2005-10-04 00:00:00+00:00',
#  '1999-04-02 00:00:00+00:00',
#  '2005-07-07 00:00:00+00:00',
#  '1994-08-25 00:00:00+00:00',
#  '2005-08-28 00:00:00+00:00',
#  '2005-10-09 00:00:00+00:00',
#  '2005-10-06 00:00:00+00:00',
#  '2005-04-05 00:00:00+00:00',
#  '2005-04-04 00:00:00+00:00',
#  '2000-04-18 00:00:00+00:00',
#  '2004-10-06 00:00:00+00:00',
#  '2004-06-25 00:00:00+00:00',
#  '2001-08-18 00:00:00+00:00',
#  '2005-01-17 00:00:00+00:00',
#  '2003-04-08 00:00:00+00:00',
#  '2005-01-27 00:00:00+00:00',
#  '2005-07-15 00:00:00+00:00',
#  '2005-06-29 00:00:00+00:00',
#  '2005-07-04 00:00:00+00:00',
#  '2002-06-25 00:00:00+00:00',
#  '1996-04-20 00:00:00+00:00',
#  '1995-10-03 00:00:00+00:00',
#  '1985-03-09 00:00:00+00:00',
#  '2003-10-02 00:00:00+00:00',
#  '1987-09-28 00:00:00+00:00',
#  '1988-10-25 00:00:00+00:00',
#  '1973-04-01 00:00:00+00:00',
#  '1986-12-20 00:00:00+00:00',
#  '2005-06-24 00:00:00+00:00',
#  '1994-07-16 00:00:00+00:00',
#  '2005-04-02 00:00:00+00:00',
#  '1984-04-09 00:00:00+00:00',
#  '1999-07-23 00:00:00+00:00',
#  '2000-07-07 00:00:00+00:00',
#  '2001-07-04 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2005-07-02 00:00:00+00:00',
#  '1989-07-29 00:00:00+00:00',
#  '1986-08-02 00:00:00+00:00',
#  '2004-04-11 00:00:00+00:00',
#  '1995-07-29 00:00:00+00:00',
#  '2004-04-03 00:00:00+00:00',
#  '2005-12-22 00:00:00+00:00',
#  '1982-03-18 00:00:00+00:00',
#  '2005-01-10 00:00:00+00:00',
#  '1995-03-04 00:00:00+00:00',
#  '2003-04-05 00:00:00+00:00',
#  '2001-05-26 00:00:00+00:00',
#  '1988-04-16 00:00:00+00:00',
#  '2004-04-28 00:00:00+00:00',
#  '2004-07-07 00:00:00+00:00',
#  '1993-12-17 00:00:00+00:00',
#  '1997-04-01 00:00:00+00:00',
#  '1998-07-18 00:00:00+00:00',
#  '2002-07-02 00:00:00+00:00',
#  '1992-03-07 00:00:00+00:00',
#  '1993-12-05 00:00:00+00:00',
#  '1994-03-19 00:00:00+00:00',
#  '2004-04-05 00:00:00+00:00',
#  '1995-04-07 00:00:00+00:00',
#  '1996-04-05 00:00:00+00:00',
#  '1995-07-29 00:00:00+00:00',
#  '1998-01-21 00:00:00+00:00',
#  '1997-04-01 00:00:00+00:00',
#  '1992-09-25 00:00:00+00:00',
#  '1994-09-25 00:00:00+00:00',
#  '2003-09-18 00:00:00+00:00',
#  '2000-08-25 00:00:00+00:00',
#  '1989-03-11 00:00:00+00:00',
#  '2003-04-05 00:00:00+00:00',
#  '2004-06-30 00:00:00+00:00',
#  '2004-06-25 00:00:00+00:00',
#  '2003-07-17 00:00:00+00:00',
#  '1998-04-04 00:00:00+00:00',
#  '2001-07-24 00:00:00+00:00',
#  '1999-03-07 00:00:00+00:00',
#  '2000-10-02 00:00:00+00:00',
#  '1999-10-05 00:00:00+00:00',
#  '2001-04-12 00:00:00+00:00',
#  '2001-04-18 00:00:00+00:00',
#  '2000-07-19 00:00:00+00:00',
#  '2005-12-10 00:00:00+00:00',
#  '2003-08-07 00:00:00+00:00',
#  '2005-12-30 00:00:00+00:00',
#  '2000-04-08 00:00:00+00:00',
#  '2004-10-20 00:00:00+00:00',
#  '1994-10-07 00:00:00+00:00',
#  '2001-03-07 00:00:00+00:00',
#  '2004-07-17 00:00:00+00:00',
#  '1996-07-25 00:00:00+00:00',
#  '1999-10-13 00:00:00+00:00',
#  '1998-10-08 00:00:00+00:00',
#  '1993-01-25 00:00:00+00:00',
#  '2000-06-03 00:00:00+00:00',
#  '1993-02-25 00:00:00+00:00',
#  '1984-03-11 00:00:00+00:00',
#  '1996-10-01 00:00:00+00:00',
#  '2005-12-16 00:00:00+00:00',
#  '2006-01-01 00:00:00+00:00',
#  '2006-01-04 00:00:00+00:00',
#  '1988-04-16 00:00:00+00:00',
#  '2003-10-04 00:00:00+00:00',
#  '2001-11-05 00:00:00+00:00',
#  '2000-09-25 00:00:00+00:00',
#  '1998-01-06 00:00:00+00:00',
#  '2005-10-12 00:00:00+00:00',
#  '1995-07-15 00:00:00+00:00',
#  '2006-01-13 00:00:00+00:00',
#  '2006-01-13 00:00:00+00:00',
#  '2005-12-07 00:00:00+00:00',
#  '1986-04-07 00:00:00+00:00',
#  '2006-01-08 00:00:00+00:00',
#  '2005-07-01 00:00:00+00:00',
#  '2003-10-05 00:00:00+00:00',
#  '1999-10-06 00:00:00+00:00',
#  '2003-12-20 00:00:00+00:00',
#  '2001-08-25 00:00:00+00:00',
#  '2003-06-27 00:00:00+00:00',
#  '2002-07-20 00:00:00+00:00',
#  '2000-10-16 00:00:00+00:00',
#  '1994-08-25 00:00:00+00:00',
#  '2004-10-27 00:00:00+00:00',
#  '2001-02-21 00:00:00+00:00',
#  '1992-05-02 00:00:00+00:00',
#  '2004-02-01 00:00:00+00:00',
#  '1998-04-05 00:00:00+00:00',
#  '1999-04-07 00:00:00+00:00',
#  '2000-01-26 00:00:00+00:00',
#  '2006-07-01 00:00:00+00:00',
#  '2001-12-22 00:00:00+00:00',
#  '2005-08-05 00:00:00+00:00',
#  '2003-07-18 00:00:00+00:00',
#  '2002-10-05 00:00:00+00:00',
#  '2005-07-09 00:00:00+00:00',
#  '2004-11-30 00:00:00+00:00',
#  '2005-07-04 00:00:00+00:00',
#  '2002-08-23 00:00:00+00:00',
#  '1995-07-07 00:00:00+00:00',
#  '1993-06-05 00:00:00+00:00',
#  '2003-04-15 00:00:00+00:00',
#  '1991-11-22 00:00:00+00:00',
#  '2003-10-05 00:00:00+00:00',
#  '1998-07-09 00:00:00+00:00',
#  '2004-05-21 00:00:00+00:00',
#  '2002-01-10 00:00:00+00:00',
#  '2003-01-06 00:00:00+00:00',
#  '2003-12-19 00:00:00+00:00',
#  '1998-10-17 00:00:00+00:00',
#  '2004-11-13 00:00:00+00:00',
#  '1996-05-25 00:00:00+00:00',
#  '1999-07-07 00:00:00+00:00',
#  '2003-08-15 00:00:00+00:00',
#  '2001-12-14 00:00:00+00:00',
#  '1998-04-03 00:00:00+00:00',
#  '2004-04-02 00:00:00+00:00',
#  '1999-04-06 00:00:00+00:00',
#  '2004-01-08 00:00:00+00:00',
#  '1999-02-02 00:00:00+00:00',
#  '2005-12-14 00:00:00+00:00',
#  '2004-09-23 00:00:00+00:00',
#  '2005-12-23 00:00:00+00:00',
#  '2004-01-03 00:00:00+00:00',
#  '1997-04-02 00:00:00+00:00',
#  '2002-03-27 00:00:00+00:00',
#  '2004-06-30 00:00:00+00:00',
#  '2004-04-04 00:00:00+00:00',
#  '1995-11-01 00:00:00+00:00',
#  '2004-05-28 00:00:00+00:00',
#  '2002-02-03 00:00:00+00:00',
#  '2002-10-06 00:00:00+00:00',
#  '2003-11-28 00:00:00+00:00',
#  '2004-07-07 00:00:00+00:00',
#  '2005-08-28 00:00:00+00:00',
#  '2005-10-05 00:00:00+00:00',
#  '2001-12-25 00:00:00+00:00',
#  '2000-06-23 00:00:00+00:00',
#  '1997-11-24 00:00:00+00:00',
#  '2005-03-19 00:00:00+00:00',
#  '2000-05-25 00:00:00+00:00',
#  '1993-11-19 00:00:00+00:00',
#  '2006-01-12 00:00:00+00:00',
#  '2005-04-02 00:00:00+00:00',
#  '2004-12-22 00:00:00+00:00',
#  '2005-10-11 00:00:00+00:00',
#  '2006-01-06 00:00:00+00:00',
#  '2005-01-28 00:00:00+00:00',
#  '2001-08-10 00:00:00+00:00',
#  '2000-06-23 00:00:00+00:00',
#  '1998-04-08 00:00:00+00:00',
#  '1998-07-03 00:00:00+00:00',
#  '1996-09-21 00:00:00+00:00',
#  '2004-01-23 00:00:00+00:00',
#  '2001-10-04 00:00:00+00:00',
#  '2002-03-25 00:00:00+00:00',
#  '2003-03-06 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2006-01-26 00:00:00+00:00',
#  '2002-04-06 00:00:00+00:00',
#  '2004-10-03 00:00:00+00:00',
#  '2005-04-22 00:00:00+00:00',
#  '1997-10-06 00:00:00+00:00',
#  '1989-10-16 00:00:00+00:00',
#  '1998-03-27 00:00:00+00:00',
#  '2004-01-12 00:00:00+00:00',
#  '2005-10-02 00:00:00+00:00',
#  '2001-12-25 00:00:00+00:00',
#  '1995-04-02 00:00:00+00:00',
#  '2003-05-03 00:00:00+00:00',
#  '2004-04-28 00:00:00+00:00',
#  '2005-04-04 00:00:00+00:00',
#  '2003-01-13 00:00:00+00:00',
#  '2002-01-05 00:00:00+00:00',
#  '2003-10-16 00:00:00+00:00',
#  '2006-02-03 00:00:00+00:00',
#  '1977-08-06 00:00:00+00:00',
#  '2005-04-10 00:00:00+00:00',
#  '2005-02-05 00:00:00+00:00',
#  '1985-10-20 00:00:00+00:00',
#  '1998-04-21 00:00:00+00:00',
#  '1998-11-30 00:00:00+00:00',
#  '1992-08-01 00:00:00+00:00',
#  '2002-08-16 00:00:00+00:00',
#  '1997-11-01 00:00:00+00:00',
#  '1992-04-25 00:00:00+00:00',
#  '2004-04-23 00:00:00+00:00',
#  '2000-02-14 00:00:00+00:00',
#  '1991-01-12 00:00:00+00:00',
#  '1987-03-29 00:00:00+00:00',
#  '1994-04-01 00:00:00+00:00',
#  '2003-12-01 00:00:00+00:00',
#  '1985-12-21 00:00:00+00:00',
#  '1994-08-12 00:00:00+00:00',
#  '2001-03-03 00:00:00+00:00',
#  '1995-07-14 00:00:00+00:00',
#  '2005-04-03 00:00:00+00:00',
#  '1993-03-06 00:00:00+00:00',
#  '2004-12-20 00:00:00+00:00',
#  '1993-05-05 00:00:00+00:00',
#  '1999-10-08 00:00:00+00:00',
#  '2005-11-23 00:00:00+00:00',
#  '2005-03-31 00:00:00+00:00',
#  '2003-09-26 00:00:00+00:00',
#  '2004-10-02 00:00:00+00:00',
#  '2006-02-03 00:00:00+00:00',
#  '2002-10-02 00:00:00+00:00',
#  '1994-07-21 00:00:00+00:00',
#  '2003-05-25 00:00:00+00:00',
#  '2005-05-22 00:00:00+00:00',
#  '1994-12-15 00:00:00+00:00',
#  '2005-02-25 00:00:00+00:00',
#  '2000-07-22 00:00:00+00:00',
#  '2003-04-19 00:00:00+00:00',
#  '2003-11-08 00:00:00+00:00',
#  '2005-03-30 00:00:00+00:00',
#  '2003-05-24 00:00:00+00:00',
#  '2004-12-18 00:00:00+00:00',
#  '1999-09-04 00:00:00+00:00',
#  '2001-01-06 00:00:00+00:00',
#  '2004-07-16 00:00:00+00:00',
#  '2004-07-01 00:00:00+00:00',
#  '1991-03-21 00:00:00+00:00',
#  '1996-04-10 00:00:00+00:00',
#  '2005-12-10 00:00:00+00:00',
#  '2006-01-22 00:00:00+00:00',
#  '1999-06-25 00:00:00+00:00',
#  '2003-01-09 00:00:00+00:00',
#  '2006-02-10 00:00:00+00:00',
#  '1997-04-19 00:00:00+00:00',
#  '1998-04-18 00:00:00+00:00',
#  '1999-04-17 00:00:00+00:00',
#  '1998-10-04 00:00:00+00:00',
#  '2000-02-05 00:00:00+00:00',
#  '1991-09-27 00:00:00+00:00',
#  '2004-04-13 00:00:00+00:00',
#  '2003-06-25 00:00:00+00:00',
#  '2006-03-03 00:00:00+00:00',
#  '2006-02-25 00:00:00+00:00',
#  '1986-03-15 00:00:00+00:00',
#  '1992-08-01 00:00:00+00:00',
#  '2005-08-20 00:00:00+00:00',
#  '1991-07-14 00:00:00+00:00',
#  '1996-04-20 00:00:00+00:00',
#  '2001-09-19 00:00:00+00:00',
#  '2006-01-09 00:00:00+00:00',
#  '2001-10-12 00:00:00+00:00',
#  '2000-04-26 00:00:00+00:00',
#  '2004-01-01 00:00:00+00:00',
#  '2005-08-20 00:00:00+00:00',
#  '1996-12-21 00:00:00+00:00',
#  '1998-04-06 00:00:00+00:00',
#  '2005-12-09 00:00:00+00:00',
#  '2001-01-09 00:00:00+00:00',
#  '1989-04-26 00:00:00+00:00',
#  '2005-01-29 00:00:00+00:00',
#  '2005-01-29 00:00:00+00:00',
#  '1999-07-05 00:00:00+00:00',
#  '2006-01-08 00:00:00+00:00',
#  '1997-05-21 00:00:00+00:00',
#  '2005-05-18 00:00:00+00:00',
#  '1988-01-08 00:00:00+00:00',
#  '2002-05-15 00:00:00+00:00',
#  '2001-03-22 00:00:00+00:00',
#  '2001-06-25 00:00:00+00:00',
#  '2003-05-23 00:00:00+00:00',
#  '2005-12-02 00:00:00+00:00',
#  '2004-04-09 00:00:00+00:00',
#  '2001-03-21 00:00:00+00:00',
#  '2004-01-22 00:00:00+00:00',
#  '2001-10-03 00:00:00+00:00',
#  '2000-04-04 00:00:00+00:00',
#  '2002-10-08 00:00:00+00:00',
#  '2006-03-23 00:00:00+00:00',
#  '2002-10-04 00:00:00+00:00',
#  '2001-04-04 00:00:00+00:00',
#  '2006-03-24 00:00:00+00:00',
#  '2003-07-07 00:00:00+00:00',
#  '1999-06-25 00:00:00+00:00',
#  '2003-04-12 00:00:00+00:00',
#  '1999-09-07 00:00:00+00:00',
#  '1992-09-11 00:00:00+00:00',
#  '2004-08-07 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '2006-04-03 00:00:00+00:00',
#  '2006-02-22 00:00:00+00:00',
#  '2006-04-03 00:00:00+00:00',
#  '2006-04-01 00:00:00+00:00',
#  '1993-04-01 00:00:00+00:00',
#  '1995-09-10 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2005-10-04 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2006-04-07 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2004-03-01 00:00:00+00:00',
#  '1987-02-07 00:00:00+00:00',
#  '2001-12-22 00:00:00+00:00',
#  '1998-08-01 00:00:00+00:00',
#  '1997-08-02 00:00:00+00:00',
#  '1996-08-03 00:00:00+00:00',
#  '1993-03-26 00:00:00+00:00',
#  '2004-04-09 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2001-04-01 00:00:00+00:00',
#  '2004-08-07 00:00:00+00:00',
#  '1995-04-10 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2006-04-07 00:00:00+00:00',
#  '2002-12-20 00:00:00+00:00',
#  '1993-07-10 00:00:00+00:00',
#  '1994-04-09 00:00:00+00:00',
#  '2004-12-04 00:00:00+00:00',
#  '1985-12-22 00:00:00+00:00',
#  '2006-01-04 00:00:00+00:00',
#  '2002-05-25 00:00:00+00:00',
#  '2000-01-10 00:00:00+00:00',
#  '2006-04-09 00:00:00+00:00',
#  '1997-02-01 00:00:00+00:00',
#  '1987-07-18 00:00:00+00:00',
#  '1988-07-09 00:00:00+00:00',
#  '1996-03-02 00:00:00+00:00',
#  '1989-07-15 00:00:00+00:00',
#  '1990-03-10 00:00:00+00:00',
#  '1990-07-07 00:00:00+00:00',
#  '1991-03-09 00:00:00+00:00',
#  '1991-07-20 00:00:00+00:00',
#  '1992-03-07 00:00:00+00:00',
#  '1992-07-11 00:00:00+00:00',
#  '1993-03-06 00:00:00+00:00',
#  '1993-07-10 00:00:00+00:00',
#  '1994-03-12 00:00:00+00:00',
#  '1994-07-09 00:00:00+00:00',
#  '1995-03-04 00:00:00+00:00',
#  '1995-07-15 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  '2001-04-05 00:00:00+00:00',
#  '2006-04-09 00:00:00+00:00',
#  '2005-08-06 00:00:00+00:00',
#  '1995-01-14 00:00:00+00:00',
#  '2005-10-10 00:00:00+00:00',
#  '1995-04-06 00:00:00+00:00',
#  '2005-11-03 00:00:00+00:00',
#  '2006-04-16 00:00:00+00:00',
#  '1989-02-22 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2003-06-06 00:00:00+00:00',
#  '2004-09-10 00:00:00+00:00',
#  '1988-04-12 00:00:00+00:00',
#  '1987-07-03 00:00:00+00:00',
#  '1989-03-14 00:00:00+00:00',
#  '2004-01-09 00:00:00+00:00',
#  '2005-01-08 00:00:00+00:00',
#  '1983-02-05 00:00:00+00:00',
#  '1980-05-08 00:00:00+00:00',
#  '2004-09-30 00:00:00+00:00',
#  '2006-03-20 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2005-08-06 00:00:00+00:00',
#  '1988-04-21 00:00:00+00:00',
#  '2000-12-21 00:00:00+00:00',
#  '2006-04-06 00:00:00+00:00',
#  '2006-04-04 00:00:00+00:00',
#  '2006-04-08 00:00:00+00:00',
#  '2006-04-09 00:00:00+00:00',
#  '2006-04-14 00:00:00+00:00',
#  '1988-10-07 00:00:00+00:00',
#  '2005-10-25 00:00:00+00:00',
#  '1990-01-07 00:00:00+00:00',
#  '2001-07-05 00:00:00+00:00',
#  '2006-04-14 00:00:00+00:00',
#  '1976-04-01 00:00:00+00:00',
#  '2006-04-08 00:00:00+00:00',
#  '2002-10-02 00:00:00+00:00',
#  '2001-04-11 00:00:00+00:00',
#  '2005-01-30 00:00:00+00:00',
#  '1995-10-09 00:00:00+00:00',
#  '2006-04-03 00:00:00+00:00',
#  '2001-05-02 00:00:00+00:00',
#  '2004-03-09 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '1992-04-13 00:00:00+00:00',
#  '1984-10-11 00:00:00+00:00',
#  '2006-04-02 00:00:00+00:00',
#  '2006-04-29 00:00:00+00:00',
#  '1991-10-18 00:00:00+00:00',
#  '2003-04-06 00:00:00+00:00',
#  '2002-05-25 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2004-01-16 00:00:00+00:00',
#  '1998-05-21 00:00:00+00:00',
#  '2002-12-18 00:00:00+00:00',
#  '1996-12-18 00:00:00+00:00',
#  '1998-08-25 00:00:00+00:00',
#  '1999-12-22 00:00:00+00:00',
#  '2002-07-04 00:00:00+00:00',
#  '2005-06-20 00:00:00+00:00',
#  '2002-05-25 00:00:00+00:00',
#  '2004-07-03 00:00:00+00:00',
#  '1993-07-23 00:00:00+00:00',
#  '1993-02-24 00:00:00+00:00',
#  '1990-10-17 00:00:00+00:00',
#  '1997-03-26 00:00:00+00:00',
#  '2005-05-07 00:00:00+00:00',
#  '2005-01-29 00:00:00+00:00',
#  '2006-05-18 00:00:00+00:00',
#  '2001-11-09 00:00:00+00:00',
#  '1999-04-08 00:00:00+00:00',
#  '1999-12-22 00:00:00+00:00',
#  '2006-03-24 00:00:00+00:00',
#  '2006-03-24 00:00:00+00:00',
#  '1996-03-09 00:00:00+00:00',
#  '1994-12-04 00:00:00+00:00',
#  '1994-10-05 00:00:00+00:00',
#  '1996-07-24 00:00:00+00:00',
#  '1978-03-14 00:00:00+00:00',
#  '2006-04-26 00:00:00+00:00',
#  '2004-10-03 00:00:00+00:00',
#  '2005-04-01 00:00:00+00:00',
#  '2002-04-19 00:00:00+00:00',
#  '2001-04-03 00:00:00+00:00',
#  '1996-04-20 00:00:00+00:00',
#  '1993-10-21 00:00:00+00:00',
#  '1994-12-16 00:00:00+00:00',
#  '1993-12-23 00:00:00+00:00',
#  '1994-08-20 00:00:00+00:00',
#  '1995-09-21 00:00:00+00:00',
#  '1998-04-02 00:00:00+00:00',
#  '2006-07-02 00:00:00+00:00',
#  '2003-08-21 00:00:00+00:00',
#  '2006-05-26 00:00:00+00:00',
#  '1993-06-21 00:00:00+00:00',
#  '1998-10-03 00:00:00+00:00',
#  '1999-10-02 00:00:00+00:00',
#  '2002-01-07 00:00:00+00:00',
#  '2004-07-28 00:00:00+00:00',
#  '1999-04-20 00:00:00+00:00',
#  '1998-10-07 00:00:00+00:00',
#  '2004-01-23 00:00:00+00:00',
#  '1999-11-25 00:00:00+00:00',
#  '1999-07-08 00:00:00+00:00',
#  '1997-10-25 00:00:00+00:00',
#  '1998-05-25 00:00:00+00:00',
#  '2001-07-21 00:00:00+00:00',
#  '1991-07-20 00:00:00+00:00',
#  '1994-06-13 00:00:00+00:00',
#  '2006-04-08 00:00:00+00:00',
#  '1990-03-21 00:00:00+00:00',
#  '2002-09-14 00:00:00+00:00',
#  '1987-03-14 00:00:00+00:00',
#  '2005-06-07 00:00:00+00:00',
#  '1998-12-19 00:00:00+00:00',
#  '2003-05-08 00:00:00+00:00',
#  '2002-08-23 00:00:00+00:00',
#  '2003-04-25 00:00:00+00:00',
#  '1996-04-04 00:00:00+00:00',
#  '1992-07-29 00:00:00+00:00',
#  '1996-12-04 00:00:00+00:00',
#  '1992-10-21 00:00:00+00:00',
#  '1968-07-21 00:00:00+00:00',
#  '1996-10-04 00:00:00+00:00',
#  '1997-10-02 00:00:00+00:00',
#  '1995-06-29 00:00:00+00:00',
#  '2001-04-04 00:00:00+00:00',
#  '1982-01-23 00:00:00+00:00',
#  '2003-11-08 00:00:00+00:00',
#  '1998-10-25 00:00:00+00:00',
#  '1999-07-23 00:00:00+00:00',
#  '2004-02-24 00:00:00+00:00',
#  '2003-10-24 00:00:00+00:00',
#  '2001-08-02 00:00:00+00:00',
#  '1999-10-05 00:00:00+00:00',
#  '2003-11-19 00:00:00+00:00',
#  '1996-05-21 00:00:00+00:00',
#  '1999-08-01 00:00:00+00:00',
#  '1999-07-09 00:00:00+00:00',
#  '2001-09-25 00:00:00+00:00',
#  '1985-03-24 00:00:00+00:00',
#  '2006-01-25 00:00:00+00:00',
#  '2006-05-19 00:00:00+00:00',
#  '1976-04-17 00:00:00+00:00',
#  '1977-06-04 00:00:00+00:00',
#  '2006-04-05 00:00:00+00:00',
#  '2006-03-29 00:00:00+00:00',
#  '2002-03-02 00:00:00+00:00',
#  '2005-12-22 00:00:00+00:00',
#  '2004-11-24 00:00:00+00:00',
#  '1991-02-20 00:00:00+00:00',
#  '2000-07-15 00:00:00+00:00',
#  '1995-02-25 00:00:00+00:00',
#  '2002-08-25 00:00:00+00:00',
#  '2002-12-21 00:00:00+00:00',
#  '2004-01-16 00:00:00+00:00',
#  '2003-04-06 00:00:00+00:00',
#  '2002-12-09 00:00:00+00:00',
#  '2004-03-25 00:00:00+00:00',
#  '2004-04-01 00:00:00+00:00',
#  '1987-04-06 00:00:00+00:00',
#  '1982-10-03 00:00:00+00:00',
#  '1984-07-07 00:00:00+00:00',
#  '1981-03-14 00:00:00+00:00',
#  '1981-07-11 00:00:00+00:00',
#  '1982-03-13 00:00:00+00:00',
#  '1988-10-17 00:00:00+00:00',
#  '2000-12-20 00:00:00+00:00',
#  '1989-07-15 00:00:00+00:00',
#  '1993-08-07 00:00:00+00:00',
#  '2003-01-04 00:00:00+00:00',
#  '2001-07-30 00:00:00+00:00',
#  '2004-02-10 00:00:00+00:00',
#  ...]

# %%
df_anime['favorites'].tolist()
# Out:
# [86816,
#  1712,
#  16908,
#  674,
#  16,
#  2079,
#  4184,
#  244,
#  1386,
#  58262,
#  83595,
#  239752,
#  3052,
#  3,
#  5318,
#  864,
#  5416,
#  1381,
#  929,
#  199,
#  112674,
#  769,
#  30901,
#  30104,
#  13741,
#  6394,
#  10266,
#  98,
#  14506,
#  1445,
#  261,
#  1155,
#  186,
#  323,
#  474,
#  187,
#  14,
#  22,
#  8893,
#  447,
#  4201,
#  1949,
#  1289,
#  196,
#  362,
#  2072,
#  472,
#  8705,
#  1445,
#  1820,
#  14,
#  4428,
#  2989,
#  1299,
#  1499,
#  277,
#  1067,
#  1017,
#  1470,
#  2470,
#  1174,
#  1147,
#  5,
#  268,
#  2482,
#  192,
#  541,
#  85,
#  152,
#  2421,
#  180,
#  231,
#  3684,
#  1139,
#  1161,
#  1071,
#  1901,
#  1142,
#  313,
#  454,
#  2681,
#  558,
#  100,
#  495,
#  46,
#  824,
#  214,
#  26,
#  239,
#  124,
#  65,
#  4,
#  126,
#  1723,
#  10,
#  41,
#  108,
#  6,
#  50,
#  9796,
#  26434,
#  1877,
#  2143,
#  38,
#  26,
#  83,
#  63,
#  21,
#  798,
#  122,
#  49,
#  900,
#  230,
#  1214,
#  2507,
#  11718,
#  435,
#  313,
#  253,
#  11,
#  554,
#  720,
#  222,
#  2814,
#  163,
#  1082,
#  10,
#  1295,
#  4464,
#  201,
#  137,
#  2590,
#  3727,
#  144,
#  772,
#  504,
#  717,
#  42,
#  1235,
#  277,
#  90,
#  19,
#  23356,
#  994,
#  720,
#  431,
#  680,
#  687,
#  7802,
#  8,
#  171,
#  624,
#  49,
#  7,
#  2056,
#  143,
#  3,
#  439,
#  119,
#  2243,
#  80,
#  47,
#  13322,
#  1170,
#  712,
#  10,
#  1510,
#  88,
#  48,
#  20,
#  232,
#  124,
#  990,
#  187,
#  49,
#  621,
#  34304,
#  153,
#  149,
#  5851,
#  38,
#  34,
#  39836,
#  141,
#  763,
#  356,
#  434,
#  4543,
#  11,
#  149,
#  3,
#  3,
#  2,
#  1,
#  13,
#  495,
#  34,
#  12,
#  111,
#  76,
#  17304,
#  2218,
#  24611,
#  32080,
#  3279,
#  136,
#  154,
#  7,
#  14305,
#  257,
#  3,
#  15545,
#  26,
#  9217,
#  270,
#  3998,
#  1504,
#  334,
#  272,
#  1126,
#  26,
#  27750,
#  382,
#  118,
#  259,
#  19539,
#  1328,
#  1383,
#  158,
#  430,
#  22,
#  14,
#  543,
#  447,
#  39,
#  14,
#  36,
#  8,
#  7,
#  23993,
#  265,
#  226,
#  25,
#  2481,
#  6436,
#  79473,
#  6420,
#  29,
#  887,
#  33,
#  251,
#  13,
#  212,
#  50,
#  28,
#  142,
#  14,
#  10,
#  88,
#  929,
#  66,
#  87,
#  38,
#  886,
#  417,
#  39,
#  476,
#  35,
#  52,
#  236,
#  14,
#  11,
#  56,
#  83,
#  137,
#  34,
#  98,
#  10,
#  638,
#  27,
#  99,
#  9,
#  375,
#  4,
#  72,
#  8,
#  1,
#  109,
#  10,
#  11,
#  34,
#  6,
#  21,
#  1105,
#  38,
#  7,
#  374,
#  17,
#  5043,
#  6003,
#  479,
#  905,
#  464,
#  96,
#  12,
#  4021,
#  664,
#  77,
#  6,
#  48,
#  618,
#  184,
#  30,
#  12,
#  3283,
#  31100,
#  137,
#  303,
#  38,
#  284,
#  71,
#  369,
#  15,
#  14,
#  63,
#  6,
#  776,
#  124,
#  159,
#  302,
#  4,
#  4970,
#  7461,
#  941,
#  70,
#  6,
#  1,
#  4,
#  2,
#  1,
#  61,
#  67,
#  77,
#  6,
#  584,
#  1218,
#  21,
#  208,
#  493,
#  36,
#  10,
#  12,
#  265,
#  36,
#  5,
#  1024,
#  53,
#  42,
#  89,
#  207,
#  2482,
#  198,
#  33,
#  8555,
#  319,
#  320,
#  658,
#  42,
#  24072,
#  232,
#  87,
#  443,
#  278,
#  127,
#  60,
#  2,
#  2257,
#  383,
#  1,
#  41,
#  174,
#  277,
#  19,
#  269,
#  130,
#  368,
#  130,
#  296,
#  114,
#  2357,
#  129,
#  27,
#  206,
#  78,
#  27,
#  1,
#  2,
#  242,
#  11,
#  20,
#  1331,
#  13,
#  31,
#  670,
#  30819,
#  139,
#  741,
#  11,
#  594,
#  20768,
#  16,
#  11,
#  9212,
#  716,
#  321,
#  55,
#  92,
#  16,
#  22,
#  149,
#  35,
#  166,
#  265,
#  221,
#  185,
#  20,
#  302,
#  62,
#  27761,
#  21,
#  441,
#  39,
#  31,
#  74,
#  39,
#  500,
#  21,
#  15,
#  8806,
#  1116,
#  786,
#  38,
#  44,
#  83,
#  7,
#  481,
#  7,
#  158,
#  2320,
#  366,
#  919,
#  5084,
#  1748,
#  143,
#  20,
#  51,
#  7337,
#  139,
#  1057,
#  285,
#  465,
#  24,
#  41,
#  47,
#  27,
#  111,
#  14,
#  76,
#  139,
#  43,
#  3,
#  47,
#  82,
#  45,
#  83,
#  287,
#  104,
#  6,
#  2,
#  6387,
#  4632,
#  424,
#  11,
#  1308,
#  106,
#  47,
#  106,
#  24,
#  1027,
#  684,
#  8977,
#  8,
#  50,
#  165,
#  5625,
#  453,
#  609,
#  10829,
#  272,
#  1504,
#  21,
#  2029,
#  865,
#  26,
#  22,
#  90,
#  602,
#  93,
#  49,
#  3054,
#  61,
#  3,
#  11,
#  1,
#  78,
#  1345,
#  292,
#  5614,
#  389,
#  71,
#  13,
#  3,
#  6,
#  309,
#  3,
#  26,
#  66,
#  2,
#  115,
#  114,
#  169,
#  85,
#  1025,
#  209,
#  590,
#  2129,
#  7,
#  5766,
#  218,
#  1,
#  43,
#  18,
#  8764,
#  118,
#  37,
#  18,
#  136,
#  734,
#  5517,
#  300,
#  495,
#  12,
#  863,
#  27,
#  82,
#  2,
#  345,
#  132,
#  6,
#  62,
#  1658,
#  71,
#  9,
#  14,
#  1065,
#  12,
#  390,
#  64,
#  50,
#  87,
#  21,
#  5,
#  20,
#  66,
#  27,
#  8,
#  32,
#  11,
#  92,
#  25,
#  1285,
#  115,
#  7,
#  90,
#  112,
#  5,
#  23,
#  39,
#  0,
#  15,
#  1421,
#  33,
#  32,
#  3,
#  2,
#  90,
#  467,
#  38,
#  18,
#  34,
#  9,
#  5,
#  42,
#  39,
#  13,
#  3,
#  8,
#  17,
#  603,
#  16,
#  12,
#  19,
#  3,
#  9,
#  38,
#  1386,
#  29,
#  6,
#  7,
#  36,
#  377,
#  1908,
#  186,
#  16,
#  6,
#  74,
#  18,
#  14,
#  7,
#  1,
#  7,
#  68,
#  13,
#  1,
#  26,
#  1,
#  3,
#  6,
#  1,
#  1729,
#  75,
#  6,
#  189,
#  137,
#  2,
#  6,
#  48,
#  0,
#  664,
#  4,
#  2,
#  9,
#  3,
#  85,
#  329,
#  320,
#  5,
#  33,
#  120,
#  24,
#  10,
#  12,
#  414,
#  5261,
#  14,
#  9,
#  48,
#  2,
#  23,
#  15,
#  7,
#  1042,
#  432,
#  22,
#  7,
#  23,
#  316,
#  891,
#  177,
#  571,
#  21,
#  126,
#  74,
#  4,
#  1,
#  145,
#  56,
#  2,
#  12,
#  15,
#  49,
#  48,
#  3,
#  20,
#  2849,
#  15,
#  94,
#  241,
#  291,
#  158,
#  1,
#  13,
#  5,
#  12,
#  238,
#  21,
#  8,
#  15,
#  22907,
#  116,
#  77,
#  87,
#  68,
#  20,
#  124,
#  19,
#  68,
#  88,
#  14352,
#  14,
#  21,
#  125,
#  1209,
#  3,
#  5,
#  52,
#  20,
#  201,
#  3227,
#  64,
#  13,
#  5,
#  62,
#  209,
#  40730,
#  29,
#  27,
#  26,
#  11,
#  18,
#  99,
#  17105,
#  116,
#  88,
#  16,
#  5,
#  25,
#  21,
#  1,
#  118,
#  130,
#  6,
#  19,
#  158,
#  11,
#  93,
#  43,
#  73,
#  2,
#  28,
#  69,
#  40,
#  3,
#  454,
#  815,
#  2,
#  15481,
#  171,
#  471,
#  426,
#  35942,
#  21,
#  1902,
#  1194,
#  3712,
#  3,
#  339,
#  146,
#  4740,
#  73,
#  13,
#  12,
#  8,
#  11,
#  18,
#  26,
#  108,
#  89,
#  234,
#  2012,
#  1201,
#  125,
#  33206,
#  172,
#  439,
#  167,
#  7,
#  77,
#  39,
#  23,
#  3774,
#  42,
#  1,
#  53,
#  20022,
#  369,
#  47,
#  26,
#  53,
#  53,
#  37,
#  62,
#  28,
#  104,
#  29,
#  34,
#  210,
#  63,
#  52,
#  29,
#  198,
#  125,
#  274,
#  92,
#  15,
#  16,
#  7,
#  30,
#  7,
#  140,
#  258,
#  107,
#  87,
#  60661,
#  17,
#  4,
#  10,
#  7,
#  9,
#  13,
#  16,
#  38,
#  52,
#  132,
#  7,
#  120,
#  21707,
#  593,
#  175,
#  47,
#  27,
#  202,
#  142,
#  51,
#  15,
#  94,
#  2873,
#  17,
#  119,
#  8,
#  372,
#  5,
#  1174,
#  73,
#  38,
#  5,
#  49,
#  821,
#  13,
#  1,
#  5,
#  1347,
#  2373,
#  4,
#  406,
#  47,
#  168,
#  73,
#  20,
#  692,
#  455,
#  61,
#  14,
#  389,
#  27,
#  11,
#  8,
#  7,
#  1,
#  14,
#  213,
#  160,
#  86,
#  2,
#  2,
#  88,
#  10,
#  69,
#  8,
#  2,
#  64,
#  1271,
#  127,
#  136,
#  2,
#  358,
#  1,
#  891,
#  44,
#  301,
#  31,
#  48,
#  87,
#  36,
#  7,
#  7,
#  24,
#  1,
#  259,
#  6,
#  98,
#  293,
#  183,
#  25,
#  82,
#  29,
#  109,
#  31,
#  400,
#  19,
#  129,
#  6,
#  3,
#  61,
#  1310,
#  352,
#  3,
#  15,
#  2866,
#  311,
#  2,
#  4,
#  18,
#  3,
#  4,
#  18,
#  37,
#  32,
#  39,
#  15,
#  52,
#  13,
#  106,
#  83,
#  29,
#  1156,
#  290,
#  2,
#  3,
#  102,
#  4,
#  10,
#  1,
#  12,
#  379,
#  93,
#  68,
#  606,
#  24,
#  38,
#  14,
#  83,
#  9,
#  2,
#  189,
#  99,
#  12,
#  4,
#  36,
#  145,
#  204,
#  43,
#  33,
#  3,
#  7,
#  21,
#  31,
#  653,
#  1843,
#  783,
#  122,
#  55,
#  172,
#  38,
#  24,
#  278,
#  903,
#  12,
#  11,
#  4,
#  ...]

# %% [markdown]
# **Formatando as datas**
#
# Percebemos que as datas estão no formato data e hora e não utilizaremos a hora para nenhuma análise. Iremos retirar e deixarmos no formato somente de data.

# %%
# Converter 'aired_from' e 'aired_to' para datetime, mantendo apenas a data
df_anime['aired_from'] = pd.to_datetime(df_anime['aired_from'], errors='coerce')
df_anime['aired_to'] = pd.to_datetime(df_anime['aired_to'], errors='coerce')

# %%
# Exibir as primeiras linhas para verificar a transformação
df_anime[['aired_from', 'aired_to']].head()
# Out:
#                  aired_from                  aired_to
# 0 1998-04-03 00:00:00+00:00 1999-04-24 00:00:00+00:00
# 1 2001-09-01 00:00:00+00:00                       NaT
# 2 1998-04-01 00:00:00+00:00 1998-09-30 00:00:00+00:00
# 3 2002-07-03 00:00:00+00:00 2002-12-25 00:00:00+00:00
# 4 2004-09-30 00:00:00+00:00 2005-09-29 00:00:00+00:00

# %%
# Encontrar a data mínima e máxima nas colunas 'aired_from' e 'aired_to'
min_aired_from = df_anime['aired_from'].min().strftime('%d/%m/%Y')
max_aired_from = df_anime['aired_from'].max().strftime('%d/%m/%Y')
min_aired_to = df_anime['aired_to'].min().strftime('%d/%m/%Y')
max_aired_to = df_anime['aired_to'].max().strftime('%d/%m/%Y')

print(f"Range da data de início de exibição (aired_from): {min_aired_from} a {max_aired_from}")
print(f"Range da data de fim de exibição (aired_to): {min_aired_to} a {max_aired_to}")
# Out:
# Range da data de início de exibição (aired_from): 01/01/1926 a 01/01/2027
# Range da data de fim de exibição (aired_to): 24/11/1965 a 10/04/2026

# %% [markdown]
#  **Formatação de gêneros**

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                  aired_from                  aired_to  \
# 0 1998-04-03 00:00:00+00:00 1999-04-24 00:00:00+00:00
# 1 2001-09-01 00:00:00+00:00                       NaT
# 2 1998-04-01 00:00:00+00:00 1998-09-30 00:00:00+00:00
# 3 2002-07-03 00:00:00+00:00 2002-12-25 00:00:00+00:00
# 4 2004-09-30 00:00:00+00:00 2005-09-29 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# 1       1.0  R - 17+ (violence & profanity)   216.0         643   398998
# 2      26.0       PG-13 - Teens 13 or older   385.0         261   805264
# 3      26.0       PG-13 - Teens 13 or older  3272.0        1958   123821
# 4      52.0                   PG - Children  4816.0        5680    16325
#
#    favorites  score  scored_by                                genres  \
# 0      86816   8.75  1022817.0         Action, Award Winning, Sci-Fi
# 1       1712   8.38   225855.0                        Action, Sci-Fi
# 2      16908   8.22   389888.0             Action, Adventure, Sci-Fi
# 3        674   7.23    45420.0  Action, Drama, Mystery, Supernatural
# 4         16   6.92     6969.0            Action, Adventure, Fantasy
#
#               themes demographics
# 0  Adult Cast, Space          NaN
# 1  Adult Cast, Space          NaN
# 2         Adult Cast      Shounen
# 3          Detective          NaN
# 4                NaN      Shounen

# %%
# Verificar os valores únicos na coluna 'genres' e sua contagem
print("Contagem de valores na coluna 'genres':")
display(df_anime['genres'].value_counts())

# Opcional: Ver os valores únicos (sem contagem)
#print("\nValores únicos na coluna 'genres':")
#display(df['genres'].unique())
# Out:
# Contagem de valores na coluna 'genres':
# genres
# Comedy                                                             2701
# Fantasy                                                            1488
# Hentai                                                             1296
# Slice of Life                                                       842
# Avant Garde                                                         808
#                                                                    ...
# Avant Garde, Award Winning, Supernatural                              1
# Action, Fantasy, Suspense                                             1
# Comedy, Romance, Suspense                                             1
# Avant Garde, Comedy, Supernatural                                     1
# Action, Adventure, Comedy, Drama, Mystery, Sci-Fi, Supernatural       1
# Name: count, Length: 936, dtype: int64

# %%
# Lidar com valores ausentes na coluna 'genres' preenchendo com uma string vazia para evitar erros ao splitar
df_anime['genres'] = df_anime['genres'].fillna('')

# Separar os gêneros em listas
df_anime['genres'] = df_anime['genres'].str.split(', ')

# Exibir as primeiras linhas para verificar a nova coluna
print("DataFrame com a coluna 'genres' como lista:")
display(df_anime['genres'].head())
# Out:
# DataFrame com a coluna 'genres' como lista:
# 0           [Action, Award Winning, Sci-Fi]
# 1                          [Action, Sci-Fi]
# 2               [Action, Adventure, Sci-Fi]
# 3    [Action, Drama, Mystery, Supernatural]
# 4              [Action, Adventure, Fantasy]
# Name: genres, dtype: object

# %%
# Se quiser manter a coluna com os gêneros filtrados e sem strings vazias:
df_anime['genres'] = df_anime['genres'].apply(lambda gs: [g for g in gs if g != ''])

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                  aired_from                  aired_to  \
# 0 1998-04-03 00:00:00+00:00 1999-04-24 00:00:00+00:00
# 1 2001-09-01 00:00:00+00:00                       NaT
# 2 1998-04-01 00:00:00+00:00 1998-09-30 00:00:00+00:00
# 3 2002-07-03 00:00:00+00:00 2002-12-25 00:00:00+00:00
# 4 2004-09-30 00:00:00+00:00 2005-09-29 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# 1       1.0  R - 17+ (violence & profanity)   216.0         643   398998
# 2      26.0       PG-13 - Teens 13 or older   385.0         261   805264
# 3      26.0       PG-13 - Teens 13 or older  3272.0        1958   123821
# 4      52.0                   PG - Children  4816.0        5680    16325
#
#    favorites  score  scored_by                                  genres  \
# 0      86816   8.75  1022817.0         [Action, Award Winning, Sci-Fi]
# 1       1712   8.38   225855.0                        [Action, Sci-Fi]
# 2      16908   8.22   389888.0             [Action, Adventure, Sci-Fi]
# 3        674   7.23    45420.0  [Action, Drama, Mystery, Supernatural]
# 4         16   6.92     6969.0            [Action, Adventure, Fantasy]
#
#               themes demographics
# 0  Adult Cast, Space          NaN
# 1  Adult Cast, Space          NaN
# 2         Adult Cast      Shounen
# 3          Detective          NaN
# 4                NaN      Shounen

# %% [markdown]
# **Formatação dos temas**

# %%
# Lidar com valores ausentes na coluna 'genres' preenchendo com uma string vazia para evitar erros ao splitar
df_anime['themes'] = df_anime['themes'].fillna('')

# Separar os gêneros em listas
df_anime['themes'] = df_anime['themes'].str.split(', ')

# Exibir as primeiras linhas para verificar a nova coluna
print("DataFrame com a coluna 'genres' como lista:")
display(df_anime['themes'].head())
# Out:
# DataFrame com a coluna 'genres' como lista:
# 0    [Adult Cast, Space]
# 1    [Adult Cast, Space]
# 2           [Adult Cast]
# 3            [Detective]
# 4                     []
# Name: themes, dtype: object

# %%
# Se quiser manter a coluna com os gêneros filtrados e sem strings vazias:
df_anime['themes'] = df_anime['themes'].apply(lambda gs: [g for g in gs if g != ''])

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
#                  aired_from                  aired_to  \
# 0 1998-04-03 00:00:00+00:00 1999-04-24 00:00:00+00:00
# 1 2001-09-01 00:00:00+00:00                       NaT
# 2 1998-04-01 00:00:00+00:00 1998-09-30 00:00:00+00:00
# 3 2002-07-03 00:00:00+00:00 2002-12-25 00:00:00+00:00
# 4 2004-09-30 00:00:00+00:00 2005-09-29 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# 1       1.0  R - 17+ (violence & profanity)   216.0         643   398998
# 2      26.0       PG-13 - Teens 13 or older   385.0         261   805264
# 3      26.0       PG-13 - Teens 13 or older  3272.0        1958   123821
# 4      52.0                   PG - Children  4816.0        5680    16325
#
#    favorites  score  scored_by                                  genres  \
# 0      86816   8.75  1022817.0         [Action, Award Winning, Sci-Fi]
# 1       1712   8.38   225855.0                        [Action, Sci-Fi]
# 2      16908   8.22   389888.0             [Action, Adventure, Sci-Fi]
# 3        674   7.23    45420.0  [Action, Drama, Mystery, Supernatural]
# 4         16   6.92     6969.0            [Action, Adventure, Fantasy]
#
#                 themes demographics
# 0  [Adult Cast, Space]          NaN
# 1  [Adult Cast, Space]          NaN
# 2         [Adult Cast]      Shounen
# 3          [Detective]          NaN
# 4                   []      Shounen

# %% [markdown]
# **Observações sobre a qualidade dos dados**
#
# Durante a análise exploratória, foi identificado que algumas colunas possuem um número substancial de valores ausentes. As colunas 'aired_from', 'aired_to', 'release_year', 'title_english', 'demographics', 'themes', 'genres', 'score', 'scored_by' e 'rank' são as que mais demandam estratefias de tratamento de dados faltantes que vai depender dos objetivos da análise.

# %%
df_anime[['score', 'scored_by', 'rank']].describe()
# Out:
#               score     scored_by          rank
# count  18681.000000  1.868100e+04  22361.000000
# mean       6.397942  2.994750e+04  10671.669916
# std        0.890524  1.215179e+05   6433.922127
# min        1.890000  1.010000e+02      0.000000
# 25%        5.780000  3.400000e+02   5088.000000
# 50%        6.370000  1.549000e+03  10675.000000
# 75%        7.030000  1.013800e+04  16293.000000
# max        9.300000  2.952092e+06  21863.000000

# %% [markdown]
# Olhando para a média (6.39) e a mediana (50% é igual 6.37), elas são bem próximas. Isso sugere que a distribuição da coluna 'score' pode não ter muitos outliers extremos que distorceriam a média significantivamente. No entando, a coluna 'scored_by' (número de usuários que avaliaram), que está relacionada, tem uma grande diferença entre a média e a mediana, indicando outiliers.
#
# Para a coluna **'score'**, a **mediana** pode ser uma escolha ligeiramente mais segura para imputação, caso existam alguns outliers que não sejam imediantamente aparentes apenas pela média e mediana próximas.

# %%
median_score = df_anime['score'].median()
df_anime['score'].fillna(median_score, inplace=True)
# Out:
# /tmp/ipython-input-3514667688.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_anime['score'].fillna(median_score, inplace=True)

# %%
# Verificar se ainda existem valores ausentes na coluna 'score'
print("Número de valores ausentes na coluna 'score' após a imputação:")
df_anime['score'].isnull().sum()
# Out:
# Número de valores ausentes na coluna 'score' após a imputação:
# np.int64(0)

# %%
#fazer mais um dataset com as colunas que iremos utilizar
df_anime_v2 = df_anime[['title', 'aired_from', 'synopsis', 'status', 'episodes', 'rating', 'rank', 'popularity', 'members', 'favorites', 'score', 'scored_by', 'genres', 'themes', 'demographics']]
df_anime_v2.head()
# Out:
#                              title                aired_from  \
# 0                     Cowboy Bebop 1998-04-03 00:00:00+00:00
# 1  Cowboy Bebop: Tengoku no Tobira 2001-09-01 00:00:00+00:00
# 2                           Trigun 1998-04-01 00:00:00+00:00
# 3               Witch Hunter Robin 2002-07-03 00:00:00+00:00
# 4                   Bouken Ou Beet 2004-09-30 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# 1       1.0  R - 17+ (violence & profanity)   216.0         643   398998
# 2      26.0       PG-13 - Teens 13 or older   385.0         261   805264
# 3      26.0       PG-13 - Teens 13 or older  3272.0        1958   123821
# 4      52.0                   PG - Children  4816.0        5680    16325
#
#    favorites  score  scored_by                                  genres  \
# 0      86816   8.75  1022817.0         [Action, Award Winning, Sci-Fi]
# 1       1712   8.38   225855.0                        [Action, Sci-Fi]
# 2      16908   8.22   389888.0             [Action, Adventure, Sci-Fi]
# 3        674   7.23    45420.0  [Action, Drama, Mystery, Supernatural]
# 4         16   6.92     6969.0            [Action, Adventure, Fantasy]
#
#                 themes demographics
# 0  [Adult Cast, Space]          NaN
# 1  [Adult Cast, Space]          NaN
# 2         [Adult Cast]      Shounen
# 3          [Detective]          NaN
# 4                   []      Shounen

# %%
df_anime_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29153 entries, 0 to 29152
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         29153 non-null  object
#  1   aired_from    4123 non-null   datetime64[ns, UTC]
#  2   synopsis      23970 non-null  object
#  3   status        29153 non-null  object
#  4   episodes      29153 non-null  float64
#  5   rating        28467 non-null  object
#  6   rank          22361 non-null  float64
#  7   popularity    29153 non-null  int64
#  8   members       29153 non-null  int64
#  9   favorites     29153 non-null  int64
#  10  score         29153 non-null  float64
#  11  scored_by     18681 non-null  float64
#  12  genres        29153 non-null  object
#  13  themes        29153 non-null  object
#  14  demographics  10788 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(3), object(7)
# memory usage: 3.3+ MB

# %% [markdown]
# **Removendo valores do dataset**
#
# Durante a fase de limpeza e pré-processamento do dataset de animes, identificamos que a coluna 'demographics' apresentava uma quantidade significativa de valores ausentes, correspondendo a aproximadamente 63% do total de entradas. Considerando os objetivos deste projeto, que incluem a análise de características e tendências dos animes, a informação demográfica é um atributo potencialmente relevante para segmentar e compreender o público-alvo de diferentes títulos.
#
# Diante da alta taxa de dados faltantes e da natureza categórica da coluna 'demographics', optamos pela estratégia de remover as linhas que possuíam valores nulos especificamente nesta coluna.
#
# Portanto, a remoção das linhas com valores ausentes na coluna 'demographics' foi uma escolha deliberada para garantir a qualidade e a validade das análises que envolvem este atributo crucial, priorizando a integridade da informação demográfica para os animes onde ela está disponível, sem comprometer a viabilidade do projeto em termos de volume de dados

# %%
# Remover linhas com valores ausentes na coluna 'demographics'
df_anime_filtered_demographics = df_anime_v2.dropna(subset=['demographics']).copy()

# Verificar o número de linhas restantes
print(f"Número de linhas após remover NaNs em 'demographics': {len(df_anime_filtered_demographics)}")

# Verificar se ainda existem valores ausentes na coluna 'demographics'
print("\nNúmero de valores ausentes na coluna 'demographics' no novo DataFrame:")
display(df_anime_filtered_demographics['demographics'].isnull().sum())

# Exibir as primeiras linhas do novo DataFrame
display(df_anime_filtered_demographics.head())
# Out:
# Número de linhas após remover NaNs em 'demographics': 10788
#
# Número de valores ausentes na coluna 'demographics' no novo DataFrame:
# np.int64(0)
#                         title                aired_from  \
# 2                      Trigun 1998-04-01 00:00:00+00:00
# 4              Bouken Ou Beet 2004-09-30 00:00:00+00:00
# 5                Eyeshield 21 2005-04-06 00:00:00+00:00
# 6        Hachimitsu to Clover 2005-04-15 00:00:00+00:00
# 7  Hungry Heart: Wild Striker 2002-09-11 00:00:00+00:00
#
#                                             synopsis           status  \
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
# 5  Shy, reserved, and small-statured, Deimon High...  Finished Airing
# 6  Yuuta Takemoto, a sophomore at an arts college...  Finished Airing
# 7  As the younger brother of Japanese soccer star...  Finished Airing
#
#    episodes                     rating    rank  popularity  members  \
# 2      26.0  PG-13 - Teens 13 or older   385.0         261   805264
# 4      52.0              PG - Children  4816.0        5680    16325
# 5     145.0  PG-13 - Teens 13 or older   826.0        1366   192054
# 6      24.0  PG-13 - Teens 13 or older   704.0         945   279311
# 7      52.0  PG-13 - Teens 13 or older  1874.0        4699    26265
#
#    favorites  score  scored_by                        genres  \
# 2      16908   8.22   389888.0   [Action, Adventure, Sci-Fi]
# 4         16   6.92     6969.0  [Action, Adventure, Fantasy]
# 5       2079   7.91    91983.0                      [Sports]
# 6       4184   7.98    85799.0      [Comedy, Drama, Romance]
# 7        244   7.54    13964.0                      [Sports]
#
#                                     themes demographics
# 2                             [Adult Cast]      Shounen
# 4                                       []      Shounen
# 5                            [Team Sports]      Shounen
# 6  [Adult Cast, Love Polygon, Visual Arts]        Josei
# 7                            [Team Sports]      Shounen

# %%
df_anime_filtered_demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10788 entries, 2 to 29149
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10788 non-null  object
#  1   aired_from    1360 non-null   datetime64[ns, UTC]
#  2   synopsis      7354 non-null   object
#  3   status        10788 non-null  object
#  4   episodes      10788 non-null  float64
#  5   rating        10663 non-null  object
#  6   rank          9421 non-null   float64
#  7   popularity    10788 non-null  int64
#  8   members       10788 non-null  int64
#  9   favorites     10788 non-null  int64
#  10  score         10788 non-null  float64
#  11  scored_by     5171 non-null   float64
#  12  genres        10788 non-null  object
#  13  themes        10788 non-null  object
#  14  demographics  10788 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(3), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
#  **Buscando missing values**

# %%
original_missing_values = df.isnull().sum()
original_missing_percentage = (original_missing_values / len(df)) * 100

missing_values = df_anime_filtered_demographics.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

print("Número de valores faltantes por coluna, base original")
display(original_missing_values)

print("\n\nNúmero de valores faltantes por coluna, base modificada")
display(missing_values)
# Out:
# Número de valores faltantes por coluna, base original
# title                 0
# title_english     16678
# title_japanese      222
# image                 0
# aired_from        25030
# aired_to          27046
# synopsis           5183
# status                0
# episodes              0
# rating              686
# rank               6792
# popularity            0
# members               0
# favorites             0
# score             10472
# scored_by         10472
# genres             6174
# themes            11918
# demographics      18365
# dtype: int64
# Número de valores faltantes por coluna, base modificada
# title              0
# aired_from      9428
# synopsis        3434
# status             0
# episodes           0
# rating           125
# rank            1367
# popularity         0
# members            0
# favorites          0
# score              0
# scored_by       5617
# genres             0
# themes             0
# demographics       0
# dtype: int64

# %%
print("Porcentagem de valores faltantes por coluna, base original")
display(original_missing_percentage)

print("\n\nPorcentagem de valores faltantes por coluna, base modificada")
display(missing_percentage)
# Out:
# Porcentagem de valores faltantes por coluna, base original
# title              0.000000
# title_english     57.208521
# title_japanese     0.761500
# image              0.000000
# aired_from        85.857373
# aired_to          92.772613
# synopsis          17.778616
# status             0.000000
# episodes           0.000000
# rating             2.353103
# rank              23.297774
# popularity         0.000000
# members            0.000000
# favorites          0.000000
# score             35.920831
# scored_by         35.920831
# genres            21.177923
# themes            40.880870
# demographics      62.995232
# dtype: float64
# Porcentagem de valores faltantes por coluna, base modificada
# title            0.000000
# aired_from      32.339725
# synopsis        11.779234
# status           0.000000
# episodes         0.000000
# rating           0.428772
# rank             4.689054
# popularity       0.000000
# members          0.000000
# favorites        0.000000
# score            0.000000
# scored_by       19.267314
# genres           0.000000
# themes           0.000000
# demographics     0.000000
# dtype: float64

# %% [markdown]
# # **Análises**

# %% [markdown]
# ## **Correlação**
#
# **Associação entre variáveis:** Quais pares numéricos têm maior correlação?

# %%
num_cols = df_anime_filtered_demographics.select_dtypes(include='number').columns.tolist()
corr = df_anime_filtered_demographics[num_cols].corr()

plt.figure(figsize=(6,5))
plt.imshow(corr, interpolation='nearest')
plt.title("Matriz de Correlação")
plt.colorbar()
plt.xticks(ticks=range(len(num_cols)), labels=num_cols, rotation=90)
plt.yticks(ticks=range(len(num_cols)), labels=num_cols)
plt.tight_layout()
plt.show()

pairs = []
for i in range(len(num_cols)):
    for j in range(i+1, len(num_cols)):
        pairs.append((num_cols[i], num_cols[j], corr.iloc[i, j]))
pairs_sorted = sorted(pairs, key=lambda x: abs(x[2]), reverse=True)[:3]
print("Resposta P3: Maiores correlações (valor absoluto):")
for a,b,v in pairs_sorted:
    print(f" - {a} x {b}: {v:.2f}")
# Out:
# Resposta P3: Maiores correlações (valor absoluto):
#  - members x scored_by: 0.99
#  - rank x popularity: 0.91
#  - favorites x scored_by: 0.78

# %%
numeric_cols = df_anime_filtered_demographics.select_dtypes(include='number')

plt.figure(figsize=(10, 8))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# Com base na análise de correlação:
#
#
# *   **members x scored_by (0.99):** Essa correlação é esperada, pois animes com mais membros tendem a ter mais avaliações.
# *   **rank x popularity (0.87):** Isso sugere que animes com um bom ranking geral (menor valor de rank) também são populares (menor valor de popularity).
# *   **members x favorites (0.86):** Isso indica que animes com muitos membros também são frequentemente adicionados à lista de favoritos.

# %% [markdown]
# **members x scored_by (0.99)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='members', y='scored_by')
plt.title('Correlação entre Members e Scored_by')
plt.xlabel('Members')
plt.ylabel('Scored_by')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='scored_by', ascending=False)

print("Top 10 animes maior score:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='members', ascending=False)

print("\n\nTop 10 animes maior número de membros:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))
# Out:
# Top 10 animes maior score:
#                                   title  score    rank  members  popularity  \
# 7424                 Shingeki no Kyojin   8.56   117.0  4188784           1
# 1393                         Death Note   8.62    92.0  4128800           2
# 10400                     One Punch Man   8.48   155.0  3404988           4
# 14519                  Kimetsu no Yaiba   8.43   187.0  3281711           5
# 3960   Fullmetal Alchemist: Brotherhood   9.10     2.0  3541474           3
# 11126             Boku no Hero Academia   7.84   986.0  3189172           7
# 10                               Naruto   8.01   674.0  3006981           9
# 9345        Shingeki no Kyojin Season 2   8.53   133.0  2899674          12
# 8612                        Tokyo Ghoul   7.79  1109.0  2962695          10
# 6452             Hunter x Hunter (2011)   9.03     8.0  3044411           8
#
#        favorites  scored_by
# 7424      181378  2952092.0
# 1393      180547  2891301.0
# 10400      65898  2348987.0
# 14519      93059  2253318.0
# 3960      234763  2228653.0
# 11126      53975  2166682.0
# 10         83595  2070000.0
# 9345       22435  1983504.0
# 8612       51829  1947195.0
# 6452      221664  1889635.0
# Top 10 animes maior número de membros:
#                                   title  score    rank  members  popularity  \
# 7424                 Shingeki no Kyojin   8.56   117.0  4188784           1
# 1393                         Death Note   8.62    92.0  4128800           2
# 3960   Fullmetal Alchemist: Brotherhood   9.10     2.0  3541474           3
# 10400                     One Punch Man   8.48   155.0  3404988           4
# 14519                  Kimetsu no Yaiba   8.43   187.0  3281711           5
# 11126             Boku no Hero Academia   7.84   986.0  3189172           7
# 6452             Hunter x Hunter (2011)   9.03     8.0  3044411           8
# 10                               Naruto   8.01   674.0  3006981           9
# 8612                        Tokyo Ghoul   7.79  1109.0  2962695          10
# 9345        Shingeki no Kyojin Season 2   8.53   133.0  2899674          12
#
#        favorites
# 7424      181378
# 1393      180547
# 3960      234763
# 10400      65898
# 14519      93059
# 11126      53975
# 6452      221664
# 10         83595
# 8612       51829
# 9345       22435

# %% [markdown]
# **rank x popularity (0.87)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='rank', y='popularity')
plt.title('Correlação entre Rank e Popularity')
plt.xlabel('Rank (quanto menor, melhor)')
plt.ylabel('Popularity (quanto menor, melhor)')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='rank', ascending=True)

print("Top 10 animes menor rank:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='popularity', ascending=False)

print("\n\nTop 10 animes por popularidade:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))
# Out:
# Top 10 animes menor rank:
#                                                    title  score  rank  \
# 29076                                     Da Ai Xian Zun   6.37   0.0
# 29115                 Meitantei Conan: Senkou no Payload   6.37   0.0
# 29058                      Nae Namjachingu neun Gomdori!   6.37   0.0
# 29081                Yuanshen: The limits of the deities   6.37   0.0
# 29149                                DJ Pikachu Full Set   6.37   0.0
# 28731                           Xiongmao He Gan Mi Xiong   6.37   0.0
# 28322  Super Sentai Universe Taisen ~Number 1 Sentai ...   6.37   0.0
# 27998                            Wacky Races: Japan Tour   6.37   0.0
# 28115    Matcha Pokemon "Chades" no Kimyou na Monogatari   6.37   0.0
# 28820                  Tu Bian Yingxiong X Concept Movie   6.37   0.0
#
#        members  popularity  favorites
# 29076        0           0          0
# 29115        0           0          0
# 29058        0           0          0
# 29081        0           0          0
# 29149        0           0          0
# 28731        0           0          0
# 28322        0           0          0
# 27998        0           0          0
# 28115        0           0          0
# 28820        0           0          0
# Top 10 animes por popularidade:
#                                        title  score     rank  members  \
# 29132                          Tomica to Tom   6.37  15383.0       24
# 28962                           Kenka no Uta   6.37      NaN       31
# 28977                         Tsumori Yamori   6.37      NaN       33
# 28997                       Yama no Ongakuka   6.37      NaN       32
# 28976                         Suteki na Yoru   6.37      NaN       32
# 28931                             Shikushiku   6.37      NaN       33
# 28963                    Kodomo Shunoukaidan   6.37      NaN       33
# 28957                      Neko no Komoriuta   6.37      NaN       34
# 28998                            △□○Kobicchi   6.37      NaN       36
# 28907  Kusunoki: 500-nen no Kaze ni Fukarete   6.37      NaN       36
#
#        popularity  favorites
# 29132       28653          0
# 28962       28644          0
# 28977       28640          0
# 28997       28636          0
# 28976       28635          0
# 28931       28634          0
# 28963       28631          0
# 28957       28630          0
# 28998       28629          0
# 28907       28628          0

# %% [markdown]
# **members x favorites (0.86)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='members', y='favorites')
plt.title('Correlação entre Members e Favorites')
plt.xlabel('Members')
plt.ylabel('Favorites')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='members', ascending=False)

print("Top 10 animes maior número de membros:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='favorites', ascending=False)

print("\n\nTop 10 animes entre os favoritos:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))
# Out:
# Top 10 animes maior número de membros:
#                        title  score    rank  members  popularity  favorites  \
# 1393              Death Note   8.62    92.0  4128800           2     180547
# 10                    Naruto   8.01   674.0  3006981           9      83595
# 1574      Naruto: Shippuuden   8.28   314.0  2640210          16     116970
# 11                 One Piece   8.73    52.0  2548930          17     239752
# 245                   Bleach   7.97   717.0  2110853          35      79473
# 202               Elfen Lied   7.46  2156.0  1576062          78      24611
# 100      Fullmetal Alchemist   8.11   532.0  1523557          85      26434
# 734            Dragon Ball Z   8.20   412.0  1287087         114      40730
# 9                    Monster   8.89    24.0  1244390         121      58262
# 770   Ouran Koukou Host Club   8.16   468.0  1190809         134      35942
#
#       scored_by
# 1393  2891301.0
# 10    2070000.0
# 1574  1754755.0
# 11    1449377.0
# 245   1208199.0
# 202    904217.0
# 100    916208.0
# 734    882045.0
# 9      473488.0
# 770    708735.0
# Top 10 animes entre os favoritos:
#                        title  score   rank  members  popularity  favorites
# 11                 One Piece   8.73   52.0  2548930          17     239752
# 1393              Death Note   8.62   92.0  4128800           2     180547
# 1574      Naruto: Shippuuden   8.28  314.0  2640210          16     116970
# 10                    Naruto   8.01  674.0  3006981           9      83595
# 245                   Bleach   7.97  717.0  2110853          35      79473
# 833                  Gintama   8.93   17.0  1120840         147      60661
# 9                    Monster   8.89   24.0  1244390         121      58262
# 734            Dragon Ball Z   8.20  412.0  1287087         114      40730
# 770   Ouran Koukou Host Club   8.16  468.0  1190809         134      35942
# 792                     Nana   8.56  115.0   736142         296      33206

# %% [markdown]
# **Top 10 Animes com Maior Número de Membros**

# %%
# Filtrar os 10 maiores por número de membros
top_members = df_anime_filtered_demographics.sort_values(by='members', ascending=False).head(10)

plt.figure(figsize=(18, 10))
sns.barplot(
    data=top_members,
    x='members',
    y='title',
    palette='viridis'
)

plt.title('Top 10 Animes com Maior Número de Membros', fontsize=16)
plt.xlabel('Número de Membros', fontsize=10)
plt.ylabel('Título', fontsize=10)

for index, value in enumerate(top_members['members']):
    plt.text(value + 10000, index, f'{value:,}', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2194111322.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
#  **Quais são os tipos de generos mais populares dos animes?**

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# Obter os dados de contagem usando a Series 'all_genres' criada na célula anterior
all_genres = df_anime_filtered_demographics['genres'].explode()
genre_counts = all_genres.value_counts()

# Criar o gráfico de barras
plt.figure(figsize=(14, 7))
ax = sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')

# Rotacionar os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=90)

# Adicionar título e rótulos aos eixos
plt.title('Contagem de Animes por Gênero', fontsize=16)
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)

# Adicionar os números acima de cada barra
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

# Exibir o gráfico
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-568348947.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')

# %% [markdown]
# **O número de animes produzidos por ano cresceu ou diminuiu ao longo do tempo?**

# %%
# O número de animes produzidos por ano cresceu ou diminuiu ao longo do tempo?
# Extrair o ano da coluna 'aired_from'
df_anime_filtered_demographics = df_anime_filtered_demographics.dropna(subset=['aired_from'])
df_anime_filtered_demographics['year'] = df_anime_filtered_demographics['aired_from'].dt.year.astype(int)

# Contar o número de animes por ano e ordenar cronologicamente
anime_por_ano = df_anime_filtered_demographics['year'].value_counts().sort_index()

plt.figure(figsize=(15, 8))
ax = anime_por_ano.plot(kind='bar')

for i, valor in enumerate(anime_por_ano):
    ax.text(i, valor + 1, str(valor), ha='center', va='bottom', fontsize=10)

# Adicionar títulos e rótulos
plt.title('Número de Animes Produzidos por Ano', fontsize=16)
plt.xlabel('Ano', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)

plt.tight_layout()
plt.show()
